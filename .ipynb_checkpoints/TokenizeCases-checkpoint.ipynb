# %% [markdown]
# This is supposed to be the tokenization script. From the given set of cases it will find out the trigrams and bigrams as per the dictionary that we are applying
#
# Takes as an input the dictionary that has been created using the POS+NGram dictionary

# %%
import re
#read the entire file in a single shot.
#I have added the string ---break --- to demarcate the next case, since the newline is not working properly in php

fname="all_jim_case_large.txt"
with open(fname, 'r') as myfile:
    data=myfile.read()

data=data.split('-------BREAK--------')
cases=[case.strip() for case in data]
print(cases[1:10])

#read the dictionary and split it on comma
dictFile="keywordMapping_jim.csv"
dictLines = [dictLine.rstrip('\n').split(',') for dictLine in open(dictFile)]
unigramDict={}
ngramDict={}
for ll in dictLines:
    #check for the presenc eof space
    if(len(ll[2].split())>1):
        str=ll[1]
        str=str.replace('"','')
        ngramDict[str]=ll[2]
        #ngramDict[ll[1]]=ll[2].replace(" ","_")
        #ngramDict[ll[1]].replace('"','')
    else:
        str=ll[1]
        str=str[1:-1]
        unigramDict[str]=ll[2]
        unigramDict[str].replace('"','')


#print(unigramDict)
# Out:
# ['It appears while the turbine is active power is moving around the wind speed sensor is returning a flatline value.\n\nUpdate 1-3-14: Appears the Anemometer issues have been resolved as of 1-2-14 at 7:00am', 'Since 11/25/14, the following tags are indicating intermittent flatlines: IDO WTG001 MDK030 BT001:XQ01.M_HSRot_Tmp, IDO WTG001 MDK030 BT002:XQ01.M_IMSGen_Tmp, and IDO WTG001 MDK030 BT003:XQ01.M_IMSRot_Tmp Actual temperatures are acceptable when tags are not flatlining (~65 degC). Update 1/26/15: Flatlines cleared. Closing case.', 'Beginning Aug 8, wind turbine 1 appears curtailed at ~2700 kW with wind speed between ~4-13 m/s.', 'During higher wind conditions the turbine is currently limited to 1.8 MW', 'Since 2/23/15, wind turbine 2 appears to be curtailed at ~2700 kW with wind speed between ~5-21 m/s.  Update 4/13/15: Wind turbine 2 appears to be curtailed since 4/10. Currently, active power is ~2700 kW.  Curtailment cleared.', 'On 11/27/14, generator bearing temperature remained above the model estimate for ~14 hours.The maximum temperature observed was ~83 degC with a model estimate of ~62 degC.  Update 4/13/15: The condition persists with a high temperature of ~78C observed on 4/9.', 'Within the past week, DE bearing temperatures have been tracking ~10-20C above the model, as high as ~84C. No other deviations are noted in the model.', 'Within the past week, generator bearing temperature DE has exceeded the model estimate with a recent increase as high as ~79C with an estimate of ~60C. The turbine was running at lower power when most of the increases occurred at <2000kW and generator speed was <1500 RPM. Ambient temperature was ~3-4C during this time.', 'While the unit is operating at decreased power <2000 kW, generator bearing temperature DE has been elevated running as high as ~86C. Ambient is ~15-18C during this time. Other wind turbines during the same timeframe are operating with DE temperatures ~50-60C with similar active power.']

# %%
def my_in_array(word,dictArr):
    # print(type(word))
    for idx,key in enumerate(dictArr):
        # print(key,word)
        if(key==word):
            # print(word)
            return(dictArr[key])
print(my_in_array("vlv",unigramDict))
# Out:
# "valve"

# %% [markdown]
# The function to deal with the ngrams. It would return the strings connected by _

# %%
def getNormalizedWord(word,ngramDict):
    retWord = my_in_array(word,ngramDict)
    if (retWord):
        retWord = retWord.replace(" ", "_", )
        retWord=retWord.replace('"','')
        retWord=retWord+" "
    return (retWord)
print(getNormalizedWord("lube oil filter",ngramDict))
# Out:
# lube_oil_filter

# %% [markdown]
# Now we need to apply the dictionary to the cases that were read earlier.
# Also while applying the dictionary elemens we will remove the punctuation etc

# %%
arrUnigramFiltered = []
startCaseNumber=0
endCaseNumber=500
for count in range(startCaseNumber,endCaseNumber):
    # print("before {}",case)
    case=cases[count]
    case = case.strip();
    case = re.sub('/[^A-Za-z0-9 _\-\+\&\,\#]/', '', case)
    case = case.replace('"', ' ')
    case = case.replace('\"', ' ')
    case = case.replace('>', ' ')
    case = case.replace('@', ' ')
    case = case.replace('<', ' ')
    case = case.replace(':', ' ')
    case = case.replace('.', ' ')
    case = case.replace('(', ' ')
    case = case.replace(')', ' ')
    case = case.replace('[', ' ')
    case = case.replace(']', ' ')
    case = case.replace('_', ' ')
    case = case.replace(',', ' ')
    case = case.replace('#', ' ')
    case = case.replace('-', ' ')
    case = case.replace('/', ' ')
    case = case.replace('"', ' ')
    case = case.replace('\n', ' ')
    case = case.replace('~', ' ')
    case = re.sub(r'\d+', ' ', case)

    #print("after {}",case)
    arrTempTerms = case.split(" ")
    str = ''
    for term in arrTempTerms:
        largestStringFound = ''
        firstword = term.lower()
        tempword = firstword
        # check if the word is present in Unigram dictionary
        print(firstword, tempword)
        retWord = my_in_array(tempword, unigramDict)
        print(retWord)
        if (retWord):
            retWord = retWord.replace('"', '')
            str += retWord+" "
        else:
            if (len(tempword) >= 1):
                 str=str+tempword+" "
    arrUnigramFiltered.append(str)
# Out:
# tagido tagido
# None
# ons ons
# None
#
# None
# cba cba
# None
#
# None
# bj bj
# None
#
# None
# xq xq
# "xq"
#
# None
# m m
# None
# act act
# None
# pw pw
# None
# appears appears
# None
# to to
# None
# be be
# None
# flatlined flatlined
# "flatline"
# at at
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# flatline flatline
# "flatline"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
# it it
# None
# appears appears
# None
# while while
# None
# the the
# None
# turbine turbine
# "turbine"
# is is
# None
# active active
# None
# power power
# "power"
# is is
# None
# moving moving
# None
# around around
# None
# the the
# None
# wind wind
# "wind"
# speed speed
# "speed"
# sensor sensor
# "sensor"
# is is
# None
# returning returning
# None
# a a
# None
# flatline flatline
# "flatline"
# value value
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# appears appears
# None
# the the
# None
# anemometer anemometer
# None
# issues issues
# "issue"
# have have
# None
# been been
# None
# resolved resolved
# None
# as as
# None
# of of
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# at at
# None
#
# None
#
# None
#
# None
# am am
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# the the
# None
# following following
# None
# tags tags
# "tag"
# are are
# None
# indicating indicating
# None
# intermittent intermittent
# "intermittent"
# flatlines flatlines
# "flatline"
#
# None
# ido ido
# None
# wtg wtg
# None
#
# None
# mdk mdk
# None
#
# None
# bt bt
# None
#
# None
# xq xq
# "xq"
#
# None
# m m
# None
# hsrot hsrot
# None
# tmp tmp
# "temperature"
#
# None
# ido ido
# None
# wtg wtg
# None
#
# None
# mdk mdk
# None
#
# None
# bt bt
# None
#
# None
# xq xq
# "xq"
#
# None
# m m
# None
# imsgen imsgen
# None
# tmp tmp
# "temperature"
#
# None
# and and
# None
# ido ido
# None
# wtg wtg
# None
#
# None
# mdk mdk
# None
#
# None
# bt bt
# None
#
# None
# xq xq
# "xq"
#
# None
# m m
# None
# imsrot imsrot
# None
# tmp tmp
# "temperature"
# actual actual
# None
# temperatures temperatures
# None
# are are
# None
# acceptable acceptable
# None
# when when
# None
# tags tags
# "tag"
# are are
# None
# not not
# None
# flatlining flatlining
# "flatline"
# ( (
# None
#
# None
#
# None
# degc) degc)
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# flatlines flatlines
# "flatline"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# beginning beginning
# None
# aug aug
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# during during
# None
# higher higher
# None
# wind wind
# "wind"
# conditions conditions
# "condition"
# the the
# None
# turbine turbine
# "turbine"
# is is
# None
# currently currently
# None
# limited limited
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# mw mw
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# currently currently
# None
#
# None
# active active
# None
# power power
# "power"
# is is
# None
#
# None
#
# None
#
# None
# kw kw
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# remained remained
# "remained"
# above above
# None
# the the
# None
# model model
# "model"
# estimate estimate
# "estimate"
# for for
# None
#
# None
#
# None
#
# None
# hours hours
# None
# the the
# None
# maximum maximum
# None
# temperature temperature
# "temperature"
# observed observed
# "observed"
# was was
# None
#
# None
#
# None
#
# None
# degc degc
# None
# with with
# None
# a a
# None
# model model
# "model"
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
#
# None
# degc degc
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# the the
# None
# condition condition
# "condition"
# persists persists
# "persist"
# with with
# None
# a a
# None
# high high
# None
# temperature temperature
# "temperature"
# of of
# None
#
# None
#
# None
# c c
# None
# observed observed
# "observed"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# within within
# None
# the the
# None
# past past
# None
# week week
# None
#
# None
# de de
# "de"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# have have
# None
# been been
# None
# tracking tracking
# "track"
#
# None
#
# None
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
#
# None
# no no
# None
# other other
# None
# deviations deviations
# "deviate"
# are are
# None
# noted noted
# None
# in in
# None
# the the
# None
# model model
# "model"
#
# None
# within within
# None
# the the
# None
# past past
# None
# week week
# None
#
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# de de
# "de"
# has has
# None
# exceeded exceeded
# "exceeded"
# the the
# None
# model model
# "model"
# estimate estimate
# "estimate"
# with with
# None
# a a
# None
# recent recent
# None
# increase increase
# "increase"
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
# with with
# None
# an an
# None
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
# c c
# None
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# running running
# None
# at at
# None
# lower lower
# "lower"
# power power
# "power"
# when when
# None
# most most
# None
# of of
# None
# the the
# None
# increases increases
# "increase"
# occurred occurred
# None
# at at
# None
#
# None
#
# None
# kw kw
# None
# and and
# None
# generator generator
# "generator"
# speed speed
# "speed"
# was was
# None
#
# None
#
# None
#
# None
# rpm rpm
# None
#
# None
# ambient ambient
# "ambient"
# temperature temperature
# "temperature"
# was was
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# while while
# None
# the the
# None
# unit unit
# "unit"
# is is
# None
# operating operating
# None
# at at
# None
# decreased decreased
# "decrease"
# power power
# "power"
#
# None
#
# None
#
# None
# kw kw
# None
#
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# de de
# "de"
# has has
# None
# been been
# None
# elevated elevated
# "elevated"
# running running
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
#
# None
# ambient ambient
# "ambient"
# is is
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# other other
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
# during during
# None
# the the
# None
# same same
# None
# timeframe timeframe
# "timeframe"
# are are
# None
# operating operating
# None
# with with
# None
# de de
# "de"
# temperatures temperatures
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# with with
# None
# similar similar
# None
# active active
# None
# power power
# "power"
#
# None
# we we
# None
# are are
# None
# currently currently
# None
# seeing seeing
# None
# the the
# None
# active active
# None
# power power
# "power"
# tag tag
# "tag"
# for for
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# at at
# None
#
# None
#
# None
# mw mw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# from from
# None
#
# None
#
# None
# to to
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# note note
# None
#
# None
# the the
# None
# wps wps
# None
# status status
# None
# tag tag
# "tag"
# is is
# None
# returning returning
# None
# a a
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# while while
# None
# the the
# None
# wt wt
# None
# operating operating
# None
# state state
# None
# is is
# None
# returning returning
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# within within
# None
# the the
# None
# past past
# None
#
# None
#
# None
# weeks weeks
# None
#
# None
# wtg wtg
# None
#
# None
# has has
# None
# been been
# None
# exhibiting exhibiting
# "exhibited"
# increased increased
# None
# nde nde
# "nde"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# that that
# None
# have have
# None
# spiked spiked
# "spike"
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# nde nde
# "nde"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# was was
# None
#
# None
#
# None
#
# None
# c c
# None
# with with
# None
# a a
# None
# model model
# "model"
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
# c c
# None
#
# None
# this this
# None
# has has
# None
# created created
# None
# an an
# None
# increased increased
# None
# nde nde
# "nde"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# spread spread
# "spread"
# of of
# None
#
# None
#
# None
# c c
# None
# between between
# None
# the the
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
#
# None
# no no
# None
# other other
# None
# adverse adverse
# None
# bearing bearing
# "bearing"
# trends trends
# None
# were were
# None
# noted noted
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# within within
# None
# the the
# None
# past past
# None
# week week
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# de de
# "de"
# has has
# None
# been been
# None
# increased increased
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
# with with
# None
# an an
# None
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
# c c
# None
#
# None
# temperatures temperatures
# None
# remained remained
# "remained"
# above above
# None
# the the
# None
# model model
# "model"
# for for
# None
#
# None
#
# None
#
# None
# hrs hrs
# None
# before before
# None
# returning returning
# None
# to to
# None
# the the
# None
# model model
# "model"
#
# None
# since since
# None
#
# None
# oct oct
# None
#
# None
#
# None
#
# None
#
# None
# nde nde
# "nde"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# have have
# None
# been been
# None
# tracking tracking
# "track"
#
# None
#
# None
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
#
# None
# no no
# None
# other other
# None
# deviations deviations
# "deviate"
# are are
# None
# noted noted
# None
# in in
# None
# the the
# None
# model model
# "model"
#
# None
# beginning beginning
# None
# may may
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# on on
# None
# may may
# None
#
# None
#
# None
#
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# appeared appeared
# None
# to to
# None
# return return
# None
# from from
# None
# curtailment curtailment
# "curtailed"
# to to
# None
# full full
# None
# power power
# "power"
# but but
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# again again
# None
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# beginning beginning
# None
# may may
# None
#
# None
#
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
# while while
# None
# the the
# None
# unit unit
# "unit"
# is is
# None
# operating operating
# None
# at at
# None
# decreased decreased
# "decrease"
# power power
# "power"
#
# None
#
# None
#
# None
# kw kw
# None
#
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# nde nde
# "nde"
# increased increased
# None
# to to
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
# before before
# None
# returning returning
# None
# to to
# None
# the the
# None
# model model
# "model"
# when when
# None
# the the
# None
# unit unit
# "unit"
# increased increased
# None
# in in
# None
# power power
# "power"
#
# None
# ambient ambient
# "ambient"
# was was
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# nde nde
# "nde"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# are are
# None
# showing showing
# None
# an an
# None
# increased increased
# None
# frequency frequency
# None
# of of
# None
# high high
# None
# temperature temperature
# "temperature"
# spikes spikes
# "spike"
# within within
# None
# the the
# None
# past past
# None
# week week
# None
#
# None
# temperatures temperatures
# None
# have have
# None
# increased increased
# None
# to to
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
#
# None
# de de
# "de"
# temperatures temperatures
# None
# are are
# None
# tracking tracking
# "track"
# the the
# None
# model model
# "model"
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# geip geip
# "geip"
# to to
# None
# continue continue
# None
# monitoring monitoring
# "monitor"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# on on
# None
# jan jan
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# increased increased
# None
# to to
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# and and
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# running running
# None
# at at
# None
# full full
# None
# power power
# "power"
#
# None
# ambient ambient
# "ambient"
# was was
# None
#
# None
#
# None
# c c
# None
#
# None
# and and
# None
# there there
# None
# was was
# None
# a a
# None
# brief brief
# None
# increase increase
# "increase"
# in in
# None
# wind wind
# "wind"
# speed speed
# "speed"
# up up
# None
# to to
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
# then then
# None
#
# None
# temperatures temperatures
# None
# are are
# None
# not not
# None
# modulating modulating
# None
# as as
# None
# well well
# None
# as as
# None
# they they
# None
# have have
# None
# in in
# None
# the the
# None
# past past
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# weekly weekly
# None
# report report
# None
#
# None
# since since
# None
# mar mar
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# have have
# None
# been been
# None
# increased increased
# None
#
# None
# high high
# None
# temperatures temperatures
# None
# observed observed
# "observed"
# are are
# None
#
# None
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
#
# None
# c c
# None
#
# None
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
# c c
# None
#
# None
# and and
# None
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
#
# None
# c c
# None
#
# None
# within within
# None
# the the
# None
# past past
# None
# week week
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# increased increased
# None
# to to
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# and and
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# running running
# None
# at at
# None
# full full
# None
# power power
# "power"
# during during
# None
# periods periods
# "periodically"
# of of
# None
# increased increased
# None
# temperatures temperatures
# None
#
# None
# and and
# None
# ambient ambient
# "ambient"
# is is
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# compared compared
# None
# to to
# None
# other other
# None
# turbines turbines
# "turbine"
# during during
# None
# the the
# None
# same same
# None
# time time
# None
# period period
# None
#
# None
# temperatures temperatures
# None
# are are
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# higher higher
# None
# on on
# None
# turbine turbine
# "turbine"
#
# None
#
# None
#
# None
#
# None
# case case
# None
#
# None
#
# None
# was was
# None
# closed closed
# "close"
#
# None
#
# None
#
# None
# months months
# None
# ago ago
# None
# for for
# None
# the the
# None
# same same
# None
# issue issue
# "issue"
# and and
# None
# some some
# None
# vibration vibration
# "vibration"
# issues issues
# "issue"
# were were
# None
# noted noted
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# have have
# None
# increased increased
# None
# to to
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# and and
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# hs hs
# "hs"
# rot rot
# "rot"
# with with
# None
# the the
# None
# turbine turbine
# "turbine"
# running running
# None
# at at
# None
# full full
# None
# power power
# "power"
# from from
# None
# aug aug
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# ambient ambient
# "ambient"
# was was
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# indicating indicating
# None
# a a
# None
# code code
# None
#
# None
#
# None
# on on
# None
# the the
# None
# wt wt
# None
# operating operating
# None
# state state
# None
# tag tag
# "tag"
#
# None
# is is
# None
# this this
# None
# turbine turbine
# "turbine"
# down down
# None
# for for
# None
# maintenance maintenance
# None
#
# None
# or or
# None
# is is
# None
# this this
# None
# due due
# None
# to to
# None
# an an
# None
# error error
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# condition condition
# "condition"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
# it it
# None
# appears appears
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# at at
# None
# inner inner
# "inner"
# dowsing dowsing
# None
# is is
# None
# currently currently
# None
# being being
# None
# curtailed curtailed
# "curtailed"
# to to
# None
#
# None
#
# None
#
# None
# mw mw
# None
# beginning beginning
# None
# apr apr
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
# it it
# None
# appears appears
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# came came
# None
# online online
# None
# but but
# None
# only only
# None
# to to
# None
# produce produce
# None
#
# None
#
# None
# kw kw
# None
# it it
# None
# had had
# None
# stayed stayed
# None
# this this
# None
# way way
# None
# for for
# None
# roughly roughly
# None
#
# None
#
# None
# hours hours
# None
# and and
# None
# then then
# None
# returned returned
# None
# to to
# None
# full full
# None
# power power
# "power"
# on on
# None
# feb feb
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# increased increased
# None
# to to
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# and and
# None
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# running running
# None
# at at
# None
# full full
# None
# power power
# "power"
# and and
# None
# ambient ambient
# "ambient"
# was was
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
#
# None
# since since
# None
# feb feb
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# appear appear
# None
# to to
# None
# be be
# None
# modulating modulating
# None
#
# None
# but but
# None
# temperatures temperatures
# None
# remained remained
# "remained"
# increased increased
# None
#
# None
# temperatures temperatures
# None
# are are
# None
# not not
# None
# excessive excessive
# None
#
# None
# however however
# None
#
# None
# this this
# None
# was was
# None
# compared compared
# None
# with with
# None
# other other
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
#
# None
# and and
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# hs hs
# "hs"
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# are are
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# above above
# None
# other other
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
# running running
# None
#
# None
#
# None
# c c
# None
# it it
# None
# appears appears
# None
# that that
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# being being
# None
# limited limited
# None
# to to
# None
#
# None
#
# None
# kw kw
# None
# of of
# None
# power power
# "power"
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# wwind wwind
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# we we
# None
# are are
# None
# currently currently
# None
# seeing seeing
# None
# the the
# None
# active active
# None
# power power
# "power"
# tag tag
# "tag"
# for for
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# at at
# None
#
# None
#
# None
# mw mw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# from from
# None
#
# None
#
# None
# to to
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# beginning beginning
# None
# feb feb
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# was was
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# curtailment curtailment
# "curtailed"
# appears appears
# None
# to to
# None
# have have
# None
# cleared cleared
# "cleared"
# since since
# None
# feb feb
# None
#
# None
#
# None
#
# None
#
# None
# note note
# None
#
# None
# this this
# None
# was was
# None
# originally originally
# None
# communicated communicated
# None
# via via
# None
# a a
# None
# rapid rapid
# "rapid"
# response response
# None
# notification notification
# "notification"
#
# None
# beginning beginning
# None
# may may
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# indicating indicating
# None
# a a
# None
# code code
# None
#
# None
#
# None
# on on
# None
# the the
# None
# wt wt
# None
# operating operating
# None
# state state
# None
# tag tag
# "tag"
#
# None
# is is
# None
# this this
# None
# turbine turbine
# "turbine"
# down down
# None
# for for
# None
# maintenance maintenance
# None
#
# None
# or or
# None
# is is
# None
# this this
# None
# due due
# None
# to to
# None
# an an
# None
# error error
# None
#
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# condition condition
# "condition"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# curtailment curtailment
# "curtailed"
# changed changed
# None
# from from
# None
#
# None
#
# None
#
# None
# kw kw
# None
# to to
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# note note
# None
#
# None
# this this
# None
# was was
# None
# originally originally
# None
# communicated communicated
# None
# via via
# None
# email email
# None
# notification notification
# "notification"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# a a
# None
# short short
# "short"
# increase increase
# "increase"
# to to
# None
#
# None
#
# None
#
# None
# kw kw
# None
# was was
# None
# observed observed
# "observed"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# while while
# None
# the the
# None
# unit unit
# "unit"
# is is
# None
# operating operating
# None
# at at
# None
# decreased decreased
# "decrease"
# power power
# "power"
#
# None
#
# None
#
# None
# kw kw
# None
#
# None
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# de de
# "de"
# has has
# None
# been been
# None
# elevated elevated
# "elevated"
# running running
# None
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
#
# None
# ambient ambient
# "ambient"
# is is
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# during during
# None
# this this
# None
# time time
# None
#
# None
# other other
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
# during during
# None
# the the
# None
# same same
# None
# timeframe timeframe
# "timeframe"
# are are
# None
# operating operating
# None
# with with
# None
# de de
# "de"
# temperatures temperatures
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
# with with
# None
# similar similar
# None
# active active
# None
# power power
# "power"
#
# None
# we we
# None
# are are
# None
# currently currently
# None
# seeing seeing
# None
# the the
# None
# active active
# None
# power power
# "power"
# tag tag
# "tag"
# for for
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# at at
# None
#
# None
#
# None
# mw mw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# from from
# None
#
# None
#
# None
# to to
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# a a
# None
# short short
# "short"
# increase increase
# "increase"
# to to
# None
#
# None
#
# None
#
# None
# kw kw
# None
# was was
# None
# observed observed
# "observed"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# it it
# None
# appears appears
# None
# there there
# None
# is is
# None
# a a
# None
# possible possible
# None
# amemometer amemometer
# None
# issue issue
# "issue"
# on on
# None
# turbine turbine
# "turbine"
#
# None
#
# None
#
# None
# currently currently
# None
# it it
# None
# is is
# None
# returning returning
# None
# flatline flatline
# "flatline"
# values values
# "values"
# at at
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# sbut sbut
# None
# the the
# None
# active active
# None
# power power
# "power"
# is is
# None
# reading reading
# "read"
#
# None
# kw kw
# None
#
# None
# wind wind
# "wind"
# at at
# None
# the the
# None
# farm farm
# None
# is is
# None
# around around
# None
#
# None
# m m
# None
# s s
# None
# flatline flatline
# "flatline"
# data data
# "data"
# recieved recieved
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# from from
# None
#
# None
#
# None
#
# None
# am am
# None
# to to
# None
#
# None
#
# None
# am am
# None
#
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# for for
# None
# inner inner
# "inner"
# dowsing dowsing
# None
# in in
# None
# not not
# None
# returning returning
# None
# current current
# "current"
# data data
# "data"
#
# None
# during during
# None
# the the
# None
# recent recent
# None
# period period
# None
# of of
# None
# operation operation
# None
# starting starting
# None
# june june
# None
#
# None
#
# None
#
# None
# de de
# "de"
# generator generator
# "generator"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# have have
# None
# exceeded exceeded
# "exceeded"
# the the
# None
# estimates estimates
# "estimate"
# with with
# None
# a a
# None
# recent recent
# None
# high high
# None
# of of
# None
#
# None
#
# None
# c c
# None
# observed observed
# "observed"
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# all all
# None
# other other
# None
# bearings bearings
# "bearing"
# in in
# None
# the the
# None
# model model
# "model"
# are are
# None
# tracking tracking
# "track"
# the the
# None
# estimates estimates
# "estimate"
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# operating operating
# None
# at at
# None
#
# None
#
# None
# kw kw
# None
# during during
# None
# this this
# None
# period period
# None
# of of
# None
# increased increased
# None
# temperature temperature
# "temperature"
#
# None
# beginning beginning
# None
# may may
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
# inner inner
# "inner"
# dowsing dowsing
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# the the
# None
# power power
# "power"
# is is
# None
# currently currently
# None
# limited limited
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# mw mw
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# active active
# None
# power power
# "power"
# increased increased
# None
# to to
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# an an
# None
# email email
# None
# notification notification
# "notification"
# was was
# None
# provided provided
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
# note note
# None
#
# None
# this this
# None
# was was
# None
# originally originally
# None
# communicated communicated
# None
# via via
# None
# email email
# None
# notification notification
# "notification"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# now now
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
# it it
# None
# appears appears
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# currently currently
# None
# limited limited
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# mw mw
# None
# during during
# None
# higher higher
# None
# wind wind
# "wind"
# conditions conditions
# "condition"
#
# None
# beginning beginning
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wtg wtg
# None
#
# None
# has has
# None
# been been
# None
# exhibiting exhibiting
# "exhibited"
# increased increased
# None
# de de
# "de"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# that that
# None
# have have
# None
# spiked spiked
# "spike"
#
# None
#
# None
#
# None
# degc degc
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# de de
# "de"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# was was
# None
#
# None
#
# None
#
# None
# degc degc
# None
# with with
# None
# a a
# None
# model model
# "model"
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
#
# None
# degc degc
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# de de
# "de"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# was was
# None
#
# None
#
# None
#
# None
# degc degc
# None
# with with
# None
# a a
# None
# model model
# "model"
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
#
# None
# degc degc
# None
#
# None
# this this
# None
# has has
# None
# created created
# None
# an an
# None
# increased increased
# None
# de de
# "de"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# spread spread
# "spread"
# of of
# None
#
# None
#
# None
#
# None
# degc degc
# None
# between between
# None
# the the
# None
# wind wind
# "wind"
# turbines turbines
# "turbine"
#
# None
# starting starting
# None
# at at
# None
#
# None
#
# None
#
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
# we we
# None
# started started
# None
# to to
# None
# noitce noitce
# None
# the the
# None
# active active
# None
# power power
# "power"
# for for
# None
# turine turine
# None
#
# None
#
# None
# return return
# None
# flatline flatline
# "flatline"
# data data
# "data"
# compared compared
# None
# to to
# None
# the the
# None
# rest rest
# None
#
# None
# also also
# None
# comparing comparing
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# to to
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# it it
# None
# appears appears
# None
# for for
# None
# the the
# None
# same same
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# struggling struggling
# None
# to to
# None
# maintian maintian
# None
# full full
# None
# power power
# "power"
# at at
# None
# wind wind
# "wind"
# above above
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# it it
# None
# appears appears
# None
# on on
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# the the
# None
# active active
# None
# power power
# "power"
# is is
# None
# remaining remaining
# None
# lower lower
# "lower"
# at at
# None
#
# None
#
# None
# kw kw
# None
#
# None
# it it
# None
# appears appears
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# currently currently
# None
# curtailed curtailed
# "curtailed"
# while while
# None
# we we
# None
# are are
# None
# seeing seeing
# None
# other other
# None
# tubines tubines
# None
# at at
# None
# full full
# None
# power power
# "power"
# and and
# None
# wind wind
# "wind"
# speed speed
# "speed"
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# it it
# None
# appears appears
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# has has
# None
# been been
# None
# limited limited
# None
# to to
# None
#
# None
#
# None
# mw mw
# None
# of of
# None
# power power
# "power"
# late late
# "late"
# on on
# None
# the the
# None
#
# None
# th th
# "th"
# it it
# None
# appear appear
# None
# to to
# None
# have have
# None
# rose rose
# "rose"
# to to
# None
#
# None
#
# None
#
# None
#
# None
# mw mw
# None
#
# None
# we we
# None
# are are
# None
# currently currently
# None
# at at
# None
# a a
# None
# lower lower
# "lower"
# wind wind
# "wind"
# condition condition
# "condition"
# where where
# None
# we we
# None
# have have
# None
# not not
# None
# reached reached
# None
#
# None
#
# None
#
# None
#
# None
# mw mw
# None
# again again
# None
#
# None
# all all
# None
# turbines turbines
# "turbine"
# for for
# None
# lynn lynn
# None
# wind wind
# "wind"
# farm farm
# None
# the the
# None
# active active
# None
# power power
# "power"
# tags tags
# "tag"
# are are
# None
# returning returning
# None
# flatline flatline
# "flatline"
# data data
# "data"
# at at
# None
#
# None
#
# None
# kw kw
# None
#
# None
# we we
# None
# have have
# None
# been been
# None
# receiving receiving
# None
# flatline flatline
# "flatline"
# data data
# "data"
# for for
# None
# turbine turbine
# "turbine"
#
# None
#
# None
# just just
# None
# wanted wanted
# None
# to to
# None
# confirm confirm
# None
# if if
# None
# this this
# None
# turbine turbine
# "turbine"
# is is
# None
# down down
# None
# for for
# None
# maintenance maintenance
# None
# or or
# None
# there there
# None
# is is
# None
# a a
# None
# communication communication
# None
# error error
# None
#
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# generator generator
# "generator"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
# during during
# None
# the the
# None
# period period
# None
# of of
# None
# operation operation
# None
# beginning beginning
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# hs hs
# "hs"
# rot rot
# "rot"
# temperature temperature
# "temperature"
# trended trended
# "trend"
# as as
# None
# high high
# None
# as as
# None
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
#
# None
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# reached reached
# None
#
# None
#
# None
# c c
# None
#
# None
# previously previously
# None
#
# None
# temperatures temperatures
# None
# trended trended
# "trend"
#
# None
#
# None
# c c
# None
# above above
# None
# the the
# None
# model model
# "model"
# at at
# None
#
# None
#
# None
#
# None
#
# None
# c c
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# condition condition
# "condition"
# cleared cleared
# "cleared"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# note note
# None
#
# None
# this this
# None
# condition condition
# "condition"
# also also
# None
# occurred occurred
# None
# on on
# None
# all all
# None
# turbines turbines
# "turbine"
# but but
# None
# temperatures temperatures
# None
# remained remained
# "remained"
# highest highest
# None
# on on
# None
# turbine turbine
# "turbine"
#
# None
#
# None
#
# None
# on on
# None
# jan jan
# None
#
# None
#
# None
#
# None
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# increased increased
# None
# to to
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# and and
# None
#
# None
# c c
# None
# on on
# None
# tag tag
# "tag"
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
# the the
# None
# turbine turbine
# "turbine"
# was was
# None
# running running
# None
# at at
# None
# full full
# None
# power power
# "power"
#
# None
# ambient ambient
# "ambient"
# was was
# None
#
# None
#
# None
# c c
# None
#
# None
# and and
# None
# there there
# None
# was was
# None
# a a
# None
# brief brief
# None
# increase increase
# "increase"
# in in
# None
# wind wind
# "wind"
# speed speed
# "speed"
# up up
# None
# to to
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# since since
# None
# then then
# None
#
# None
# temperatures temperatures
# None
# are are
# None
# not not
# None
# modulating modulating
# None
# as as
# None
# well well
# None
# as as
# None
# they they
# None
# have have
# None
# in in
# None
# the the
# None
# past past
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appeared appeared
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
# on on
# None
# july july
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# appears appears
# None
# to to
# None
# have have
# None
# since since
# None
# july july
# None
#
# None
#
# None
# with with
# None
# at at
# None
# least least
# None
# one one
# None
# brief brief
# None
# instance instance
# None
# of of
# None
# power power
# "power"
#
# None
#
# None
#
# None
# kw kw
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# turbine turbine
# "turbine"
# no no
# None
# longer longer
# None
# curtailed curtailed
# "curtailed"
#
# None
# closing closing
# "close"
# case case
# None
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
#
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appears appears
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# cleared cleared
# "cleared"
# on on
# None
# sep sep
# None
#
# None
#
# None
# th th
# "th"
#
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperatures temperatures
# None
# were were
# None
# elevated elevated
# "elevated"
# as as
# None
# high high
# None
# as as
# None
#
# None
# c c
# None
# for for
# None
# hs hs
# "hs"
# rot rot
# "rot"
#
# None
#
# None
# c c
# None
# for for
# None
# ims ims
# "ims"
# gen gen
# "generator"
#
# None
# and and
# None
#
# None
# c c
# None
# for for
# None
# ims ims
# "ims"
# rot rot
# "rot"
#
# None
# at at
# None
# the the
# None
# same same
# None
# time time
# None
# as as
# None
# the the
# None
# gear gear
# "gear"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# deviations deviations
# "deviate"
#
# None
# the the
# None
# ambient ambient
# "ambient"
# temperature temperature
# "temperature"
# sensor sensor
# "sensor"
# for for
# None
# the the
# None
# turbine turbine
# "turbine"
# flatlined flatlined
# "flatline"
# at at
# None
#
# None
#
# None
# c c
# None
#
# None
# no no
# None
# other other
# None
# issues issues
# "issue"
# are are
# None
# noted noted
# None
# in in
# None
# the the
# None
# model model
# "model"
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# weekly weekly
# None
# report report
# None
#
# None
# all all
# None
# trends trends
# None
# have have
# None
# returned returned
# None
# to to
# None
# their their
# None
# models models
# "model"
# starting starting
# None
# sep sep
# None
#
# None
#
# None
#
# None
#
# None
# did did
# None
# the the
# None
# site site
# None
# perform perform
# None
# any any
# None
# maintenance maintenance
# None
# to to
# None
# resolve resolve
# "resolve"
# the the
# None
# issue issue
# "issue"
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# appeared appeared
# None
# to to
# None
# be be
# None
# curtailed curtailed
# "curtailed"
# at at
# None
#
# None
#
# None
#
# None
# kw kw
# None
# with with
# None
# wind wind
# "wind"
# speed speed
# "speed"
# between between
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# m m
# None
# s s
# None
# on on
# None
# july july
# None
#
# None
#
# None
#
# None
# curtailment curtailment
# "curtailed"
# appears appears
# None
# to to
# None
# have have
# None
# since since
# None
# july july
# None
#
# None
#
# None
# with with
# None
# a a
# None
# few few
# None
# brief brief
# None
# instances instances
# "instances"
# of of
# None
# power power
# "power"
#
# None
#
# None
#
# None
# kw kw
# None
# wind wind
# "wind"
# turbine turbine
# "turbine"
#
# None
#
# None
# is is
# None
# indicating indicating
# None
# a a
# None
# code code
# None
#
# None
#
# None
# on on
# None
# the the
# None
# wt wt
# None
# operating operating
# None
# state state
# None
# tag tag
# "tag"
#
# None
# is is
# None
# this this
# None
# turbine turbine
# "turbine"
# down down
# None
# for for
# None
# maintenance maintenance
# None
#
# None
# or or
# None
# is is
# None
# this this
# None
# due due
# None
# to to
# None
# an an
# None
# error error
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# generator generator
# "generator"
# de de
# "de"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# began began
# None
# to to
# None
# exceed exceed
# None
# residual residual
# "residual"
# thresholds thresholds
# "threshold"
#
# None
# and and
# None
# a a
# None
# high high
# None
# temperature temperature
# ...
# None
#
# None
#
# None
#
# None
# condition condition
# "condition"
# persists persists
# "persist"
#
# None
#
# None
# july july
# None
#
# None
#
# None
#
# None
# vibrations vibrations
# "vibration"
# have have
# None
# dropped dropped
# "dropped"
# to to
# None
# acceptable acceptable
# None
# levels levels
# None
#
# None
#
# None
#
# None
# july july
# None
#
# None
#
# None
#
# None
#
# None
# flow flow
# "flow"
# and and
# None
# pressure pressure
# "pressure"
# do do
# None
# not not
# None
# seem seem
# None
# to to
# None
# be be
# None
# correlating correlating
# None
# with with
# None
# the the
# None
# changes changes
# None
# in in
# None
# vibration vibration
# "vibration"
#
# None
#
# None
# currently currently
# None
# trending trending
# "trend"
# at at
# None
#
# None
#
# None
# um um
# None
#
# None
#
# None
#
# None
#
# None
# august august
# None
#
# None
#
# None
#
# None
# vibrations vibrations
# "vibration"
# are are
# None
# trending trending
# "trend"
# below below
# None
#
# None
# um um
# None
#
# None
#
# None
#
# None
#
# None
# august august
# None
#
# None
#
# None
#
# None
# conditions conditions
# "condition"
# are are
# None
# stable stable
# None
# during during
# None
# startup startup
# "startup"
# and and
# None
# shutdown shutdown
# None
#
# None
# dv dv
# None
# proficy proficy
# None
# hr hr
# None
#
# None
# hpshtstmte hpshtstmte
# None
# b b
# None
#
# None
#
# None
# hr hr
# None
#
# None
# hp hp
# "hp"
# sh sh
# "sh"
# dsh dsh
# "dsh"
# outlet outlet
# "outlet"
# temperature temperature
# "temperature"
# will will
# None
# read read
# "read"
# erratically erratically
# "erratic"
# low low
# "low"
#
# None
# before before
# None
# coming coming
# None
# up up
# None
# to to
# None
# the the
# None
# estimate estimate
# "estimate"
# at at
# None
# higher higher
# None
# loads loads
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# erratic erratic
# "erratic"
# conditions conditions
# "condition"
# appear appear
# None
# to to
# None
# have have
# None
# ceased ceased
# None
# since since
# None
# beginning beginning
# None
# of of
# None
# july july
# None
#
# None
# update update
# None
#
# None
# erratic erratic
# "erratic"
# condition condition
# "condition"
# corrected corrected
# None
#
# None
# fluid fluid
# "fluid"
# coupling coupling
# "coupling"
# casing casing
# "casing"
# vibration vibration
# "vibration"
# has has
# None
# been been
# None
# erratic erratic
# "erratic"
#
# None
# after after
# None
# resuming resuming
# None
#
# None
# x x
# None
#
# None
# operation operation
# None
#
# None
# duct duct
# "duct"
# burner burner
# "burner"
# fuel fuel
# "fuel"
# pressure pressure
# "pressure"
# will will
# None
# remain remain
# None
# low low
# "low"
#
# None
# spike spike
# "spike"
# high high
# None
# to to
# None
#
# None
#
# None
# psig psig
# None
#
# None
# then then
# None
# return return
# None
# to to
# None
# the the
# None
# model model
# "model"
# after after
# None
# about about
# None
#
# None
#
# None
# hours hours
# None
#
# None
# duct duct
# "duct"
# temperature temperature
# "temperature"
# tracks tracks
# "track"
# throughout throughout
# "throughout"
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# duct duct
# "duct"
# burner burner
# "burner"
# fuel fuel
# "fuel"
# pressure pressure
# "pressure"
# now now
# None
# appears appears
# None
# to to
# None
# be be
# None
# reading reading
# "read"
# correctly correctly
# "correct"
# ( (
# None
# psig) psig)
# None
# when when
# None
# unit unit
# "unit"
# is is
# None
# offline offline
# None
#
# None
# if if
# None
# readings readings
# "read"
# while while
# None
# unit unit
# "unit"
# is is
# None
# running running
# None
# are are
# None
# also also
# None
# acceptable acceptable
# None
#
# None
# the the
# None
# model model
# "model"
# can can
# None
# be be
# None
# updated updated
# None
#
# None
# update update
# None
#
# None
# lube lube
# "lube"
# oil oil
# "oil"
# filter filter
# "filter"
# changed changed
# None
#
# None
#
# None
# lube lube
# "lube"
# oil oil
# "oil"
# filter filter
# "filter"
# has has
# None
# been been
# None
# gradually gradually
# "gradual"
# increasing increasing
# "increase"
# from from
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# thrust thrust
# "thrust"
# bearing bearing
# "bearing"
# temp temp
# "temperature"
# took took
# None
# a a
# None
# step step
# "step"
# change change
# None
# down down
# None
# from from
# None
#
# None
#
# None
#
# None
# degc degc
# None
# to to
# None
#
# None
#
# None
#
# None
# degc degc
# None
# with with
# None
# model model
# "model"
# prediction prediction
# "predicted"
# at at
# None
#
# None
#
# None
#
# None
# degc degc
# None
#
# None
# atreduced atreduced
# None
# loads loads
# None
# ip ip
# "ip"
# attemperator attemperator
# "attemperator"
# spray spray
# "spray"
# valve valve
# "valve"
# and and
# None
# spray spray
# "spray"
# flow flow
# "flow"
# are are
# None
# higher higher
# None
# than than
# None
# expected expected
# None
# with with
# None
# ip ip
# "ip"
# rh rh
# "rh"
# dsh dsh
# "dsh"
# outlet outlet
# "outlet"
# temperature temperature
# "temperature"
# decreasing decreasing
# "decrease"
# to to
# None
#
# None
#
# None
# f f
# None
# with with
# None
# an an
# None
# estimate estimate
# "estimate"
# of of
# None
#
# None
#
# None
# f f
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# ip ip
# "ip"
# rh rh
# "rh"
# dsh dsh
# "dsh"
# outlet outlet
# "outlet"
# temperatureis temperatureis
# None
# back back
# None
# totracking totracking
# None
# at at
# None
#
# None
#
# None
#
# None
#
# None
# f f
# None
# of of
# None
# late late
# "late"
#
# None
# if if
# None
# current current
# "current"
# conditions conditions
# "condition"
# are are
# None
# acceptable acceptable
# None
#
# None
# they they
# None
# can can
# None
# be be
# None
# added added
# None
# to to
# None
# the the
# None
# model model
# "model"
# to to
# None
# improve improve
# None
# tracking tracking
# "track"
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# suction suction
# "suction"
# pressure pressure
# "pressure"
# took took
# None
# a a
# None
# step step
# "step"
# change change
# None
# down down
# None
# from from
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# with with
# None
# model model
# "model"
# prediction prediction
# "predicted"
# at at
# None
#
# None
#
# None
#
# None
# barg barg
# None
#
# None
# hr hr
# None
#
# None
# gpstkte gpstkte
# None
#
# None
#
# None
# a a
# None
#
# None
# b b
# None
#
# None
# and and
# None
# c c
# None
# are are
# None
# showing showing
# None
# increased increased
# None
# spread spread
# "spread"
#
# None
# hr hr
# None
#
# None
# gpstkte gpstkte
# None
# a a
# None
# is is
# None
# currently currently
# None
# the the
# None
# lowest lowest
# None
#
# None
# reading reading
# "read"
#
# None
#
# None
# f f
# None
#
# None
# with with
# None
# hr hr
# None
#
# None
# gpstkte gpstkte
# None
# b b
# None
# reading reading
# "read"
#
# None
#
# None
# f f
# None
#
# None
# in in
# None
# october october
# None
#
# None
# all all
# None
# four four
# None
# indications indications
# None
# were were
# None
# reading reading
# "read"
# within within
# None
#
# None
#
# None
# f f
# None
# of of
# None
# each each
# None
# at at
# None
#
# None
#
# None
# f f
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# conditions conditions
# "condition"
# persist persist
# "persist"
#
# None
# condition condition
# "condition"
# continues continues
# "continues"
# following following
# None
# data data
# "data"
# return return
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
# the the
# None
# lube lube
# "lube"
# oil oil
# "oil"
# dp dp
# "dp"
# has has
# None
# been been
# None
# flatlined flatlined
# "flatline"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# hr hr
# None
#
# None
# lpdrmstmte lpdrmstmte
# None
#
# None
#
# None
#
# None
# hr hr
# None
#
# None
# lp lp
# "lp"
# drum drum
# "drum"
# outlet outlet
# "outlet"
# temperature temperature
# "temperature"
# increased increased
# None
# from from
# None
#
# None
#
# None
# f f
# None
# to to
# None
#
# None
#
# None
# f f
# None
#
# None
# the the
# None
# a a
# None
# and and
# None
# b b
# None
# sensors sensors
# "sensor"
# continued continued
# None
# to to
# None
# track track
# "track"
# as as
# None
# expected expected
# None
# at at
# None
#
# None
#
# None
# f f
# None
#
# None
# lube lube
# "lube"
# oil oil
# "oil"
# filter filter
# "filter"
# has has
# None
# been been
# None
# slowly slowly
# "slowly"
# increasing increasing
# "increase"
# from from
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# pump pump
# "pump"
# discharge discharge
# "discharge"
# decreased decreased
# "decrease"
# down down
# None
# to to
# None
#
# None
#
# None
#
# None
# with with
# None
# model model
# "model"
# prediction prediction
# "predicted"
# at at
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# multiple multiple
# None
# tags tags
# "tag"
# affected affected
# None
#
# None
# before before
# None
# shutdown shutdown
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# hp hp
# "hp"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# (tag (tag
# None
# t t
# None
# b) b)
# None
# began began
# None
# reading reading
# "read"
# elevated elevated
# "elevated"
# from from
# None
# model model
# "model"
# estimates estimates
# "estimate"
# and and
# None
# drifting drifting
# None
# higher higher
# None
# than than
# None
# the the
# None
# other other
# None
# two two
# None
# drum drum
# "drum"
# level level
# None
# indications indications
# None
#
# None
# now now
# None
# reading reading
# "read"
# about about
# None
#
# None
#
# None
# inch inch
# None
# differential differential
# "differential"
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# the the
# None
# issue issue
# "issue"
# has has
# None
# persisted persisted
# "persist"
# on on
# None
# the the
# None
# most most
# None
# recent recent
# None
# run run
# "run"
# as as
# None
# well well
# None
#
# None
# after after
# None
# startup startup
# "startup"
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# lube lube
# "lube"
# oil oil
# "oil"
# filter filter
# "filter"
# increased increased
# None
# up up
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# barg barg
# None
# then then
# None
# dropped dropped
# "dropped"
# to to
# None
#
# None
#
# None
#
# None
#
# None
# discharge discharge
# "discharge"
# pressure pressure
# "pressure"
# has has
# None
# increased increased
# None
# above above
# None
# model model
# "model"
# predictions predictions
# "predicted"
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# st st
# "st"
# load load
# "load"
# is is
# None
# around around
# None
#
# None
#
# None
# mw mw
# None
#
# None
# gt gt
# "gt"
# load load
# "load"
# is is
# None
# at at
# None
#
# None
#
# None
# mw mw
# None
#
# None
# the the
# None
# unit unit
# "unit"
# is is
# None
# running running
# None
#
# None
# x x
# None
#
# None
#
# None
# the the
# None
# ip ip
# "ip"
# rh rh
# "rh"
# dsh dsh
# "dsh"
# temp temp
# "temperature"
# control control
# "control"
# valve valve
# "valve"
# was was
# None
# wide wide
# None
# open open
# None
# for for
# None
# the the
# None
# most most
# None
# recent recent
# None
# run run
# "run"
#
# None
# there there
# None
# are are
# None
# no no
# None
# duct duct
# "duct"
# burners burners
# None
# running running
# None
# at at
# None
# this this
# None
# time time
# None
#
# None
# fluid fluid
# "fluid"
# coupling coupling
# "coupling"
# journal journal
# "journal"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# above above
# None
# model model
# "model"
# predictionsl predictionsl
# None
#
# None
# fluid fluid
# "fluid"
# coupling coupling
# "coupling"
# oil oil
# "oil"
# resevoir resevoir
# None
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# above above
# None
# model model
# "model"
# predictions predictions
# "predicted"
# as as
# None
# well well
# None
#
# None
# this this
# None
# is is
# None
# the the
# None
# only only
# None
# bearing bearing
# "bearing"
# increasing increasing
# "increase"
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# (hr (hr
# None
#
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
# ) )
# None
# was was
# None
# reading reading
# "read"
# around around
# None
#
# None
#
# None
# inches inches
# None
# on on
# None
# the the
# None
# last last
# None
# run run
# "run"
# on on
# None
#
# None
#
# None
#
# None
#
# None
# when when
# None
# the the
# None
# model model
# "model"
# was was
# None
# expecting expecting
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# inches inches
# None
#
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# is is
# None
# reading reading
# "read"
#
# None
#
# None
#
# None
#
# None
#
# None
# inches inches
# None
# and and
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# is is
# None
# reading reading
# "read"
#
# None
#
# None
#
# None
#
# None
#
# None
# inches inches
# None
#
# None
# motor motor
# "motor"
# winding winding
# "wind"
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# pump pump
# "pump"
# drive drive
# "drive"
# end end
# None
# journal journal
# "journal"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
# and and
# None
# there there
# None
# also also
# None
# has has
# None
# been been
# None
# an an
# None
# axial axial
# "axial"
# position position
# "position"
# change change
# None
# in in
# None
# this this
# None
# time time
# None
# frame frame
# None
#
# None
# hp hp
# "hp"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# (hr (hr
# None
#
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
# ) )
# None
# is is
# None
# reading reading
# "read"
# up up
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# inches inches
# None
# starting starting
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# while while
# None
# the the
# None
# model model
# "model"
# has has
# None
# been been
# None
# expecting expecting
# None
# expecting expecting
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# inches inches
# None
#
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# is is
# None
# reading reading
# "read"
#
# None
#
# None
#
# None
# inches inches
# None
# and and
# None
# ip ip
# "ip"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# is is
# None
# reading reading
# "read"
#
# None
#
# None
#
# None
# inches inches
# None
#
# None
# mischarge mischarge
# None
# pressure pressure
# "pressure"
# has has
# None
# increased increased
# None
# above above
# None
# model model
# "model"
# predictions predictions
# "predicted"
# since since
# None
#
# None
#
# None
#
# None
#
# None
# and and
# None
# remains remains
# None
# elevated elevated
# "elevated"
#
# None
# on on
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# hp hp
# "hp"
# sh sh
# "sh"
# dsh dsh
# "dsh"
# spray spray
# "spray"
# flow flow
# "flow"
# is is
# None
# up up
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# lbm lbm
# None
# hr hr
# None
# and and
# None
# the the
# None
# hp hp
# "hp"
# sh sh
# "sh"
# dsh dsh
# "dsh"
# outlet outlet
# "outlet"
# temperature temperature
# "temperature"
# went went
# None
# down down
# None
# to to
# None
# as as
# None
# low low
# "low"
# as as
# None
#
# None
#
# None
# deg deg
# None
# f f
# None
# when when
# None
# the the
# None
# model model
# "model"
# was was
# None
# estimating estimating
# None
#
# None
#
# None
# deg deg
# None
# f f
# None
#
# None
# the the
# None
# lube lube
# "lube"
# oil oil
# "oil"
# filters filters
# "filter"
# have have
# None
# increased increased
# None
# from from
# None
#
# None
#
# None
#
# None
#
# None
# bar bar
# None
# to to
# None
#
# None
#
# None
#
# None
#
# None
# bar bar
# None
# since since
# None
#
# None
#
# None
#
# None
#
# None
# started started
# None
# and and
# None
# continue continue
# None
# to to
# None
# rise rise
# None
#
# None
# lube lube
# "lube"
# oil oil
# "oil"
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# above above
# None
# model model
# "model"
# predictions predictions
# "predicted"
#
# None
# nde nde
# "nde"
# thrust thrust
# "thrust"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# has has
# None
# also also
# None
# increased increased
# None
# over over
# None
# the the
# None
# same same
# None
# time time
# None
# period period
# None
#
# None
#
# None
# coupling coupling
# "coupling"
# bearing bearing
# "bearing"
# temperature temperature
# "temperature"
# have have
# None
# increased increased
# None
# over over
# None
# the the
# None
# past past
# None
#
# None
#
# None
# hours hours
# None
# and and
# None
# remain remain
# None
# above above
# None
# model model
# "model"
# predictions predictions
# "predicted"
#
# None
# in in
# None
# the the
# None
# last last
# None
# week week
# None
# the the
# None
# hr hr
# None
#
# None
# hp hp
# "hp"
# drum drum
# "drum"
# level level
# None
# b b
# None
# has has
# None
# been been
# None
# flat flat
# "flat"
# lined lined
# "lined"
# at at
# None
#
# None
#
# None
#
# None
#
# None
# in in
# None
#
# None
#
# None
# update update
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
# hp hp
# "hp"
# drum drum
# "drum"
# level level
# None
#
# None
#
# None
# has has
# None
# dropped dropped
# "dropped"
# to to
# None
# predicted predicted
# "predicted"
# values values
# "values"
#
# None
# but but
# None
# hp hp
# "hp"
# drum drum
# "drum"
# level level
# None
# has has
# None
# flatlined flatlined
# "flatline"
# at at
# None
#
# None
#
# None
#
# None
# in in
# None
# condition condition
# "condition"
# cleared cleared
# "cleared"
# after after
# None
# restart restart
# "restart"
# seal seal
# "seal"
# loop loop
# "loop"
# temperature temperature
# "temperature"
# has has
# None
# increased increased
# None
# tracking tracking
# "track"
# with with
# None
# axial axial
# "axial"
# position position
# "position"
# 500
# 'beginning aug wind turbine appears curtailed at kw with wind speed between m s '

# %%
print(len(arrUnigramFiltered))
arrUnigramFiltered[301]
# Out:
# 500
# 'beginning august the bc inlet steam temperature (bti ) is trend at degf compared to a model predicted of degf the inlet steam pressure is trend near model predicted at psig exhaust steam temperature pressure are trend with model '

# %% [markdown]
# Now we will check for the presence of the trigrams. The strings are already normalized to unigrams

# %%
arrTrigramFiltered=[]
#for case in cases[startCaseNumber:endCaseNumber]:
for count in range(startCaseNumber,endCaseNumber):
    print(count)
    details =arrUnigramFiltered[count]
    arrTempTerms = details.split(" ")
    lenCase = len(arrTempTerms)
    str=details;
    for i in range(lenCase):
        largestStringFound=''
        firstword=''
        secondword=''
        thirdword=''
        firstword=arrTempTerms[i].lower()
        if (i <= (lenCase-3)):
            secondword=arrTempTerms[i+1].lower()
            thirdword=arrTempTerms[i+2].lower()

        if (firstword == " " or secondword == " " or thirdword == " "):
            break;
        tempword = firstword+" "+secondword+" "+thirdword
        #tempword=tempword.strim()
        print("tempword=>",tempword)

        retword=getNormalizedWord(tempword,ngramDict)
        if (retword):
            print("normalized",retWord)
            str = str.replace(tempword, retword)

    arrTrigramFiltered.append(str)
# Out:
# 0
# tempword=> tagido ons cba
# tempword=> ons cba bj
# tempword=> cba bj xq
# tempword=> bj xq m
# tempword=> xq m act
# tempword=> m act pw
# tempword=> act pw appears
# tempword=> pw appears to
# tempword=> appears to be
# tempword=> to be flatline
# tempword=> be flatline at
# tempword=> flatline at update
# tempword=> at update flatline
# tempword=> update flatline cleared
# tempword=> flatline cleared close
# tempword=> cleared close case
# tempword=> close case
# tempword=> case
# tempword=>
# 1
# tempword=> it appears while
# tempword=> appears while the
# tempword=> while the turbine
# tempword=> the turbine is
# tempword=> turbine is active
# tempword=> is active power
# tempword=> active power is
# tempword=> power is moving
# tempword=> is moving around
# tempword=> moving around the
# tempword=> around the wind
# tempword=> the wind speed
# tempword=> wind speed sensor
# tempword=> speed sensor is
# tempword=> sensor is returning
# tempword=> is returning a
# tempword=> returning a flatline
# tempword=> a flatline value
# tempword=> flatline value update
# tempword=> value update appears
# tempword=> update appears the
# tempword=> appears the anemometer
# tempword=> the anemometer issue
# tempword=> anemometer issue have
# tempword=> issue have been
# tempword=> have been resolved
# tempword=> been resolved as
# tempword=> resolved as of
# tempword=> as of at
# tempword=> of at am
# tempword=> at am
# tempword=> am
# tempword=>
# 2
# tempword=> since the following
# tempword=> the following tag
# tempword=> following tag are
# tempword=> tag are indicating
# tempword=> are indicating intermittent
# tempword=> indicating intermittent flatline
# tempword=> intermittent flatline ido
# tempword=> flatline ido wtg
# tempword=> ido wtg mdk
# tempword=> wtg mdk bt
# tempword=> mdk bt xq
# tempword=> bt xq m
# tempword=> xq m hsrot
# tempword=> m hsrot temperature
# tempword=> hsrot temperature ido
# tempword=> temperature ido wtg
# tempword=> ido wtg mdk
# tempword=> wtg mdk bt
# tempword=> mdk bt xq
# tempword=> bt xq m
# tempword=> xq m imsgen
# tempword=> m imsgen temperature
# tempword=> imsgen temperature and
# tempword=> temperature and ido
# tempword=> and ido wtg
# tempword=> ido wtg mdk
# tempword=> wtg mdk bt
# tempword=> mdk bt xq
# tempword=> bt xq m
# tempword=> xq m imsrot
# tempword=> m imsrot temperature
# tempword=> imsrot temperature actual
# tempword=> temperature actual temperatures
# tempword=> actual temperatures are
# tempword=> temperatures are acceptable
# tempword=> are acceptable when
# tempword=> acceptable when tag
# tempword=> when tag are
# tempword=> tag are not
# tempword=> are not flatline
# tempword=> not flatline (
# tempword=> flatline ( degc)
# tempword=> ( degc) update
# tempword=> degc) update flatline
# tempword=> update flatline cleared
# tempword=> flatline cleared close
# tempword=> cleared close case
# tempword=> close case
# tempword=> case
# tempword=>
# 3
# tempword=> beginning aug wind
# tempword=> aug wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears curtailed
# tempword=> appears curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 4
# tempword=> during higher wind
# tempword=> higher wind condition
# tempword=> wind condition the
# tempword=> condition the turbine
# tempword=> the turbine is
# tempword=> turbine is currently
# tempword=> is currently limited
# tempword=> currently limited to
# tempword=> limited to mw
# tempword=> to mw
# tempword=> mw
# tempword=>
# 5
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed since
# tempword=> curtailed since currently
# tempword=> since currently active
# tempword=> currently active power
# tempword=> active power is
# tempword=> power is kw
# tempword=> is kw curtailed
# tempword=> kw curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 6
# tempword=> on generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature remained
# tempword=> temperature remained above
# tempword=> remained above the
# tempword=> above the model
# tempword=> the model estimate
# tempword=> model estimate for
# tempword=> estimate for hours
# tempword=> for hours the
# tempword=> hours the maximum
# tempword=> the maximum temperature
# tempword=> maximum temperature observed
# tempword=> temperature observed was
# tempword=> observed was degc
# tempword=> was degc with
# tempword=> degc with a
# tempword=> with a model
# tempword=> a model estimate
# tempword=> model estimate of
# tempword=> estimate of degc
# tempword=> of degc update
# tempword=> degc update the
# tempword=> update the condition
# tempword=> the condition persist
# tempword=> condition persist with
# tempword=> persist with a
# tempword=> with a high
# tempword=> a high temperature
# tempword=> high temperature of
# tempword=> temperature of c
# tempword=> of c observed
# tempword=> c observed on
# tempword=> observed on
# tempword=> on
# tempword=>
# 7
# tempword=> within the past
# tempword=> the past week
# tempword=> past week de
# tempword=> week de bearing
# tempword=> de bearing temperatures
# tempword=> bearing temperatures have
# tempword=> temperatures have been
# tempword=> have been track
# tempword=> been track c
# tempword=> track c above
# tempword=> c above the
# tempword=> above the model
# tempword=> the model as
# tempword=> model as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c no
# tempword=> c no other
# tempword=> no other deviate
# tempword=> other deviate are
# tempword=> deviate are noted
# tempword=> are noted in
# tempword=> noted in the
# tempword=> in the model
# tempword=> the model
# tempword=> model
# tempword=>
# 8
# tempword=> within the past
# tempword=> the past week
# tempword=> past week generator
# tempword=> week generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature de
# normalized position
# tempword=> temperature de has
# tempword=> de has exceeded
# tempword=> has exceeded the
# tempword=> exceeded the model
# tempword=> the model estimate
# tempword=> model estimate with
# tempword=> estimate with a
# tempword=> with a recent
# tempword=> a recent increase
# tempword=> recent increase as
# tempword=> increase as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c with
# tempword=> c with an
# tempword=> with an estimate
# tempword=> an estimate of
# tempword=> estimate of c
# tempword=> of c the
# tempword=> c the turbine
# tempword=> the turbine was
# tempword=> turbine was running
# tempword=> was running at
# tempword=> running at lower
# tempword=> at lower power
# tempword=> lower power when
# tempword=> power when most
# tempword=> when most of
# tempword=> most of the
# tempword=> of the increase
# tempword=> the increase occurred
# tempword=> increase occurred at
# tempword=> occurred at kw
# tempword=> at kw and
# tempword=> kw and generator
# tempword=> and generator speed
# tempword=> generator speed was
# tempword=> speed was rpm
# tempword=> was rpm ambient
# tempword=> rpm ambient temperature
# tempword=> ambient temperature was
# tempword=> temperature was c
# tempword=> was c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time
# tempword=> time
# tempword=>
# 9
# tempword=> while the unit
# tempword=> the unit is
# tempword=> unit is operating
# tempword=> is operating at
# tempword=> operating at decrease
# tempword=> at decrease power
# tempword=> decrease power kw
# tempword=> power kw generator
# tempword=> kw generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature de
# normalized position
# tempword=> temperature de has
# tempword=> de has been
# tempword=> has been elevated
# tempword=> been elevated running
# tempword=> elevated running as
# tempword=> running as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c ambient
# tempword=> c ambient is
# tempword=> ambient is c
# tempword=> is c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time other
# tempword=> time other wind
# tempword=> other wind turbine
# tempword=> wind turbine during
# tempword=> turbine during the
# tempword=> during the same
# tempword=> the same timeframe
# tempword=> same timeframe are
# tempword=> timeframe are operating
# tempword=> are operating with
# tempword=> operating with de
# tempword=> with de temperatures
# tempword=> de temperatures c
# tempword=> temperatures c with
# tempword=> c with similar
# tempword=> with similar active
# tempword=> similar active power
# tempword=> active power
# tempword=> power
# tempword=>
# 10
# tempword=> we are currently
# tempword=> are currently seeing
# tempword=> currently seeing the
# tempword=> seeing the active
# tempword=> the active power
# tempword=> active power tag
# tempword=> power tag for
# tempword=> tag for turbine
# tempword=> for turbine at
# tempword=> turbine at mw
# tempword=> at mw with
# tempword=> mw with wind
# tempword=> with wind speed
# tempword=> wind speed from
# tempword=> speed from to
# tempword=> from to m
# tempword=> to m s
# tempword=> m s
# tempword=> s
# tempword=>
# 11
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s note
# tempword=> s note the
# tempword=> note the wps
# tempword=> the wps status
# tempword=> wps status tag
# tempword=> status tag is
# tempword=> tag is returning
# tempword=> is returning a
# tempword=> returning a while
# tempword=> a while the
# tempword=> while the wt
# tempword=> the wt operating
# tempword=> wt operating state
# tempword=> operating state is
# tempword=> state is returning
# tempword=> is returning update
# tempword=> returning update curtailed
# tempword=> update curtailed cleared
# tempword=> curtailed cleared close
# tempword=> cleared close case
# tempword=> close case
# tempword=> case
# tempword=>
# 12
# tempword=> within the past
# tempword=> the past weeks
# tempword=> past weeks wtg
# tempword=> weeks wtg has
# tempword=> wtg has been
# tempword=> has been exhibited
# tempword=> been exhibited increased
# tempword=> exhibited increased nde
# tempword=> increased nde bearing
# tempword=> nde bearing temperatures
# tempword=> bearing temperatures that
# tempword=> temperatures that have
# tempword=> that have spike
# tempword=> have spike c
# tempword=> spike c above
# tempword=> c above the
# tempword=> above the model
# tempword=> the model on
# tempword=> model on nde
# tempword=> on nde bearing
# tempword=> nde bearing temperature
# normalized position
# tempword=> bearing temperature was
# tempword=> temperature was c
# tempword=> was c with
# tempword=> c with a
# tempword=> with a model
# tempword=> a model estimate
# tempword=> model estimate of
# tempword=> estimate of c
# tempword=> of c this
# tempword=> c this has
# tempword=> this has created
# tempword=> has created an
# tempword=> created an increased
# tempword=> an increased nde
# tempword=> increased nde bearing
# tempword=> nde bearing temperature
# normalized position
# tempword=> bearing temperature spread
# tempword=> temperature spread of
# tempword=> spread of c
# tempword=> of c between
# tempword=> c between the
# tempword=> between the wind
# tempword=> the wind turbine
# tempword=> wind turbine no
# tempword=> turbine no other
# tempword=> no other adverse
# tempword=> other adverse bearing
# tempword=> adverse bearing trends
# tempword=> bearing trends were
# tempword=> trends were noted
# tempword=> were noted update
# tempword=> noted update within
# tempword=> update within the
# tempword=> within the past
# tempword=> the past week
# tempword=> past week generator
# tempword=> week generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature de
# normalized position
# tempword=> temperature de has
# tempword=> de has been
# tempword=> has been increased
# tempword=> been increased as
# tempword=> increased as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c with
# tempword=> c with an
# tempword=> with an estimate
# tempword=> an estimate of
# tempword=> estimate of c
# tempword=> of c temperatures
# tempword=> c temperatures remained
# tempword=> temperatures remained above
# tempword=> remained above the
# tempword=> above the model
# tempword=> the model for
# tempword=> model for hrs
# tempword=> for hrs before
# tempword=> hrs before returning
# tempword=> before returning to
# tempword=> returning to the
# tempword=> to the model
# tempword=> the model
# tempword=> model
# tempword=>
# 13
# tempword=> since oct nde
# tempword=> oct nde bearing
# tempword=> nde bearing temperatures
# tempword=> bearing temperatures have
# tempword=> temperatures have been
# tempword=> have been track
# tempword=> been track c
# tempword=> track c above
# tempword=> c above the
# tempword=> above the model
# tempword=> the model as
# tempword=> model as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c no
# tempword=> c no other
# tempword=> no other deviate
# tempword=> other deviate are
# tempword=> deviate are noted
# tempword=> are noted in
# tempword=> noted in the
# tempword=> in the model
# tempword=> the model
# tempword=> model
# tempword=>
# 14
# tempword=> beginning may wind
# tempword=> may wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears curtailed
# tempword=> appears curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 15
# tempword=> on may turbine
# tempword=> may turbine appeared
# tempword=> turbine appeared to
# tempword=> appeared to return
# tempword=> to return from
# tempword=> return from curtailed
# tempword=> from curtailed to
# tempword=> curtailed to full
# tempword=> to full power
# tempword=> full power but
# tempword=> power but appears
# tempword=> but appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed again
# tempword=> curtailed again at
# tempword=> again at kw
# tempword=> at kw beginning
# tempword=> kw beginning may
# tempword=> beginning may with
# tempword=> may with wind
# tempword=> with wind speed
# tempword=> wind speed m
# tempword=> speed m s
# tempword=> m s
# tempword=> s
# tempword=>
# 16
# tempword=> while the unit
# tempword=> the unit is
# tempword=> unit is operating
# tempword=> is operating at
# tempword=> operating at decrease
# tempword=> at decrease power
# tempword=> decrease power kw
# tempword=> power kw generator
# tempword=> kw generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature nde
# normalized position
# tempword=> temperature nde increased
# tempword=> nde increased to
# tempword=> increased to as
# tempword=> to as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c before
# tempword=> c before returning
# tempword=> before returning to
# tempword=> returning to the
# tempword=> to the model
# tempword=> the model when
# tempword=> model when the
# tempword=> when the unit
# tempword=> the unit increased
# tempword=> unit increased in
# tempword=> increased in power
# tempword=> in power ambient
# tempword=> power ambient was
# tempword=> ambient was c
# tempword=> was c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time
# tempword=> time
# tempword=>
# 17
# tempword=> nde bearing temperatures
# tempword=> bearing temperatures are
# tempword=> temperatures are showing
# tempword=> are showing an
# tempword=> showing an increased
# tempword=> an increased frequency
# tempword=> increased frequency of
# tempword=> frequency of high
# tempword=> of high temperature
# tempword=> high temperature spike
# tempword=> temperature spike within
# tempword=> spike within the
# tempword=> within the past
# tempword=> the past week
# tempword=> past week temperatures
# tempword=> week temperatures have
# tempword=> temperatures have increased
# tempword=> have increased to
# tempword=> increased to as
# tempword=> to as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c de
# tempword=> c de temperatures
# tempword=> de temperatures are
# tempword=> temperatures are track
# tempword=> are track the
# tempword=> track the model
# tempword=> the model update
# tempword=> model update geip
# tempword=> update geip to
# tempword=> geip to continue
# tempword=> to continue monitor
# tempword=> continue monitor close
# tempword=> monitor close case
# tempword=> close case
# tempword=> case
# tempword=>
# 18
# tempword=> on jan gear
# tempword=> jan gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures increased
# tempword=> temperatures increased to
# tempword=> increased to c
# tempword=> to c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims generator
# tempword=> ims generator c
# tempword=> generator c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims rot
# tempword=> ims rot and
# tempword=> rot and c
# tempword=> and c on
# tempword=> c on tag
# tempword=> on tag hs
# tempword=> tag hs rot
# tempword=> hs rot the
# tempword=> rot the turbine
# tempword=> the turbine was
# tempword=> turbine was running
# tempword=> was running at
# tempword=> running at full
# tempword=> at full power
# tempword=> full power ambient
# tempword=> power ambient was
# tempword=> ambient was c
# tempword=> was c and
# tempword=> c and there
# tempword=> and there was
# tempword=> there was a
# tempword=> was a brief
# tempword=> a brief increase
# tempword=> brief increase in
# tempword=> increase in wind
# tempword=> in wind speed
# tempword=> wind speed up
# tempword=> speed up to
# tempword=> up to m
# tempword=> to m s
# tempword=> m s since
# tempword=> s since then
# tempword=> since then temperatures
# tempword=> then temperatures are
# tempword=> temperatures are not
# tempword=> are not modulating
# tempword=> not modulating as
# tempword=> modulating as well
# tempword=> as well as
# tempword=> well as they
# tempword=> as they have
# tempword=> they have in
# tempword=> have in the
# tempword=> in the past
# tempword=> the past weekly
# tempword=> past weekly report
# tempword=> weekly report since
# tempword=> report since mar
# tempword=> since mar gear
# tempword=> mar gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures have
# tempword=> temperatures have been
# tempword=> have been increased
# tempword=> been increased high
# tempword=> increased high temperatures
# tempword=> high temperatures observed
# tempword=> temperatures observed are
# tempword=> observed are hs
# tempword=> are hs rot
# tempword=> hs rot c
# tempword=> rot c ims
# tempword=> c ims generator
# tempword=> ims generator c
# tempword=> generator c and
# tempword=> c and ims
# tempword=> and ims rot
# tempword=> ims rot c
# tempword=> rot c
# tempword=> c
# tempword=>
# 19
# tempword=> within the past
# tempword=> the past week
# tempword=> past week gear
# tempword=> week gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures increased
# tempword=> temperatures increased to
# tempword=> increased to c
# tempword=> to c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims generator
# tempword=> ims generator c
# tempword=> generator c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims rot
# tempword=> ims rot and
# tempword=> rot and c
# tempword=> and c on
# tempword=> c on tag
# tempword=> on tag hs
# tempword=> tag hs rot
# tempword=> hs rot the
# tempword=> rot the turbine
# tempword=> the turbine was
# tempword=> turbine was running
# tempword=> was running at
# tempword=> running at full
# tempword=> at full power
# tempword=> full power during
# tempword=> power during periodically
# tempword=> during periodically of
# tempword=> periodically of increased
# tempword=> of increased temperatures
# tempword=> increased temperatures and
# tempword=> temperatures and ambient
# tempword=> and ambient is
# tempword=> ambient is c
# tempword=> is c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time compared
# tempword=> time compared to
# tempword=> compared to other
# tempword=> to other turbine
# tempword=> other turbine during
# tempword=> turbine during the
# tempword=> during the same
# tempword=> the same time
# tempword=> same time period
# tempword=> time period temperatures
# tempword=> period temperatures are
# tempword=> temperatures are c
# tempword=> are c higher
# tempword=> c higher on
# tempword=> higher on turbine
# tempword=> on turbine case
# tempword=> turbine case was
# tempword=> case was close
# tempword=> was close months
# tempword=> close months ago
# tempword=> months ago for
# tempword=> ago for the
# tempword=> for the same
# tempword=> the same issue
# tempword=> same issue and
# tempword=> issue and some
# tempword=> and some vibration
# tempword=> some vibration issue
# tempword=> vibration issue were
# tempword=> issue were noted
# tempword=> were noted update
# tempword=> noted update gear
# tempword=> update gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures have
# tempword=> temperatures have increased
# tempword=> have increased to
# tempword=> increased to c
# tempword=> to c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims generator
# tempword=> ims generator c
# tempword=> generator c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims rot
# tempword=> ims rot and
# tempword=> rot and c
# tempword=> and c on
# tempword=> c on tag
# tempword=> on tag hs
# tempword=> tag hs rot
# tempword=> hs rot with
# tempword=> rot with the
# tempword=> with the turbine
# tempword=> the turbine running
# tempword=> turbine running at
# tempword=> running at full
# tempword=> at full power
# tempword=> full power from
# tempword=> power from aug
# tempword=> from aug ambient
# tempword=> aug ambient was
# tempword=> ambient was c
# tempword=> was c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time
# tempword=> time
# tempword=>
# 20
# tempword=> wind turbine is
# tempword=> turbine is indicating
# tempword=> is indicating a
# tempword=> indicating a code
# tempword=> a code on
# tempword=> code on the
# tempword=> on the wt
# tempword=> the wt operating
# tempword=> wt operating state
# tempword=> operating state tag
# tempword=> state tag is
# tempword=> tag is this
# tempword=> is this turbine
# tempword=> this turbine down
# tempword=> turbine down for
# tempword=> down for maintenance
# tempword=> for maintenance or
# tempword=> maintenance or is
# tempword=> or is this
# tempword=> is this due
# tempword=> this due to
# tempword=> due to an
# tempword=> to an error
# tempword=> an error update
# tempword=> error update condition
# tempword=> update condition cleared
# tempword=> condition cleared close
# tempword=> cleared close case
# tempword=> close case
# tempword=> case
# tempword=>
# 21
# tempword=> it appears turbine
# tempword=> appears turbine at
# tempword=> turbine at inner
# tempword=> at inner dowsing
# tempword=> inner dowsing is
# tempword=> dowsing is currently
# tempword=> is currently being
# tempword=> currently being curtailed
# tempword=> being curtailed to
# tempword=> curtailed to mw
# tempword=> to mw
# tempword=> mw
# tempword=>
# 22
# tempword=> beginning apr wind
# tempword=> apr wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears curtailed
# tempword=> appears curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 23
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed
# tempword=> curtailed
# tempword=>
# 24
# tempword=> it appears on
# tempword=> appears on turbine
# tempword=> on turbine came
# tempword=> turbine came online
# tempword=> came online but
# tempword=> online but only
# tempword=> but only to
# tempword=> only to produce
# tempword=> to produce kw
# tempword=> produce kw it
# tempword=> kw it had
# tempword=> it had stayed
# tempword=> had stayed this
# tempword=> stayed this way
# tempword=> this way for
# tempword=> way for roughly
# tempword=> for roughly hours
# tempword=> roughly hours and
# tempword=> hours and then
# tempword=> and then returned
# tempword=> then returned to
# tempword=> returned to full
# tempword=> to full power
# tempword=> full power
# tempword=> power
# tempword=>
# 25
# tempword=> on feb gear
# tempword=> feb gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures increased
# tempword=> temperatures increased to
# tempword=> increased to c
# tempword=> to c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims generator
# tempword=> ims generator c
# tempword=> generator c on
# tempword=> c on tag
# tempword=> on tag ims
# tempword=> tag ims rot
# tempword=> ims rot and
# tempword=> rot and c
# tempword=> and c on
# tempword=> c on tag
# tempword=> on tag hs
# tempword=> tag hs rot
# tempword=> hs rot the
# tempword=> rot the turbine
# tempword=> the turbine was
# tempword=> turbine was running
# tempword=> was running at
# tempword=> running at full
# tempword=> at full power
# tempword=> full power and
# tempword=> power and ambient
# tempword=> and ambient was
# tempword=> ambient was c
# tempword=> was c since
# tempword=> c since feb
# tempword=> since feb gear
# tempword=> feb gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures appear
# tempword=> temperatures appear to
# tempword=> appear to be
# tempword=> to be modulating
# tempword=> be modulating but
# tempword=> modulating but temperatures
# tempword=> but temperatures remained
# tempword=> temperatures remained increased
# tempword=> remained increased temperatures
# tempword=> increased temperatures are
# tempword=> temperatures are not
# tempword=> are not excessive
# tempword=> not excessive however
# tempword=> excessive however this
# tempword=> however this was
# tempword=> this was compared
# tempword=> was compared with
# tempword=> compared with other
# tempword=> with other wind
# tempword=> other wind turbine
# tempword=> wind turbine and
# tempword=> turbine and turbine
# tempword=> and turbine hs
# tempword=> turbine hs gear
# tempword=> hs gear bearing
# tempword=> gear bearing temperatures
# tempword=> bearing temperatures are
# tempword=> temperatures are c
# tempword=> are c above
# tempword=> c above other
# tempword=> above other wind
# tempword=> other wind turbine
# tempword=> wind turbine running
# tempword=> turbine running c
# tempword=> running c
# tempword=> c
# tempword=>
# 26
# tempword=> it appears that
# tempword=> appears that turbine
# tempword=> that turbine is
# tempword=> turbine is being
# tempword=> is being limited
# tempword=> being limited to
# tempword=> limited to kw
# tempword=> to kw of
# tempword=> kw of power
# tempword=> of power
# tempword=> power
# tempword=>
# 27
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s curtailed
# tempword=> s curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 28
# tempword=> wwind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update turbine
# tempword=> update turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed close
# tempword=> curtailed close case
# tempword=> close case
# tempword=> case
# tempword=>
# 29
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s curtailed
# tempword=> s curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 30
# tempword=> we are currently
# tempword=> are currently seeing
# tempword=> currently seeing the
# tempword=> seeing the active
# tempword=> the active power
# tempword=> active power tag
# tempword=> power tag for
# tempword=> tag for turbine
# tempword=> for turbine at
# tempword=> turbine at mw
# tempword=> at mw with
# tempword=> mw with wind
# tempword=> with wind speed
# tempword=> wind speed from
# tempword=> speed from to
# tempword=> from to m
# tempword=> to m s
# tempword=> m s
# tempword=> s
# tempword=>
# 31
# tempword=> beginning feb wind
# tempword=> feb wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears was
# tempword=> appears was curtailed
# tempword=> was curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s curtailed
# tempword=> s curtailed appears
# tempword=> curtailed appears to
# tempword=> appears to have
# tempword=> to have cleared
# tempword=> have cleared since
# tempword=> cleared since feb
# tempword=> since feb note
# tempword=> feb note this
# tempword=> note this was
# tempword=> this was originally
# tempword=> was originally communicated
# tempword=> originally communicated via
# tempword=> communicated via a
# tempword=> via a rapid
# tempword=> a rapid response
# tempword=> rapid response notification
# tempword=> response notification
# tempword=> notification
# tempword=>
# 32
# tempword=> beginning may wind
# tempword=> may wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears curtailed
# tempword=> appears curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 33
# tempword=> wind turbine is
# tempword=> turbine is indicating
# tempword=> is indicating a
# tempword=> indicating a code
# tempword=> a code on
# tempword=> code on the
# tempword=> on the wt
# tempword=> the wt operating
# tempword=> wt operating state
# tempword=> operating state tag
# tempword=> state tag is
# tempword=> tag is this
# tempword=> is this turbine
# tempword=> this turbine down
# tempword=> turbine down for
# tempword=> down for maintenance
# tempword=> for maintenance or
# tempword=> maintenance or is
# tempword=> or is this
# tempword=> is this due
# tempword=> this due to
# tempword=> due to an
# tempword=> to an error
# tempword=> an error update
# tempword=> error update condition
# tempword=> update condition cleared
# tempword=> condition cleared close
# tempword=> cleared close case
# tempword=> close case
# tempword=> case
# tempword=>
# 34
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update on
# tempword=> update on wind
# tempword=> on wind turbine
# tempword=> wind turbine curtailed
# tempword=> turbine curtailed changed
# tempword=> curtailed changed from
# tempword=> changed from kw
# tempword=> from kw to
# tempword=> kw to kw
# tempword=> to kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 35
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s note
# tempword=> s note this
# tempword=> note this was
# tempword=> this was originally
# tempword=> was originally communicated
# tempword=> originally communicated via
# tempword=> communicated via email
# tempword=> via email notification
# tempword=> email notification on
# tempword=> notification on curtailed
# tempword=> on curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 36
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 37
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed close
# tempword=> curtailed close case
# tempword=> close case
# tempword=> case
# tempword=>
# 38
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s a
# tempword=> s a short
# tempword=> a short increase
# tempword=> short increase to
# tempword=> increase to kw
# tempword=> to kw was
# tempword=> kw was observed
# tempword=> was observed on
# tempword=> observed on
# tempword=> on
# tempword=>
# 39
# tempword=> while the unit
# tempword=> the unit is
# tempword=> unit is operating
# tempword=> is operating at
# tempword=> operating at decrease
# tempword=> at decrease power
# tempword=> decrease power kw
# tempword=> power kw generator
# tempword=> kw generator bearing
# tempword=> generator bearing temperature
# normalized position
# tempword=> bearing temperature de
# normalized position
# tempword=> temperature de has
# tempword=> de has been
# tempword=> has been elevated
# tempword=> been elevated running
# tempword=> elevated running as
# tempword=> running as high
# tempword=> as high as
# tempword=> high as c
# tempword=> as c ambient
# tempword=> c ambient is
# tempword=> ambient is c
# tempword=> is c during
# tempword=> c during this
# tempword=> during this time
# tempword=> this time other
# tempword=> time other wind
# tempword=> other wind turbine
# tempword=> wind turbine during
# tempword=> turbine during the
# tempword=> during the same
# tempword=> the same timeframe
# tempword=> same timeframe are
# tempword=> timeframe are operating
# tempword=> are operating with
# tempword=> operating with de
# tempword=> with de temperatures
# tempword=> de temperatures c
# tempword=> temperatures c with
# tempword=> c with similar
# tempword=> with similar active
# tempword=> similar active power
# tempword=> active power
# tempword=> power
# tempword=>
# 40
# tempword=> we are currently
# tempword=> are currently seeing
# tempword=> currently seeing the
# tempword=> seeing the active
# tempword=> the active power
# tempword=> active power tag
# tempword=> power tag for
# tempword=> tag for turbine
# tempword=> for turbine at
# tempword=> turbine at mw
# tempword=> at mw with
# tempword=> mw with wind
# tempword=> with wind speed
# tempword=> wind speed from
# tempword=> speed from to
# tempword=> from to m
# tempword=> to m s
# tempword=> m s
# tempword=> s
# tempword=>
# 41
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update curtailed
# tempword=> update curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 42
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s a
# tempword=> s a short
# tempword=> a short increase
# tempword=> short increase to
# tempword=> increase to kw
# tempword=> to kw was
# tempword=> kw was observed
# tempword=> was observed on
# tempword=> observed on
# tempword=> on
# tempword=>
# 43
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 44
# tempword=> it appears there
# tempword=> appears there is
# tempword=> there is a
# tempword=> is a possible
# tempword=> a possible amemometer
# tempword=> possible amemometer issue
# tempword=> amemometer issue on
# tempword=> issue on turbine
# tempword=> on turbine currently
# tempword=> turbine currently it
# tempword=> currently it is
# tempword=> it is returning
# tempword=> is returning flatline
# tempword=> returning flatline values
# tempword=> flatline values at
# tempword=> values at m
# tempword=> at m sbut
# tempword=> m sbut the
# tempword=> sbut the active
# tempword=> the active power
# tempword=> active power is
# tempword=> power is read
# tempword=> is read kw
# tempword=> read kw wind
# tempword=> kw wind at
# tempword=> wind at the
# tempword=> at the farm
# tempword=> the farm is
# tempword=> farm is around
# tempword=> is around m
# tempword=> around m s
# tempword=> m s
# tempword=> s
# tempword=>
# 45
# tempword=> flatline data recieved
# tempword=> data recieved on
# tempword=> recieved on from
# tempword=> on from am
# tempword=> from am to
# tempword=> am to am
# tempword=> to am
# tempword=> am
# tempword=>
# 46
# tempword=> turbine for inner
# tempword=> for inner dowsing
# tempword=> inner dowsing in
# tempword=> dowsing in not
# tempword=> in not returning
# tempword=> not returning current
# tempword=> returning current data
# tempword=> current data
# tempword=> data
# tempword=>
# 47
# tempword=> during the recent
# tempword=> the recent period
# tempword=> recent period of
# tempword=> period of operation
# tempword=> of operation starting
# tempword=> operation starting june
# tempword=> starting june de
# tempword=> june de generator
# tempword=> de generator bearing
# tempword=> generator bearing temperatures
# tempword=> bearing temperatures have
# tempword=> temperatures have exceeded
# tempword=> have exceeded the
# tempword=> exceeded the estimate
# tempword=> the estimate with
# tempword=> estimate with a
# tempword=> with a recent
# tempword=> a recent high
# tempword=> recent high of
# tempword=> high of c
# tempword=> of c observed
# tempword=> c observed c
# tempword=> observed c above
# tempword=> c above the
# tempword=> above the model
# tempword=> the model all
# tempword=> model all other
# tempword=> all other bearing
# tempword=> other bearing in
# tempword=> bearing in the
# tempword=> in the model
# tempword=> the model are
# tempword=> model are track
# tempword=> are track the
# tempword=> track the estimate
# tempword=> the estimate the
# tempword=> estimate the turbine
# tempword=> the turbine was
# tempword=> turbine was operating
# tempword=> was operating at
# tempword=> operating at kw
# tempword=> at kw during
# tempword=> kw during this
# tempword=> during this period
# tempword=> this period of
# tempword=> period of increased
# tempword=> of increased temperature
# tempword=> increased temperature
# tempword=> temperature
# tempword=>
# 48
# tempword=> beginning may wind
# tempword=> may wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears curtailed
# tempword=> appears curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 49
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed close
# tempword=> curtailed close case
# tempword=> close case
# tempword=> case
# tempword=>
# 50
# tempword=> inner dowsing turbine
# tempword=> dowsing turbine the
# tempword=> turbine the power
# tempword=> the power is
# tempword=> power is currently
# tempword=> is currently limited
# tempword=> currently limited to
# tempword=> limited to mw
# tempword=> to mw
# tempword=> mw
# tempword=>
# 51
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s on
# tempword=> s on wind
# tempword=> on wind turbine
# tempword=> wind turbine active
# tempword=> turbine active power
# tempword=> active power increased
# tempword=> power increased to
# tempword=> increased to kw
# tempword=> to kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s an
# tempword=> s an email
# tempword=> an email notification
# tempword=> email notification was
# tempword=> notification was provided
# tempword=> was provided on
# tempword=> provided on update
# tempword=> on update curtailed
# tempword=> update curtailed cleared
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# 52
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s note
# tempword=> s note this
# tempword=> note this was
# tempword=> this was originally
# tempword=> was originally communicated
# tempword=> originally communicated via
# tempword=> communicated via email
# tempword=> via email notification
# tempword=> email notification on
# tempword=> notification on update
# tempword=> on update turbine
# tempword=> update turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed close
# tempword=> curtailed close case
# tempword=> close case
# tempword=> case
# tempword=>
# 53
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s
# tempword=> s
# tempword=>
# 54
# tempword=> since wind turbine
# tempword=> wind turbine appears
# tempword=> turbine appears to
# tempword=> appears to be
# tempword=> to be curtailed
# tempword=> be curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine is
# tempword=> turbine is now
# tempword=> is now curtailed
# tempword=> now curtailed at
# tempword=> curtailed at kw
# tempword=> at kw with
# tempword=> kw with wind
# tempword=> with wind speed
# tempword=> wind speed between
# tempword=> speed between m
# tempword=> between m s
# tempword=> m s update
# tempword=> s update wind
# tempword=> update wind turbine
# tempword=> wind turbine no
# tempword=> turbine no longer
# tempword=> no longer curtailed
# tempword=> longer curtailed close
# tempword=> curtailed close case
# tempword=> close case
# tempword=> case
# tempword=>
# 55
# tempword=> it appears turbine
# tempword=> appears turbine is
# tempword=> turbine is currently
# tempword=> is currently limited
# tempword=> currently limited to
# tempword=> limited to mw
# tempword=> to mw during
# tempword=> mw during higher
# tempword=> during higher wind
# tempword=> higher wind condition
# tempword=> wind condition
# tempword=> condition
# tempword=>
# 56
# tempword=> beginning wtg has
# tempword=> wtg has been
# tempword=> has been exhibited
# tempword=> been exhibited increased
# tempword=> exhibited increased de
# tempword=> increased de bearing
# tempword=> de bearing temperatures
# tempword=> bearing temperatures that
# tempword=> temperatures that have
# tempword=> that have spike
# tempword=> have spike degc
# tempword=> spike degc above
# tempword=> degc above the
# tempword=> above the model
# tempword=> the model on
# tempword=> model on de
# tempword=> on de bearing
# tempword=> de bearing temperature
# normalized position
# tempword=> bearing temperature was
# tempword=> temperature was degc
# tempword=> was degc with
# tempword=> degc with a
# tempword=> with a model
# tempword=> a model estimate
# tempword=> model estimate of
# tempword=> estimate of degc
# tempword=> of degc on
# tempword=> degc on de
# tempword=> on de bearing
# tempword=> de bearing temperature
# normalized position
# tempword=> bearing temperature was
# tempword=> temperature was degc
# tempword=> was degc with
# tempword=> degc with a
# tempword=> with a model
# tempword=> a model estimate
# tempword=> model estimate of
# tempword=> estimate of degc
# tempword=> of degc this
# tempword=> degc this has
# tempword=> this has created
# tempword=> has created an
# tempword=> created an increased
# tempword=> an increased de
# tempword=> increased de bearing
# tempword=> de bearing temperature
# normalized position
# tempword=> bearing temperature spread
# tempword=> temperature spread of
# tempword=> spread of degc
# tempword=> of degc between
# tempword=> degc between the
# tempword=> between the wind
# tempword=> the wind turbine
# tempword=> wind turbine
# tempword=> turbine
# tempword=>
# 57
# tempword=> starting at on
# tempword=> at on we
# tempword=> on we started
# tempword=> we started to
# tempword=> started to noitce
# tempword=> to noitce the
# tempword=> noitce the active
# tempword=> the active power
# tempword=> active power for
# tempword=> power for turine
# tempword=> for turine return
# tempword=> turine return flatline
# tempword=> return flatline data
# tempword=> flatline data compared
# tempword=> data compared to
# tempword=> compared to the
# tempword=> to the rest
# tempword=> the rest also
# tempword=> rest also comparing
# tempword=> also comparing turbine
# tempword=> comparing turbine to
# tempword=> turbine to turbine
# tempword=> to turbine it
# tempword=> turbine it appears
# tempword=> it appears for
# tempword=> appears for the
# tempword=> for the same
# tempword=> the same wind
# tempword=> same wind turbine
# tempword=> wind turbine is
# tempword=> turbine is struggling
# ...
# tempword=> degc to degc
# tempword=> to degc with
# tempword=> degc with model
# tempword=> with model predicted
# tempword=> model predicted at
# tempword=> predicted at degc
# tempword=> at degc
# tempword=> degc
# tempword=>
# 475
# tempword=> atreduced loads ip
# tempword=> loads ip attemperator
# tempword=> ip attemperator spray
# normalized position
# tempword=> attemperator spray valve
# normalized position
# tempword=> spray valve and
# tempword=> valve and spray
# tempword=> and spray flow
# tempword=> spray flow are
# tempword=> flow are higher
# tempword=> are higher than
# tempword=> higher than expected
# tempword=> than expected with
# tempword=> expected with ip
# tempword=> with ip rh
# tempword=> ip rh dsh
# normalized position
# tempword=> rh dsh outlet
# tempword=> dsh outlet temperature
# normalized position
# tempword=> outlet temperature decrease
# tempword=> temperature decrease to
# tempword=> decrease to f
# tempword=> to f with
# tempword=> f with an
# tempword=> with an estimate
# tempword=> an estimate of
# tempword=> estimate of f
# tempword=> of f update
# tempword=> f update ip
# tempword=> update ip rh
# tempword=> ip rh dsh
# normalized position
# tempword=> rh dsh outlet
# tempword=> dsh outlet temperatureis
# tempword=> outlet temperatureis back
# tempword=> temperatureis back totracking
# tempword=> back totracking at
# tempword=> totracking at f
# tempword=> at f of
# tempword=> f of late
# tempword=> of late if
# tempword=> late if current
# tempword=> if current condition
# tempword=> current condition are
# tempword=> condition are acceptable
# tempword=> are acceptable they
# tempword=> acceptable they can
# tempword=> they can be
# tempword=> can be added
# tempword=> be added to
# tempword=> added to the
# tempword=> to the model
# tempword=> the model to
# tempword=> model to improve
# tempword=> to improve track
# tempword=> improve track
# tempword=> track
# tempword=>
# 476
# tempword=> on suction pressure
# tempword=> suction pressure took
# tempword=> pressure took a
# tempword=> took a step
# tempword=> a step change
# tempword=> step change down
# tempword=> change down from
# tempword=> down from barg
# tempword=> from barg to
# tempword=> barg to barg
# tempword=> to barg with
# tempword=> barg with model
# tempword=> with model predicted
# tempword=> model predicted at
# tempword=> predicted at barg
# tempword=> at barg
# tempword=> barg
# tempword=>
# 477
# tempword=> hr gpstkte a
# tempword=> gpstkte a b
# tempword=> a b and
# tempword=> b and c
# tempword=> and c are
# tempword=> c are showing
# tempword=> are showing increased
# tempword=> showing increased spread
# tempword=> increased spread hr
# tempword=> spread hr gpstkte
# tempword=> hr gpstkte a
# tempword=> gpstkte a is
# tempword=> a is currently
# tempword=> is currently the
# tempword=> currently the lowest
# tempword=> the lowest read
# tempword=> lowest read f
# tempword=> read f with
# tempword=> f with hr
# tempword=> with hr gpstkte
# tempword=> hr gpstkte b
# tempword=> gpstkte b read
# tempword=> b read f
# tempword=> read f in
# tempword=> f in october
# tempword=> in october all
# tempword=> october all four
# tempword=> all four indications
# tempword=> four indications were
# tempword=> indications were read
# tempword=> were read within
# tempword=> read within f
# tempword=> within f of
# tempword=> f of each
# tempword=> of each at
# tempword=> each at f
# tempword=> at f update
# tempword=> f update condition
# tempword=> update condition persist
# tempword=> condition persist
# tempword=> persist
# tempword=>
# 478
# tempword=> condition continues following
# tempword=> continues following data
# tempword=> following data return
# tempword=> data return on
# tempword=> return on the
# tempword=> on the lube
# tempword=> the lube oil
# tempword=> lube oil dp
# tempword=> oil dp has
# tempword=> dp has been
# tempword=> has been flatline
# tempword=> been flatline
# tempword=> flatline
# tempword=>
# 479
# tempword=> on hr lpdrmstmte
# tempword=> hr lpdrmstmte hr
# tempword=> lpdrmstmte hr lp
# tempword=> hr lp drum
# tempword=> lp drum outlet
# tempword=> drum outlet temperature
# tempword=> outlet temperature increased
# tempword=> temperature increased from
# tempword=> increased from f
# tempword=> from f to
# tempword=> f to f
# tempword=> to f the
# tempword=> f the a
# tempword=> the a and
# tempword=> a and b
# tempword=> and b sensor
# tempword=> b sensor continued
# tempword=> sensor continued to
# tempword=> continued to track
# tempword=> to track as
# tempword=> track as expected
# tempword=> as expected at
# tempword=> expected at f
# tempword=> at f
# tempword=> f
# tempword=>
# 480
# tempword=> lube oil filter
# normalized position
# tempword=> oil filter has
# tempword=> filter has been
# tempword=> has been slowly
# tempword=> been slowly increase
# tempword=> slowly increase from
# tempword=> increase from barg
# tempword=> from barg to
# tempword=> barg to barg
# tempword=> to barg since
# tempword=> barg since
# tempword=> since
# tempword=>
# 481
# tempword=>
# 482
# tempword=> on pump discharge
# tempword=> pump discharge decrease
# tempword=> discharge decrease down
# tempword=> decrease down to
# tempword=> down to with
# tempword=> to with model
# tempword=> with model predicted
# tempword=> model predicted at
# tempword=> predicted at multiple
# tempword=> at multiple tag
# tempword=> multiple tag affected
# tempword=> tag affected
# tempword=> affected
# tempword=>
# 483
# tempword=> before shutdown on
# tempword=> shutdown on hp
# tempword=> on hp drum
# tempword=> hp drum level
# tempword=> drum level (tag
# tempword=> level (tag t
# tempword=> (tag t b)
# tempword=> t b) began
# tempword=> b) began read
# tempword=> began read elevated
# tempword=> read elevated from
# tempword=> elevated from model
# tempword=> from model estimate
# tempword=> model estimate and
# tempword=> estimate and drifting
# tempword=> and drifting higher
# tempword=> drifting higher than
# tempword=> higher than the
# tempword=> than the other
# tempword=> the other two
# tempword=> other two drum
# tempword=> two drum level
# tempword=> drum level indications
# tempword=> level indications now
# tempword=> indications now read
# tempword=> now read about
# tempword=> read about inch
# tempword=> about inch differential
# tempword=> inch differential update
# tempword=> differential update the
# tempword=> update the issue
# tempword=> the issue has
# tempword=> issue has persist
# tempword=> has persist on
# tempword=> persist on the
# tempword=> on the most
# tempword=> the most recent
# tempword=> most recent run
# tempword=> recent run as
# tempword=> run as well
# tempword=> as well
# tempword=> well
# tempword=>
# 484
# tempword=> after startup on
# tempword=> startup on lube
# tempword=> on lube oil
# tempword=> lube oil filter
# normalized position
# tempword=> oil filter increased
# tempword=> filter increased up
# tempword=> increased up to
# tempword=> up to barg
# tempword=> to barg then
# tempword=> barg then dropped
# tempword=> then dropped to
# tempword=> dropped to
# tempword=> to
# tempword=>
# 485
# tempword=> discharge pressure has
# tempword=> pressure has increased
# tempword=> has increased above
# tempword=> increased above model
# tempword=> above model predicted
# tempword=> model predicted since
# tempword=> predicted since
# tempword=> since
# tempword=>
# 486
# tempword=> on st load
# tempword=> st load is
# tempword=> load is around
# tempword=> is around mw
# tempword=> around mw gt
# tempword=> mw gt load
# tempword=> gt load is
# tempword=> load is at
# tempword=> is at mw
# tempword=> at mw the
# tempword=> mw the unit
# tempword=> the unit is
# tempword=> unit is running
# tempword=> is running x
# tempword=> running x the
# tempword=> x the ip
# tempword=> the ip rh
# tempword=> ip rh dsh
# normalized position
# tempword=> rh dsh temperature
# tempword=> dsh temperature control
# tempword=> temperature control valve
# tempword=> control valve was
# tempword=> valve was wide
# tempword=> was wide open
# tempword=> wide open for
# tempword=> open for the
# tempword=> for the most
# tempword=> the most recent
# tempword=> most recent run
# tempword=> recent run there
# tempword=> run there are
# tempword=> there are no
# tempword=> are no duct
# tempword=> no duct burners
# tempword=> duct burners running
# tempword=> burners running at
# tempword=> running at this
# tempword=> at this time
# tempword=> this time
# tempword=> time
# tempword=>
# 487
# tempword=> fluid coupling journal
# tempword=> coupling journal bearing
# tempword=> journal bearing temperature
# normalized position
# tempword=> bearing temperature has
# tempword=> temperature has increased
# tempword=> has increased above
# tempword=> increased above model
# tempword=> above model predictionsl
# tempword=> model predictionsl fluid
# tempword=> predictionsl fluid coupling
# tempword=> fluid coupling oil
# tempword=> coupling oil resevoir
# tempword=> oil resevoir temperature
# tempword=> resevoir temperature has
# tempword=> temperature has increased
# tempword=> has increased above
# tempword=> increased above model
# tempword=> above model predicted
# tempword=> model predicted as
# tempword=> predicted as well
# tempword=> as well this
# tempword=> well this is
# tempword=> this is the
# tempword=> is the only
# tempword=> the only bearing
# tempword=> only bearing increase
# tempword=> bearing increase
# tempword=> increase
# tempword=>
# 488
# tempword=> ip drum level
# tempword=> drum level (hr
# tempword=> level (hr ip
# tempword=> (hr ip drum
# tempword=> ip drum level
# tempword=> drum level )
# tempword=> level ) was
# tempword=> ) was read
# tempword=> was read around
# tempword=> read around inches
# tempword=> around inches on
# tempword=> inches on the
# tempword=> on the last
# tempword=> the last run
# tempword=> last run on
# tempword=> run on when
# tempword=> on when the
# tempword=> when the model
# tempword=> the model was
# tempword=> model was expecting
# tempword=> was expecting inches
# tempword=> expecting inches ip
# tempword=> inches ip drum
# tempword=> ip drum level
# tempword=> drum level is
# tempword=> level is read
# tempword=> is read inches
# tempword=> read inches and
# tempword=> inches and ip
# tempword=> and ip drum
# tempword=> ip drum level
# tempword=> drum level is
# tempword=> level is read
# tempword=> is read inches
# tempword=> read inches
# tempword=> inches
# tempword=>
# 489
# tempword=> motor wind temperature
# tempword=> wind temperature has
# tempword=> temperature has increased
# tempword=> has increased since
# tempword=> increased since
# tempword=> since
# tempword=>
# 490
# tempword=> pump drive end
# tempword=> drive end journal
# tempword=> end journal bearing
# tempword=> journal bearing temperature
# normalized position
# tempword=> bearing temperature has
# tempword=> temperature has increased
# tempword=> has increased since
# tempword=> increased since and
# tempword=> since and there
# tempword=> and there also
# tempword=> there also has
# tempword=> also has been
# tempword=> has been an
# tempword=> been an axial
# tempword=> an axial position
# tempword=> axial position change
# tempword=> position change in
# tempword=> change in this
# tempword=> in this time
# tempword=> this time frame
# tempword=> time frame
# tempword=> frame
# tempword=>
# 491
# tempword=> hp drum level
# tempword=> drum level (hr
# tempword=> level (hr ip
# tempword=> (hr ip drum
# tempword=> ip drum level
# tempword=> drum level )
# tempword=> level ) is
# tempword=> ) is read
# tempword=> is read up
# tempword=> read up to
# tempword=> up to inches
# tempword=> to inches starting
# tempword=> inches starting on
# tempword=> starting on while
# tempword=> on while the
# tempword=> while the model
# tempword=> the model has
# tempword=> model has been
# tempword=> has been expecting
# tempword=> been expecting expecting
# tempword=> expecting expecting inches
# tempword=> expecting inches ip
# tempword=> inches ip drum
# tempword=> ip drum level
# tempword=> drum level is
# tempword=> level is read
# tempword=> is read inches
# tempword=> read inches and
# tempword=> inches and ip
# tempword=> and ip drum
# tempword=> ip drum level
# tempword=> drum level is
# tempword=> level is read
# tempword=> is read inches
# tempword=> read inches
# tempword=> inches
# tempword=>
# 492
# tempword=> mischarge pressure has
# tempword=> pressure has increased
# tempword=> has increased above
# tempword=> increased above model
# tempword=> above model predicted
# tempword=> model predicted since
# tempword=> predicted since and
# tempword=> since and remains
# tempword=> and remains elevated
# tempword=> remains elevated
# tempword=> elevated
# tempword=>
# 493
# tempword=> on hp sh
# tempword=> hp sh dsh
# normalized position
# tempword=> sh dsh spray
# tempword=> dsh spray flow
# tempword=> spray flow is
# tempword=> flow is up
# tempword=> is up to
# tempword=> up to lbm
# tempword=> to lbm hr
# tempword=> lbm hr and
# tempword=> hr and the
# tempword=> and the hp
# tempword=> the hp sh
# tempword=> hp sh dsh
# normalized position
# tempword=> sh dsh outlet
# normalized position
# tempword=> dsh outlet temperature
# normalized position
# tempword=> outlet temperature went
# tempword=> temperature went down
# tempword=> went down to
# tempword=> down to as
# tempword=> to as low
# tempword=> as low as
# tempword=> low as deg
# tempword=> as deg f
# tempword=> deg f when
# tempword=> f when the
# tempword=> when the model
# tempword=> the model was
# tempword=> model was estimating
# tempword=> was estimating deg
# tempword=> estimating deg f
# tempword=> deg f
# tempword=> f
# tempword=>
# 494
# tempword=> the lube oil
# tempword=> lube oil filter
# normalized position
# tempword=> oil filter have
# tempword=> filter have increased
# tempword=> have increased from
# tempword=> increased from bar
# tempword=> from bar to
# tempword=> bar to bar
# tempword=> to bar since
# tempword=> bar since started
# tempword=> since started and
# tempword=> started and continue
# tempword=> and continue to
# tempword=> continue to rise
# tempword=> to rise
# tempword=> rise
# tempword=>
# 495
# tempword=> lube oil temperature
# normalized position
# tempword=> oil temperature has
# tempword=> temperature has increased
# tempword=> has increased above
# tempword=> increased above model
# tempword=> above model predicted
# tempword=> model predicted nde
# tempword=> predicted nde thrust
# tempword=> nde thrust bearing
# tempword=> thrust bearing temperature
# normalized position
# tempword=> bearing temperature has
# tempword=> temperature has also
# tempword=> has also increased
# tempword=> also increased over
# tempword=> increased over the
# tempword=> over the same
# tempword=> the same time
# tempword=> same time period
# tempword=> time period
# tempword=> period
# tempword=>
# 496
# tempword=>
# 497
# tempword=> coupling bearing temperature
# tempword=> bearing temperature have
# tempword=> temperature have increased
# tempword=> have increased over
# tempword=> increased over the
# tempword=> over the past
# tempword=> the past hours
# tempword=> past hours and
# tempword=> hours and remain
# tempword=> and remain above
# tempword=> remain above model
# tempword=> above model predicted
# tempword=> model predicted
# tempword=> predicted
# tempword=>
# 498
# tempword=> in the last
# tempword=> the last week
# tempword=> last week the
# tempword=> week the hr
# tempword=> the hr hp
# tempword=> hr hp drum
# tempword=> hp drum level
# tempword=> drum level b
# tempword=> level b has
# tempword=> b has been
# tempword=> has been flat
# tempword=> been flat lined
# tempword=> flat lined at
# tempword=> lined at in
# tempword=> at in update
# tempword=> in update hp
# tempword=> update hp drum
# tempword=> hp drum level
# tempword=> drum level has
# tempword=> level has dropped
# tempword=> has dropped to
# tempword=> dropped to predicted
# tempword=> to predicted values
# tempword=> predicted values but
# tempword=> values but hp
# tempword=> but hp drum
# tempword=> hp drum level
# tempword=> drum level has
# tempword=> level has flatline
# tempword=> has flatline at
# tempword=> flatline at in
# tempword=> at in
# tempword=> in
# tempword=>
# 499
# tempword=> condition cleared after
# tempword=> cleared after restart
# tempword=> after restart seal
# tempword=> restart seal loop
# tempword=> seal loop temperature
# tempword=> loop temperature has
# tempword=> temperature has increased
# tempword=> has increased track
# tempword=> increased track with
# tempword=> track with axial
# tempword=> with axial position
# tempword=> axial position
# tempword=> position
# tempword=>
# beginning august the bc inlet steam temperature (bti ) is trend at degf compared to a model predicted of degf the inlet steam pressure is trend near model predicted at psig exhaust_steam_temperature  pressure are trend with model

# %%
print(arrTrigramFiltered[301])
# Out:
# beginning august the bc inlet steam temperature (bti ) is trend at degf compared to a model predicted of degf the inlet steam pressure is trend near model predicted at psig exhaust_steam_temperature  pressure are trend with model

# %%
Now apply the bigram logic

# %%
arrBigramFiltered=[]
for count in range(startCaseNumber,endCaseNumber):

    details =arrTrigramFiltered[count]
    arrTempTerms = details.split(" ")
    lenCase = len(arrTempTerms)
    str = ''
    # echo $details."<br/>";
    str=details;
    for i in range(lenCase):

        largestStringFound=''
        firstword=''
        secondword=''
        thirdword=''

        firstword=arrTempTerms[i].lower()
        if (i <= (lenCase-2)):
            secondword=arrTempTerms[i+1].lower()
        if (firstword == " " or secondword == " "):
            break
        tempword = firstword+" "+secondword
        print("tempword=>", tempword)
        retword = getNormalizedWord(tempword, ngramDict)
        if (retword):
            print("normalized", retWord)
            str = str.replace(tempword, retword)

    arrBigramFiltered.append(str)
# Out:
# tempword=> tagido ons
# tempword=> ons cba
# tempword=> cba bj
# tempword=> bj xq
# tempword=> xq m
# tempword=> m act
# tempword=> act pw
# tempword=> pw appears
# tempword=> appears to
# tempword=> to be
# tempword=> be flatline
# tempword=> flatline at
# tempword=> at update
# tempword=> update flatline
# tempword=> flatline cleared
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> it appears
# tempword=> appears while
# tempword=> while the
# tempword=> the turbine
# tempword=> turbine is
# tempword=> is active
# tempword=> active power
# tempword=> power is
# tempword=> is moving
# tempword=> moving around
# tempword=> around the
# tempword=> the wind
# tempword=> wind speed
# normalized position
# tempword=> speed sensor
# tempword=> sensor is
# tempword=> is returning
# tempword=> returning a
# tempword=> a flatline
# tempword=> flatline value
# tempword=> value update
# tempword=> update appears
# tempword=> appears the
# tempword=> the anemometer
# tempword=> anemometer issue
# tempword=> issue have
# tempword=> have been
# tempword=> been resolved
# tempword=> resolved as
# tempword=> as of
# tempword=> of at
# tempword=> at am
# tempword=> am
# tempword=>
# tempword=> since the
# tempword=> the following
# tempword=> following tag
# tempword=> tag are
# tempword=> are indicating
# tempword=> indicating intermittent
# tempword=> intermittent flatline
# tempword=> flatline ido
# tempword=> ido wtg
# tempword=> wtg mdk
# tempword=> mdk bt
# tempword=> bt xq
# tempword=> xq m
# tempword=> m hsrot
# tempword=> hsrot temperature
# tempword=> temperature ido
# tempword=> ido wtg
# tempword=> wtg mdk
# tempword=> mdk bt
# tempword=> bt xq
# tempword=> xq m
# tempword=> m imsgen
# tempword=> imsgen temperature
# tempword=> temperature and
# tempword=> and ido
# tempword=> ido wtg
# tempword=> wtg mdk
# tempword=> mdk bt
# tempword=> bt xq
# tempword=> xq m
# tempword=> m imsrot
# tempword=> imsrot temperature
# tempword=> temperature actual
# tempword=> actual temperatures
# tempword=> temperatures are
# tempword=> are acceptable
# tempword=> acceptable when
# tempword=> when tag
# tempword=> tag are
# tempword=> are not
# tempword=> not flatline
# tempword=> flatline (
# tempword=> ( degc)
# tempword=> degc) update
# tempword=> update flatline
# tempword=> flatline cleared
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> beginning aug
# tempword=> aug wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> during higher
# tempword=> higher wind
# tempword=> wind condition
# tempword=> condition the
# tempword=> the turbine
# tempword=> turbine is
# tempword=> is currently
# tempword=> currently limited
# tempword=> limited to
# tempword=> to mw
# tempword=> mw
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed since
# tempword=> since currently
# tempword=> currently active
# tempword=> active power
# tempword=> power is
# tempword=> is kw
# tempword=> kw curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> on generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  remained
# tempword=> remained above
# tempword=> above the
# tempword=> the model
# tempword=> model estimate
# normalized position
# tempword=> estimate for
# tempword=> for hours
# tempword=> hours the
# tempword=> the maximum
# tempword=> maximum temperature
# tempword=> temperature observed
# tempword=> observed was
# tempword=> was degc
# tempword=> degc with
# tempword=> with a
# tempword=> a model
# tempword=> model estimate
# normalized position
# tempword=> estimate of
# tempword=> of degc
# tempword=> degc update
# tempword=> update the
# tempword=> the condition
# tempword=> condition persist
# tempword=> persist with
# tempword=> with a
# tempword=> a high
# tempword=> high temperature
# tempword=> temperature of
# tempword=> of c
# tempword=> c observed
# tempword=> observed on
# tempword=> on
# tempword=>
# tempword=> within the
# tempword=> the past
# tempword=> past week
# tempword=> week de
# tempword=> de bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures have
# tempword=> have been
# tempword=> been track
# tempword=> track c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c no
# tempword=> no other
# tempword=> other deviate
# tempword=> deviate are
# tempword=> are noted
# tempword=> noted in
# tempword=> in the
# tempword=> the model
# tempword=> model
# tempword=>
# tempword=> within the
# tempword=> the past
# tempword=> past week
# tempword=> week generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  de
# tempword=> de has
# tempword=> has exceeded
# tempword=> exceeded the
# tempword=> the model
# tempword=> model estimate
# normalized position
# tempword=> estimate with
# tempword=> with a
# tempword=> a recent
# tempword=> recent increase
# tempword=> increase as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c with
# tempword=> with an
# tempword=> an estimate
# tempword=> estimate of
# tempword=> of c
# tempword=> c the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was running
# tempword=> running at
# tempword=> at lower
# tempword=> lower power
# tempword=> power when
# tempword=> when most
# tempword=> most of
# tempword=> of the
# tempword=> the increase
# tempword=> increase occurred
# tempword=> occurred at
# tempword=> at kw
# tempword=> kw and
# tempword=> and generator
# tempword=> generator speed
# normalized position
# tempword=> speed was
# tempword=> was rpm
# tempword=> rpm ambient
# tempword=> ambient temperature
# normalized position
# tempword=> temperature was
# tempword=> was c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time
# tempword=>
# tempword=> while the
# tempword=> the unit
# tempword=> unit is
# tempword=> is operating
# tempword=> operating at
# tempword=> at decrease
# tempword=> decrease power
# tempword=> power kw
# tempword=> kw generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  de
# tempword=> de has
# tempword=> has been
# tempword=> been elevated
# tempword=> elevated running
# tempword=> running as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c ambient
# tempword=> ambient is
# tempword=> is c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time other
# tempword=> other wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine during
# tempword=> during the
# tempword=> the same
# tempword=> same timeframe
# tempword=> timeframe are
# tempword=> are operating
# tempword=> operating with
# tempword=> with de
# tempword=> de temperatures
# tempword=> temperatures c
# tempword=> c with
# tempword=> with similar
# tempword=> similar active
# tempword=> active power
# tempword=> power
# tempword=>
# tempword=> we are
# tempword=> are currently
# tempword=> currently seeing
# tempword=> seeing the
# tempword=> the active
# tempword=> active power
# tempword=> power tag
# tempword=> tag for
# tempword=> for turbine
# tempword=> turbine at
# tempword=> at mw
# tempword=> mw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed from
# tempword=> from to
# tempword=> to m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s note
# tempword=> note the
# tempword=> the wps
# tempword=> wps status
# tempword=> status tag
# tempword=> tag is
# tempword=> is returning
# tempword=> returning a
# tempword=> a while
# tempword=> while the
# tempword=> the wt
# tempword=> wt operating
# tempword=> operating state
# tempword=> state is
# tempword=> is returning
# tempword=> returning update
# tempword=> update curtailed
# tempword=> curtailed cleared
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> within the
# tempword=> the past
# tempword=> past weeks
# tempword=> weeks wtg
# tempword=> wtg has
# tempword=> has been
# tempword=> been exhibited
# tempword=> exhibited increased
# tempword=> increased nde_bearing_temperature
# tempword=> nde_bearing_temperature s
# tempword=> s that
# tempword=> that have
# tempword=> have spike
# tempword=> spike c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model on
# tempword=> on nde_bearing_temperature
# tempword=> nde_bearing_temperature
# tempword=>  was
# tempword=> was c
# tempword=> c with
# tempword=> with a
# tempword=> a model
# tempword=> model estimate
# normalized position
# tempword=> estimate of
# tempword=> of c
# tempword=> c this
# tempword=> this has
# tempword=> has created
# tempword=> created an
# tempword=> an increased
# tempword=> increased nde_bearing_temperature
# tempword=> nde_bearing_temperature
# tempword=>  spread
# tempword=> spread of
# tempword=> of c
# tempword=> c between
# tempword=> between the
# tempword=> the wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine no
# tempword=> no other
# tempword=> other adverse
# tempword=> adverse bearing
# tempword=> bearing trends
# tempword=> trends were
# tempword=> were noted
# tempword=> noted update
# tempword=> update within
# tempword=> within the
# tempword=> the past
# tempword=> past week
# tempword=> week generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  de
# tempword=> de has
# tempword=> has been
# tempword=> been increased
# tempword=> increased as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c with
# tempword=> with an
# tempword=> an estimate
# tempword=> estimate of
# tempword=> of c
# tempword=> c temperatures
# tempword=> temperatures remained
# tempword=> remained above
# tempword=> above the
# tempword=> the model
# tempword=> model for
# tempword=> for hrs
# tempword=> hrs before
# tempword=> before returning
# tempword=> returning to
# tempword=> to the
# tempword=> the model
# tempword=> model
# tempword=>
# tempword=> since oct
# tempword=> oct nde
# tempword=> nde bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures have
# tempword=> have been
# tempword=> been track
# tempword=> track c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c no
# tempword=> no other
# tempword=> other deviate
# tempword=> deviate are
# tempword=> are noted
# tempword=> noted in
# tempword=> in the
# tempword=> the model
# tempword=> model
# tempword=>
# tempword=> beginning may
# tempword=> may wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> on may
# tempword=> may turbine
# tempword=> turbine appeared
# tempword=> appeared to
# tempword=> to return
# tempword=> return from
# tempword=> from curtailed
# tempword=> curtailed to
# tempword=> to full
# tempword=> full power
# tempword=> power but
# tempword=> but appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed again
# tempword=> again at
# tempword=> at kw
# tempword=> kw beginning
# tempword=> beginning may
# tempword=> may with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> while the
# tempword=> the unit
# tempword=> unit is
# tempword=> is operating
# tempword=> operating at
# tempword=> at decrease
# tempword=> decrease power
# tempword=> power kw
# tempword=> kw generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  nde
# tempword=> nde increased
# tempword=> increased to
# tempword=> to as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c before
# tempword=> before returning
# tempword=> returning to
# tempword=> to the
# tempword=> the model
# tempword=> model when
# tempword=> when the
# tempword=> the unit
# tempword=> unit increased
# tempword=> increased in
# tempword=> in power
# tempword=> power ambient
# tempword=> ambient was
# tempword=> was c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time
# tempword=>
# tempword=> nde bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures are
# tempword=> are showing
# tempword=> showing an
# tempword=> an increased
# tempword=> increased frequency
# tempword=> frequency of
# tempword=> of high
# tempword=> high temperature
# tempword=> temperature spike
# tempword=> spike within
# tempword=> within the
# tempword=> the past
# tempword=> past week
# tempword=> week temperatures
# tempword=> temperatures have
# tempword=> have increased
# tempword=> increased to
# tempword=> to as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c de
# tempword=> de temperatures
# tempword=> temperatures are
# tempword=> are track
# tempword=> track the
# tempword=> the model
# tempword=> model update
# tempword=> update geip
# tempword=> geip to
# tempword=> to continue
# tempword=> continue monitor
# tempword=> monitor close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> on jan
# tempword=> jan gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures increased
# tempword=> increased to
# tempword=> to c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims generator
# tempword=> generator c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims rot
# normalized position
# tempword=> rot and
# tempword=> and c
# tempword=> c on
# tempword=> on tag
# tempword=> tag hs
# tempword=> hs rot
# normalized position
# tempword=> rot the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was running
# tempword=> running at
# tempword=> at full
# tempword=> full power
# tempword=> power ambient
# tempword=> ambient was
# tempword=> was c
# tempword=> c and
# tempword=> and there
# tempword=> there was
# tempword=> was a
# tempword=> a brief
# tempword=> brief increase
# tempword=> increase in
# tempword=> in wind
# tempword=> wind speed
# normalized position
# tempword=> speed up
# tempword=> up to
# tempword=> to m
# tempword=> m s
# tempword=> s since
# tempword=> since then
# tempword=> then temperatures
# tempword=> temperatures are
# tempword=> are not
# tempword=> not modulating
# tempword=> modulating as
# tempword=> as well
# tempword=> well as
# tempword=> as they
# tempword=> they have
# tempword=> have in
# tempword=> in the
# tempword=> the past
# tempword=> past weekly
# tempword=> weekly report
# tempword=> report since
# tempword=> since mar
# tempword=> mar gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures have
# tempword=> have been
# tempword=> been increased
# tempword=> increased high
# tempword=> high temperatures
# tempword=> temperatures observed
# tempword=> observed are
# tempword=> are hs
# tempword=> hs rot
# normalized position
# tempword=> rot c
# tempword=> c ims
# tempword=> ims generator
# tempword=> generator c
# tempword=> c and
# tempword=> and ims
# tempword=> ims rot
# normalized position
# tempword=> rot c
# tempword=> c
# tempword=>
# tempword=> within the
# tempword=> the past
# tempword=> past week
# tempword=> week gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures increased
# tempword=> increased to
# tempword=> to c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims generator
# tempword=> generator c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims rot
# normalized position
# tempword=> rot and
# tempword=> and c
# tempword=> c on
# tempword=> on tag
# tempword=> tag hs
# tempword=> hs rot
# normalized position
# tempword=> rot the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was running
# tempword=> running at
# tempword=> at full
# tempword=> full power
# tempword=> power during
# tempword=> during periodically
# tempword=> periodically of
# tempword=> of increased
# tempword=> increased temperatures
# tempword=> temperatures and
# tempword=> and ambient
# tempword=> ambient is
# tempword=> is c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time compared
# tempword=> compared to
# tempword=> to other
# tempword=> other turbine
# tempword=> turbine during
# tempword=> during the
# tempword=> the same
# tempword=> same time
# tempword=> time period
# tempword=> period temperatures
# tempword=> temperatures are
# tempword=> are c
# tempword=> c higher
# tempword=> higher on
# tempword=> on turbine
# tempword=> turbine case
# tempword=> case was
# tempword=> was close
# tempword=> close months
# tempword=> months ago
# tempword=> ago for
# tempword=> for the
# tempword=> the same
# tempword=> same issue
# tempword=> issue and
# tempword=> and some
# tempword=> some vibration
# tempword=> vibration issue
# tempword=> issue were
# tempword=> were noted
# tempword=> noted update
# tempword=> update gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures have
# tempword=> have increased
# tempword=> increased to
# tempword=> to c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims generator
# tempword=> generator c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims rot
# normalized position
# tempword=> rot and
# tempword=> and c
# tempword=> c on
# tempword=> on tag
# tempword=> tag hs
# tempword=> hs rot
# normalized position
# tempword=> rot with
# tempword=> with the
# tempword=> the turbine
# tempword=> turbine running
# tempword=> running at
# tempword=> at full
# tempword=> full power
# tempword=> power from
# tempword=> from aug
# tempword=> aug ambient
# tempword=> ambient was
# tempword=> was c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine is
# tempword=> is indicating
# tempword=> indicating a
# tempword=> a code
# tempword=> code on
# tempword=> on the
# tempword=> the wt
# tempword=> wt operating
# tempword=> operating state
# tempword=> state tag
# tempword=> tag is
# tempword=> is this
# tempword=> this turbine
# tempword=> turbine down
# tempword=> down for
# tempword=> for maintenance
# tempword=> maintenance or
# tempword=> or is
# tempword=> is this
# tempword=> this due
# tempword=> due to
# tempword=> to an
# tempword=> an error
# tempword=> error update
# tempword=> update condition
# tempword=> condition cleared
# normalized position
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> it appears
# tempword=> appears turbine
# tempword=> turbine at
# tempword=> at inner
# tempword=> inner dowsing
# tempword=> dowsing is
# tempword=> is currently
# tempword=> currently being
# tempword=> being curtailed
# tempword=> curtailed to
# tempword=> to mw
# tempword=> mw
# tempword=>
# tempword=> beginning apr
# tempword=> apr wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed
# tempword=>
# tempword=> it appears
# tempword=> appears on
# tempword=> on turbine
# tempword=> turbine came
# tempword=> came online
# tempword=> online but
# tempword=> but only
# tempword=> only to
# tempword=> to produce
# tempword=> produce kw
# tempword=> kw it
# tempword=> it had
# tempword=> had stayed
# tempword=> stayed this
# tempword=> this way
# tempword=> way for
# tempword=> for roughly
# tempword=> roughly hours
# tempword=> hours and
# tempword=> and then
# tempword=> then returned
# tempword=> returned to
# tempword=> to full
# tempword=> full power
# tempword=> power
# tempword=>
# tempword=> on feb
# tempword=> feb gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures increased
# tempword=> increased to
# tempword=> to c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims generator
# tempword=> generator c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims rot
# normalized position
# tempword=> rot and
# tempword=> and c
# tempword=> c on
# tempword=> on tag
# tempword=> tag hs
# tempword=> hs rot
# normalized position
# tempword=> rot the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was running
# tempword=> running at
# tempword=> at full
# tempword=> full power
# tempword=> power and
# tempword=> and ambient
# tempword=> ambient was
# tempword=> was c
# tempword=> c since
# tempword=> since feb
# tempword=> feb gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures appear
# tempword=> appear to
# tempword=> to be
# tempword=> be modulating
# tempword=> modulating but
# tempword=> but temperatures
# tempword=> temperatures remained
# tempword=> remained increased
# tempword=> increased temperatures
# tempword=> temperatures are
# tempword=> are not
# tempword=> not excessive
# tempword=> excessive however
# tempword=> however this
# tempword=> this was
# tempword=> was compared
# tempword=> compared with
# tempword=> with other
# tempword=> other wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine and
# tempword=> and turbine
# tempword=> turbine hs
# tempword=> hs gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures are
# tempword=> are c
# tempword=> c above
# tempword=> above other
# tempword=> other wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine running
# tempword=> running c
# tempword=> c
# tempword=>
# tempword=> it appears
# tempword=> appears that
# tempword=> that turbine
# tempword=> turbine is
# tempword=> is being
# tempword=> being limited
# tempword=> limited to
# tempword=> to kw
# tempword=> kw of
# tempword=> of power
# tempword=> power
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> wwind turbine
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update turbine
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> we are
# tempword=> are currently
# tempword=> currently seeing
# tempword=> seeing the
# tempword=> the active
# tempword=> active power
# tempword=> power tag
# tempword=> tag for
# tempword=> for turbine
# tempword=> turbine at
# tempword=> at mw
# tempword=> mw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed from
# tempword=> from to
# tempword=> to m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> beginning feb
# tempword=> feb wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears was
# tempword=> was curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s curtailed
# tempword=> curtailed appears
# tempword=> appears to
# tempword=> to have
# tempword=> have cleared
# tempword=> cleared since
# tempword=> since feb
# tempword=> feb note
# tempword=> note this
# tempword=> this was
# tempword=> was originally
# tempword=> originally communicated
# tempword=> communicated via
# tempword=> via a
# tempword=> a rapid
# tempword=> rapid response
# tempword=> response notification
# tempword=> notification
# tempword=>
# tempword=> beginning may
# tempword=> may wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine is
# tempword=> is indicating
# tempword=> indicating a
# tempword=> a code
# tempword=> code on
# tempword=> on the
# tempword=> the wt
# tempword=> wt operating
# tempword=> operating state
# tempword=> state tag
# tempword=> tag is
# tempword=> is this
# tempword=> this turbine
# tempword=> turbine down
# tempword=> down for
# tempword=> for maintenance
# tempword=> maintenance or
# tempword=> or is
# tempword=> is this
# tempword=> this due
# tempword=> due to
# tempword=> to an
# tempword=> an error
# tempword=> error update
# tempword=> update condition
# tempword=> condition cleared
# normalized position
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update on
# tempword=> on wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine curtailed
# tempword=> curtailed changed
# tempword=> changed from
# tempword=> from kw
# tempword=> kw to
# tempword=> to kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s note
# tempword=> note this
# tempword=> this was
# tempword=> was originally
# tempword=> originally communicated
# tempword=> communicated via
# tempword=> via email
# tempword=> email notification
# tempword=> notification on
# tempword=> on curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s a
# tempword=> a short
# tempword=> short increase
# tempword=> increase to
# tempword=> to kw
# tempword=> kw was
# tempword=> was observed
# tempword=> observed on
# tempword=> on
# tempword=>
# tempword=> while the
# tempword=> the unit
# tempword=> unit is
# tempword=> is operating
# tempword=> operating at
# tempword=> at decrease
# tempword=> decrease power
# tempword=> power kw
# tempword=> kw generator_bearing_temperature
# tempword=> generator_bearing_temperature
# tempword=>  de
# tempword=> de has
# tempword=> has been
# tempword=> been elevated
# tempword=> elevated running
# tempword=> running as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c ambient
# tempword=> ambient is
# tempword=> is c
# tempword=> c during
# tempword=> during this
# tempword=> this time
# tempword=> time other
# tempword=> other wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine during
# tempword=> during the
# tempword=> the same
# tempword=> same timeframe
# tempword=> timeframe are
# tempword=> are operating
# tempword=> operating with
# tempword=> with de
# tempword=> de temperatures
# tempword=> temperatures c
# tempword=> c with
# tempword=> with similar
# tempword=> similar active
# tempword=> active power
# tempword=> power
# tempword=>
# tempword=> we are
# tempword=> are currently
# tempword=> currently seeing
# tempword=> seeing the
# tempword=> the active
# tempword=> active power
# tempword=> power tag
# tempword=> tag for
# tempword=> for turbine
# tempword=> turbine at
# tempword=> at mw
# tempword=> mw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed from
# tempword=> from to
# tempword=> to m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s a
# tempword=> a short
# tempword=> short increase
# tempword=> increase to
# tempword=> to kw
# tempword=> kw was
# tempword=> was observed
# tempword=> observed on
# tempword=> on
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> it appears
# tempword=> appears there
# tempword=> there is
# tempword=> is a
# tempword=> a possible
# tempword=> possible amemometer
# tempword=> amemometer issue
# tempword=> issue on
# tempword=> on turbine
# tempword=> turbine currently
# tempword=> currently it
# tempword=> it is
# tempword=> is returning
# tempword=> returning flatline
# tempword=> flatline values
# tempword=> values at
# tempword=> at m
# tempword=> m sbut
# tempword=> sbut the
# tempword=> the active
# tempword=> active power
# tempword=> power is
# tempword=> is read
# tempword=> read kw
# tempword=> kw wind
# tempword=> wind at
# tempword=> at the
# tempword=> the farm
# tempword=> farm is
# tempword=> is around
# tempword=> around m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> flatline data
# normalized position
# tempword=> data recieved
# tempword=> recieved on
# tempword=> on from
# tempword=> from am
# tempword=> am to
# tempword=> to am
# tempword=> am
# tempword=>
# tempword=> turbine for
# tempword=> for inner
# tempword=> inner dowsing
# tempword=> dowsing in
# tempword=> in not
# tempword=> not returning
# tempword=> returning current
# tempword=> current data
# tempword=> data
# tempword=>
# tempword=> during the
# tempword=> the recent
# tempword=> recent period
# tempword=> period of
# tempword=> of operation
# tempword=> operation starting
# tempword=> starting june
# tempword=> june de
# tempword=> de generator
# tempword=> generator bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures have
# tempword=> have exceeded
# tempword=> exceeded the
# tempword=> the estimate
# tempword=> estimate with
# tempword=> with a
# tempword=> a recent
# tempword=> recent high
# tempword=> high of
# tempword=> of c
# tempword=> c observed
# tempword=> observed c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model all
# tempword=> all other
# tempword=> other bearing
# tempword=> bearing in
# tempword=> in the
# tempword=> the model
# tempword=> model are
# tempword=> are track
# tempword=> track the
# tempword=> the estimate
# tempword=> estimate the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was operating
# tempword=> operating at
# tempword=> at kw
# tempword=> kw during
# tempword=> during this
# tempword=> this period
# tempword=> period of
# tempword=> of increased
# tempword=> increased temperature
# tempword=> temperature
# tempword=>
# tempword=> beginning may
# tempword=> may wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> inner dowsing
# tempword=> dowsing turbine
# tempword=> turbine the
# tempword=> the power
# tempword=> power is
# tempword=> is currently
# tempword=> currently limited
# tempword=> limited to
# tempword=> to mw
# tempword=> mw
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s on
# tempword=> on wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine active
# tempword=> active power
# tempword=> power increased
# tempword=> increased to
# tempword=> to kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s an
# tempword=> an email
# tempword=> email notification
# tempword=> notification was
# tempword=> was provided
# tempword=> provided on
# tempword=> on update
# tempword=> update curtailed
# tempword=> curtailed cleared
# tempword=> cleared
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s note
# tempword=> note this
# tempword=> this was
# tempword=> was originally
# tempword=> originally communicated
# tempword=> communicated via
# tempword=> via email
# tempword=> email notification
# tempword=> notification on
# tempword=> on update
# tempword=> update turbine
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine is
# tempword=> is now
# tempword=> now curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> it appears
# tempword=> appears turbine
# tempword=> turbine is
# tempword=> is currently
# tempword=> currently limited
# tempword=> limited to
# tempword=> to mw
# tempword=> mw during
# tempword=> during higher
# tempword=> higher wind
# tempword=> wind condition
# tempword=> condition
# tempword=>
# tempword=> beginning wtg
# tempword=> wtg has
# tempword=> has been
# tempword=> been exhibited
# tempword=> exhibited increased
# tempword=> increased de_bearing_temperature
# tempword=> de_bearing_temperature s
# tempword=> s that
# tempword=> that have
# tempword=> have spike
# tempword=> spike degc
# tempword=> degc above
# tempword=> above the
# tempword=> the model
# tempword=> model on
# tempword=> on de_bearing_temperature
# tempword=> de_bearing_temperature
# tempword=>  was
# tempword=> was degc
# tempword=> degc with
# tempword=> with a
# tempword=> a model
# tempword=> model estimate
# normalized position
# tempword=> estimate of
# tempword=> of degc
# tempword=> degc on
# tempword=> on de_bearing_temperature
# tempword=> de_bearing_temperature
# tempword=>  was
# tempword=> was degc
# tempword=> degc with
# tempword=> with a
# tempword=> a model
# tempword=> model estimate
# normalized position
# tempword=> estimate of
# tempword=> of degc
# tempword=> degc this
# tempword=> this has
# tempword=> has created
# tempword=> created an
# tempword=> an increased
# tempword=> increased de_bearing_temperature
# tempword=> de_bearing_temperature
# tempword=>  spread
# tempword=> spread of
# tempword=> of degc
# tempword=> degc between
# tempword=> between the
# tempword=> the wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine
# tempword=>
# tempword=> starting at
# tempword=> at on
# tempword=> on we
# tempword=> we started
# tempword=> started to
# tempword=> to noitce
# tempword=> noitce the
# tempword=> the active
# tempword=> active power
# tempword=> power for
# tempword=> for turine
# tempword=> turine return
# tempword=> return flatline
# tempword=> flatline data
# normalized position
# tempword=> data compared
# tempword=> compared to
# tempword=> to the
# tempword=> the rest
# tempword=> rest also
# tempword=> also comparing
# tempword=> comparing turbine
# tempword=> turbine to
# tempword=> to turbine
# tempword=> turbine it
# tempword=> it appears
# tempword=> appears for
# tempword=> for the
# tempword=> the same
# tempword=> same wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine is
# tempword=> is struggling
# tempword=> struggling to
# tempword=> to maintian
# tempword=> maintian full
# tempword=> full power
# tempword=> power at
# tempword=> at wind
# tempword=> wind above
# tempword=> above m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> it appears
# tempword=> appears on
# tempword=> on turbine
# tempword=> turbine the
# tempword=> the active
# tempword=> active power
# tempword=> power is
# tempword=> is remaining
# tempword=> remaining lower
# tempword=> lower at
# tempword=> at kw
# tempword=> kw
# tempword=>
# tempword=> it appears
# tempword=> appears turbine
# tempword=> turbine is
# tempword=> is currently
# tempword=> currently curtailed
# tempword=> curtailed while
# tempword=> while we
# tempword=> we are
# tempword=> are seeing
# tempword=> seeing other
# tempword=> other tubines
# tempword=> tubines at
# tempword=> at full
# tempword=> full power
# tempword=> power and
# tempword=> and wind
# tempword=> wind speed
# normalized position
# tempword=> speed m
# tempword=> m s
# tempword=> s
# tempword=>
# tempword=> on it
# tempword=> it appears
# tempword=> appears turbine
# tempword=> turbine has
# tempword=> has been
# tempword=> been limited
# tempword=> limited to
# tempword=> to mw
# tempword=> mw of
# tempword=> of power
# tempword=> power late
# tempword=> late on
# tempword=> on the
# tempword=> the th
# tempword=> th it
# tempword=> it appear
# tempword=> appear to
# tempword=> to have
# tempword=> have rose
# tempword=> rose to
# tempword=> to mw
# tempword=> mw we
# tempword=> we are
# tempword=> are currently
# tempword=> currently at
# tempword=> at a
# tempword=> a lower
# tempword=> lower wind
# tempword=> wind condition
# tempword=> condition where
# tempword=> where we
# tempword=> we have
# tempword=> have not
# tempword=> not reached
# tempword=> reached mw
# tempword=> mw again
# tempword=> again
# tempword=>
# tempword=> all turbine
# tempword=> turbine for
# tempword=> for lynn
# tempword=> lynn wind
# tempword=> wind farm
# tempword=> farm the
# tempword=> the active
# tempword=> active power
# tempword=> power tag
# tempword=> tag are
# tempword=> are returning
# tempword=> returning flatline
# tempword=> flatline data
# normalized position
# tempword=> data at
# tempword=> at kw
# tempword=> kw
# tempword=>
# tempword=> we have
# tempword=> have been
# tempword=> been receiving
# tempword=> receiving flatline
# tempword=> flatline data
# normalized position
# tempword=> data for
# tempword=> for turbine
# tempword=> turbine just
# tempword=> just wanted
# tempword=> wanted to
# tempword=> to confirm
# tempword=> confirm if
# tempword=> if this
# tempword=> this turbine
# tempword=> turbine is
# tempword=> is down
# tempword=> down for
# tempword=> for maintenance
# tempword=> maintenance or
# tempword=> or there
# tempword=> there is
# tempword=> is a
# tempword=> a communication
# tempword=> communication error
# tempword=> error
# tempword=>
# tempword=> since wind
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update generator
# tempword=> generator no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed
# tempword=>
# tempword=> during the
# tempword=> the period
# tempword=> period of
# tempword=> of operation
# tempword=> operation beginning
# tempword=> beginning hs
# tempword=> hs rot
# normalized position
# tempword=> rot temperature
# tempword=> temperature trend
# tempword=> trend as
# tempword=> as high
# tempword=> high as
# tempword=> as c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures reached
# tempword=> reached c
# tempword=> c previously
# tempword=> previously temperatures
# tempword=> temperatures trend
# tempword=> trend c
# tempword=> c above
# tempword=> above the
# tempword=> the model
# tempword=> model at
# tempword=> at c
# tempword=> c update
# tempword=> update condition
# tempword=> condition cleared
# normalized position
# tempword=> cleared close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> note this
# tempword=> this condition
# tempword=> condition also
# tempword=> also occurred
# tempword=> occurred on
# tempword=> on all
# tempword=> all turbine
# tempword=> turbine but
# tempword=> but temperatures
# tempword=> temperatures remained
# tempword=> remained highest
# tempword=> highest on
# tempword=> on turbine
# tempword=> turbine on
# tempword=> on jan
# tempword=> jan gear
# tempword=> gear bearing
# normalized position
# tempword=> bearing temperatures
# tempword=> temperatures increased
# tempword=> increased to
# tempword=> to c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims generator
# tempword=> generator c
# tempword=> c on
# tempword=> on tag
# tempword=> tag ims
# normalized position
# tempword=> ims rot
# normalized position
# tempword=> rot and
# tempword=> and c
# tempword=> c on
# tempword=> on tag
# tempword=> tag hs
# tempword=> hs rot
# normalized position
# tempword=> rot the
# tempword=> the turbine
# tempword=> turbine was
# tempword=> was running
# tempword=> running at
# tempword=> at full
# tempword=> full power
# tempword=> power ambient
# tempword=> ambient was
# tempword=> was c
# tempword=> c and
# tempword=> and there
# tempword=> there was
# tempword=> was a
# tempword=> a brief
# tempword=> brief increase
# tempword=> increase in
# tempword=> in wind
# tempword=> wind speed
# normalized position
# tempword=> speed up
# tempword=> up to
# tempword=> to m
# tempword=> m s
# tempword=> s since
# tempword=> since then
# tempword=> then temperatures
# tempword=> temperatures are
# tempword=> are not
# tempword=> not modulating
# tempword=> modulating as
# tempword=> as well
# tempword=> well as
# tempword=> as they
# tempword=> they have
# tempword=> have in
# tempword=> in the
# tempword=> the past
# tempword=> past
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appeared
# tempword=> appeared to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s on
# tempword=> on july
# tempword=> july curtailed
# tempword=> curtailed appears
# tempword=> appears to
# tempword=> to have
# tempword=> have since
# tempword=> since july
# tempword=> july with
# tempword=> with at
# tempword=> at least
# tempword=> least one
# tempword=> one brief
# tempword=> brief instance
# tempword=> instance of
# tempword=> of power
# tempword=> power kw
# tempword=> kw
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# tempword=> s update
# tempword=> update turbine
# tempword=> turbine no
# tempword=> no longer
# tempword=> longer curtailed
# tempword=> curtailed close
# tempword=> close case
# tempword=> case
# tempword=>
# tempword=> wind turbine
# normalized position
# tempword=> turbine appears
# tempword=> appears to
# tempword=> to be
# tempword=> be curtailed
# tempword=> curtailed at
# tempword=> at kw
# tempword=> kw with
# tempword=> with wind
# tempword=> wind speed
# normalized position
# tempword=> speed between
# tempword=> between m
# tempword=> m s
# ...
# tempword=> outlet temperature
# normalized position
# tempword=> temperature will
# tempword=> will read
# tempword=> read erratic
# normalized position
# tempword=> erratic low
# tempword=> low before
# tempword=> before coming
# tempword=> coming up
# tempword=> up to
# tempword=> to the
# tempword=> the estimate
# tempword=> estimate at
# tempword=> at higher
# tempword=> higher loads
# tempword=> loads update
# tempword=> update erratic
# tempword=> erratic condition
# tempword=> condition appear
# tempword=> appear to
# tempword=> to have
# tempword=> have ceased
# tempword=> ceased since
# tempword=> since beginning
# tempword=> beginning of
# tempword=> of july
# tempword=> july
# tempword=>
# tempword=> update erratic
# tempword=> erratic condition
# tempword=> condition corrected
# tempword=> corrected fluid_coupling_casing
# tempword=> fluid_coupling_casing
# tempword=>  vibration
# tempword=> vibration has
# tempword=> has been
# tempword=> been erratic
# tempword=> erratic
# tempword=>
# tempword=> after resuming
# tempword=> resuming x
# tempword=> x operation
# tempword=> operation duct_burner_fuel
# tempword=> duct_burner_fuel
# tempword=>  pressure
# tempword=> pressure will
# tempword=> will remain
# tempword=> remain low
# tempword=> low spike
# tempword=> spike high
# tempword=> high to
# tempword=> to psig
# tempword=> psig then
# tempword=> then return
# tempword=> return to
# tempword=> to the
# tempword=> the model
# tempword=> model after
# tempword=> after about
# tempword=> about hours
# tempword=> hours duct
# tempword=> duct temperature
# tempword=> temperature track
# tempword=> track throughout
# tempword=> throughout update
# tempword=> update duct_burner_fuel
# tempword=> duct_burner_fuel
# tempword=>  pressure
# tempword=> pressure now
# tempword=> now appears
# tempword=> appears to
# tempword=> to be
# tempword=> be read
# tempword=> read correct
# tempword=> correct (
# tempword=> ( psig)
# tempword=> psig) when
# tempword=> when unit
# tempword=> unit is
# tempword=> is offline
# tempword=> offline if
# tempword=> if read
# tempword=> read while
# tempword=> while unit
# tempword=> unit is
# tempword=> is running
# tempword=> running are
# tempword=> are also
# tempword=> also acceptable
# tempword=> acceptable the
# tempword=> the model
# tempword=> model can
# tempword=> can be
# tempword=> be updated
# tempword=> updated
# tempword=>
# tempword=> update lube_oil_filter
# tempword=> lube_oil_filter
# tempword=>  changed
# tempword=> changed lube_oil_filter
# tempword=> lube_oil_filter
# tempword=>  has
# tempword=> has been
# tempword=> been gradual
# tempword=> gradual increase
# tempword=> increase from
# tempword=> from barg
# tempword=> barg to
# tempword=> to barg
# tempword=> barg since
# tempword=> since
# tempword=>
# tempword=> on thrust_bearing_temperature
# tempword=> thrust_bearing_temperature
# tempword=>  took
# tempword=> took a
# tempword=> a step
# tempword=> step change
# tempword=> change down
# tempword=> down from
# tempword=> from degc
# tempword=> degc to
# tempword=> to degc
# tempword=> degc with
# tempword=> with model
# tempword=> model predicted
# normalized position
# tempword=> predicted at
# tempword=> at degc
# tempword=> degc
# tempword=>
# tempword=> atreduced loads
# tempword=> loads ip_attemperator_spray
# tempword=> ip_attemperator_spray
# tempword=>  valve
# tempword=> valve and
# tempword=> and spray
# tempword=> spray flow
# normalized position
# tempword=> flow are
# tempword=> are higher
# tempword=> higher than
# tempword=> than expected
# tempword=> expected with
# tempword=> with ip_rh_dsh
# tempword=> ip_rh_dsh
# tempword=>  outlet
# tempword=> outlet temperature
# normalized position
# tempword=> temperature decrease
# tempword=> decrease to
# tempword=> to f
# tempword=> f with
# tempword=> with an
# tempword=> an estimate
# tempword=> estimate of
# tempword=> of f
# tempword=> f update
# tempword=> update ip_rh_dsh
# tempword=> ip_rh_dsh
# tempword=>  outlet
# tempword=> outlet temperatureis
# tempword=> temperatureis back
# tempword=> back totracking
# tempword=> totracking at
# tempword=> at f
# tempword=> f of
# tempword=> of late
# tempword=> late if
# tempword=> if current
# tempword=> current condition
# tempword=> condition are
# tempword=> are acceptable
# tempword=> acceptable they
# tempword=> they can
# tempword=> can be
# tempword=> be added
# tempword=> added to
# tempword=> to the
# tempword=> the model
# tempword=> model to
# tempword=> to improve
# tempword=> improve track
# tempword=> track
# tempword=>
# tempword=> on suction
# tempword=> suction pressure
# normalized position
# tempword=> pressure took
# tempword=> took a
# tempword=> a step
# tempword=> step change
# tempword=> change down
# tempword=> down from
# tempword=> from barg
# tempword=> barg to
# tempword=> to barg
# tempword=> barg with
# tempword=> with model
# tempword=> model predicted
# normalized position
# tempword=> predicted at
# tempword=> at barg
# tempword=> barg
# tempword=>
# tempword=> hr gpstkte
# tempword=> gpstkte a
# tempword=> a b
# tempword=> b and
# tempword=> and c
# tempword=> c are
# tempword=> are showing
# tempword=> showing increased
# tempword=> increased spread
# tempword=> spread hr
# tempword=> hr gpstkte
# tempword=> gpstkte a
# tempword=> a is
# tempword=> is currently
# tempword=> currently the
# tempword=> the lowest
# tempword=> lowest read
# tempword=> read f
# tempword=> f with
# tempword=> with hr
# tempword=> hr gpstkte
# tempword=> gpstkte b
# tempword=> b read
# tempword=> read f
# tempword=> f in
# tempword=> in october
# tempword=> october all
# tempword=> all four
# tempword=> four indications
# tempword=> indications were
# tempword=> were read
# tempword=> read within
# tempword=> within f
# tempword=> f of
# tempword=> of each
# tempword=> each at
# tempword=> at f
# tempword=> f update
# tempword=> update condition
# tempword=> condition persist
# tempword=> persist
# tempword=>
# tempword=> condition continues
# normalized position
# tempword=> continues following
# tempword=> following data
# tempword=> data return
# tempword=> return on
# tempword=> on the
# tempword=> the lube
# tempword=> lube oil
# normalized position
# tempword=> oil dp
# tempword=> dp has
# tempword=> has been
# tempword=> been flatline
# tempword=> flatline
# tempword=>
# tempword=> on hr
# tempword=> hr lpdrmstmte
# tempword=> lpdrmstmte hr
# tempword=> hr lp
# tempword=> lp drum
# normalized position
# tempword=> drum outlet
# tempword=> outlet temperature
# normalized position
# tempword=> temperature increased
# tempword=> increased from
# tempword=> from f
# tempword=> f to
# tempword=> to f
# tempword=> f the
# tempword=> the a
# tempword=> a and
# tempword=> and b
# tempword=> b sensor
# tempword=> sensor continued
# tempword=> continued to
# tempword=> to track
# tempword=> track as
# tempword=> as expected
# tempword=> expected at
# tempword=> at f
# tempword=> f
# tempword=>
# tempword=> lube_oil_filter
# tempword=>  has
# tempword=> has been
# tempword=> been slowly
# tempword=> slowly increase
# tempword=> increase from
# tempword=> from barg
# tempword=> barg to
# tempword=> to barg
# tempword=> barg since
# tempword=> since
# tempword=>
# tempword=>
# tempword=> on pump
# tempword=> pump discharge
# normalized position
# tempword=> discharge decrease
# tempword=> decrease down
# tempword=> down to
# tempword=> to with
# tempword=> with model
# tempword=> model predicted
# normalized position
# tempword=> predicted at
# tempword=> at multiple
# tempword=> multiple tag
# tempword=> tag affected
# tempword=> affected
# tempword=>
# tempword=> before shutdown
# tempword=> shutdown on
# tempword=> on hp
# tempword=> hp drum
# normalized position
# tempword=> drum level
# tempword=> level (tag
# tempword=> (tag t
# tempword=> t b)
# tempword=> b) began
# tempword=> began read
# tempword=> read elevated
# tempword=> elevated from
# tempword=> from model
# tempword=> model estimate
# normalized position
# tempword=> estimate and
# tempword=> and drifting
# tempword=> drifting higher
# tempword=> higher than
# tempword=> than the
# tempword=> the other
# tempword=> other two
# tempword=> two drum
# tempword=> drum level
# tempword=> level indications
# tempword=> indications now
# tempword=> now read
# tempword=> read about
# tempword=> about inch
# tempword=> inch differential
# tempword=> differential update
# tempword=> update the
# tempword=> the issue
# tempword=> issue has
# tempword=> has persist
# tempword=> persist on
# tempword=> on the
# tempword=> the most
# tempword=> most recent
# tempword=> recent run
# tempword=> run as
# tempword=> as well
# tempword=> well
# tempword=>
# tempword=> after startup
# tempword=> startup on
# tempword=> on lube_oil_filter
# tempword=> lube_oil_filter
# tempword=>  increased
# tempword=> increased up
# tempword=> up to
# tempword=> to barg
# tempword=> barg then
# tempword=> then dropped
# tempword=> dropped to
# tempword=> to
# tempword=>
# tempword=> discharge pressure
# normalized position
# tempword=> pressure has
# tempword=> has increased
# tempword=> increased above
# tempword=> above model
# tempword=> model predicted
# normalized position
# tempword=> predicted since
# tempword=> since
# tempword=>
# tempword=> on st
# tempword=> st load
# normalized position
# tempword=> load is
# tempword=> is around
# tempword=> around mw
# tempword=> mw gt
# tempword=> gt load
# normalized position
# tempword=> load is
# tempword=> is at
# tempword=> at mw
# tempword=> mw the
# tempword=> the unit
# tempword=> unit is
# tempword=> is running
# tempword=> running x
# tempword=> x the
# tempword=> the ip_rh_dsh
# tempword=> ip_rh_dsh
# tempword=>  temperature
# tempword=> temperature control
# tempword=> control valve
# normalized position
# tempword=> valve was
# tempword=> was wide
# tempword=> wide open
# tempword=> open for
# tempword=> for the
# tempword=> the most
# tempword=> most recent
# tempword=> recent run
# tempword=> run there
# tempword=> there are
# tempword=> are no
# tempword=> no duct
# tempword=> duct burners
# tempword=> burners running
# tempword=> running at
# tempword=> at this
# tempword=> this time
# tempword=> time
# tempword=>
# tempword=> fluid coupling
# normalized position
# tempword=> coupling journal_bearing_temperature
# tempword=> journal_bearing_temperature
# tempword=>  has
# tempword=> has increased
# tempword=> increased above
# tempword=> above model
# tempword=> model predictionsl
# tempword=> predictionsl fluid
# tempword=> fluid coupling
# normalized position
# tempword=> coupling oil
# tempword=> oil resevoir
# tempword=> resevoir temperature
# tempword=> temperature has
# tempword=> has increased
# tempword=> increased above
# tempword=> above model
# tempword=> model predicted
# normalized position
# tempword=> predicted as
# tempword=> as well
# tempword=> well this
# tempword=> this is
# tempword=> is the
# tempword=> the only
# tempword=> only bearing
# tempword=> bearing increase
# tempword=> increase
# tempword=>
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level (hr
# tempword=> (hr ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level )
# tempword=> ) was
# tempword=> was read
# tempword=> read around
# tempword=> around inches
# tempword=> inches on
# tempword=> on the
# tempword=> the last
# tempword=> last run
# tempword=> run on
# tempword=> on when
# tempword=> when the
# tempword=> the model
# tempword=> model was
# tempword=> was expecting
# tempword=> expecting inches
# tempword=> inches ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level is
# tempword=> is read
# tempword=> read inches
# tempword=> inches and
# tempword=> and ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level is
# tempword=> is read
# tempword=> read inches
# tempword=> inches
# tempword=>
# tempword=> motor wind
# tempword=> wind temperature
# tempword=> temperature has
# tempword=> has increased
# tempword=> increased since
# tempword=> since
# tempword=>
# tempword=> pump drive
# tempword=> drive end
# tempword=> end journal_bearing_temperature
# tempword=> journal_bearing_temperature
# tempword=>  has
# tempword=> has increased
# tempword=> increased since
# tempword=> since and
# tempword=> and there
# tempword=> there also
# tempword=> also has
# tempword=> has been
# tempword=> been an
# tempword=> an axial
# tempword=> axial position
# normalized position
# tempword=> position change
# tempword=> change in
# tempword=> in this
# tempword=> this time
# tempword=> time frame
# tempword=> frame
# tempword=>
# tempword=> hp drum
# normalized position
# tempword=> drum level
# tempword=> level (hr
# tempword=> (hr ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level )
# tempword=> ) is
# tempword=> is read
# tempword=> read up
# tempword=> up to
# tempword=> to inches
# tempword=> inches starting
# tempword=> starting on
# tempword=> on while
# tempword=> while the
# tempword=> the model
# tempword=> model has
# tempword=> has been
# tempword=> been expecting
# tempword=> expecting expecting
# tempword=> expecting inches
# tempword=> inches ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level is
# tempword=> is read
# tempword=> read inches
# tempword=> inches and
# tempword=> and ip
# tempword=> ip drum
# normalized position
# tempword=> drum level
# tempword=> level is
# tempword=> is read
# tempword=> read inches
# tempword=> inches
# tempword=>
# tempword=> mischarge pressure
# tempword=> pressure has
# tempword=> has increased
# tempword=> increased above
# tempword=> above model
# tempword=> model predicted
# normalized position
# tempword=> predicted since
# tempword=> since and
# tempword=> and remains
# tempword=> remains elevated
# tempword=> elevated
# tempword=>
# tempword=> on hp_sh_dsh
# tempword=> hp_sh_dsh
# tempword=>  spray
# tempword=> spray flow
# normalized position
# tempword=> flow is
# tempword=> is up
# tempword=> up to
# tempword=> to lbm
# tempword=> lbm hr
# tempword=> hr and
# tempword=> and the
# tempword=> the hp_sh_dsh
# tempword=> hp_sh_dsh
# tempword=>  outlet
# tempword=> outlet temperature
# normalized position
# tempword=> temperature went
# tempword=> went down
# tempword=> down to
# tempword=> to as
# tempword=> as low
# tempword=> low as
# tempword=> as deg
# tempword=> deg f
# tempword=> f when
# tempword=> when the
# tempword=> the model
# tempword=> model was
# tempword=> was estimating
# tempword=> estimating deg
# tempword=> deg f
# tempword=> f
# tempword=>
# tempword=> the lube_oil_filter
# tempword=> lube_oil_filter
# tempword=>  have
# tempword=> have increased
# tempword=> increased from
# tempword=> from bar
# tempword=> bar to
# tempword=> to bar
# tempword=> bar since
# tempword=> since started
# tempword=> started and
# tempword=> and continue
# tempword=> continue to
# tempword=> to rise
# tempword=> rise
# tempword=>
# tempword=> lube_oil_temperature
# tempword=>  has
# tempword=> has increased
# tempword=> increased above
# tempword=> above model
# tempword=> model predicted
# normalized position
# tempword=> predicted nde
# tempword=> nde thrust_bearing_temperature
# tempword=> thrust_bearing_temperature
# tempword=>  has
# tempword=> has also
# tempword=> also increased
# tempword=> increased over
# tempword=> over the
# tempword=> the same
# tempword=> same time
# tempword=> time period
# tempword=> period
# tempword=>
# tempword=>
# tempword=> coupling bearing
# tempword=> bearing temperature
# normalized position
# tempword=> temperature have
# tempword=> have increased
# tempword=> increased over
# tempword=> over the
# tempword=> the past
# tempword=> past hours
# tempword=> hours and
# tempword=> and remain
# tempword=> remain above
# tempword=> above model
# tempword=> model predicted
# normalized position
# tempword=> predicted
# tempword=>
# tempword=> in the
# tempword=> the last
# tempword=> last week
# tempword=> week the
# tempword=> the hr
# tempword=> hr hp
# tempword=> hp drum
# normalized position
# tempword=> drum level
# tempword=> level b
# tempword=> b has
# tempword=> has been
# tempword=> been flat
# tempword=> flat lined
# normalized position
# tempword=> lined at
# tempword=> at in
# tempword=> in update
# tempword=> update hp
# tempword=> hp drum
# normalized position
# tempword=> drum level
# tempword=> level has
# tempword=> has dropped
# tempword=> dropped to
# tempword=> to predicted
# tempword=> predicted values
# tempword=> values but
# tempword=> but hp
# tempword=> hp drum
# normalized position
# tempword=> drum level
# tempword=> level has
# tempword=> has flatline
# tempword=> flatline at
# tempword=> at in
# tempword=> in
# tempword=>
# tempword=> condition cleared
# normalized position
# tempword=> cleared after
# tempword=> after restart
# tempword=> restart seal
# tempword=> seal loop
# tempword=> loop temperature
# tempword=> temperature has
# tempword=> has increased
# tempword=> increased track
# tempword=> track with
# tempword=> with axial
# tempword=> axial position
# normalized position
# tempword=> position
# tempword=>

# %%
print(arrBigramFiltered[301])
# Out:
# beginning august the bc inlet_steam  temperature (bti ) is trend at degf compared to a model_predicted  of degf the inlet_steam  pressure is trend near model_predicted  at psig exhaust_steam_temperature  pressure are trend with model

# %% [markdown]
# Finally print the original and the converted case

# %%
for i in range(startCaseNumber,endCaseNumber):
    print("original=>",cases[i])
    print("converted=>",arrBigramFiltered[i])
# Out:
# original=> TagIDO ONS001 CBA030 BJ001:XQ01.M_Act_Pw appears to be flatlined at 33.71  Update 1/26/15: Flatline cleared. Closing case
# converted=> tagido ons cba bj xq m act pw appears to be flatline at update flatline cleared close case
# original=> It appears while the turbine is active power is moving around the wind speed sensor is returning a flatline value.
#
# Update 1-3-14: Appears the Anemometer issues have been resolved as of 1-2-14 at 7:00am
# converted=> it appears while the turbine is active power is moving around the wind_speed  sensor is returning a flatline value update appears the anemometer issue have been resolved as of at am
# original=> Since 11/25/14, the following tags are indicating intermittent flatlines: IDO WTG001 MDK030 BT001:XQ01.M_HSRot_Tmp, IDO WTG001 MDK030 BT002:XQ01.M_IMSGen_Tmp, and IDO WTG001 MDK030 BT003:XQ01.M_IMSRot_Tmp Actual temperatures are acceptable when tags are not flatlining (~65 degC). Update 1/26/15: Flatlines cleared. Closing case.
# converted=> since the following tag are indicating intermittent flatline ido wtg mdk bt xq m hsrot temperature ido wtg mdk bt xq m imsgen temperature and ido wtg mdk bt xq m imsrot temperature actual temperatures are acceptable when tag are not flatline ( degc) update flatline cleared close case
# original=> Beginning Aug 8, wind turbine 1 appears curtailed at ~2700 kW with wind speed between ~4-13 m/s.
# converted=> beginning aug wind_turbine  appears curtailed at kw with wind_speed  between m s
# original=> During higher wind conditions the turbine is currently limited to 1.8 MW
# converted=> during higher wind condition the turbine is currently limited to mw
# original=> Since 2/23/15, wind turbine 2 appears to be curtailed at ~2700 kW with wind speed between ~5-21 m/s.  Update 4/13/15: Wind turbine 2 appears to be curtailed since 4/10. Currently, active power is ~2700 kW.  Curtailment cleared.
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update wind_turbine  appears to be curtailed since currently active power is kw curtailed cleared
# original=> On 11/27/14, generator bearing temperature remained above the model estimate for ~14 hours.The maximum temperature observed was ~83 degC with a model estimate of ~62 degC.  Update 4/13/15: The condition persists with a high temperature of ~78C observed on 4/9.
# converted=> on generator_bearing_temperature  remained above the model_estimate  for hours the maximum temperature observed was degc with a model_estimate  of degc update the condition persist with a high temperature of c observed on
# original=> Within the past week, DE bearing temperatures have been tracking ~10-20C above the model, as high as ~84C. No other deviations are noted in the model.
# converted=> within the past week de_bearing  temperatures have been track c above the model as high as c no other deviate are noted in the model
# original=> Within the past week, generator bearing temperature DE has exceeded the model estimate with a recent increase as high as ~79C with an estimate of ~60C. The turbine was running at lower power when most of the increases occurred at <2000kW and generator speed was <1500 RPM. Ambient temperature was ~3-4C during this time.
# converted=> within the past week generator_bearing_temperature  de has exceeded the model_estimate  with a recent increase as high as c with an estimate of c the turbine was running at lower power when most of the increase occurred at kw and generator_speed  was rpm ambient_temperature  was c during this time
# original=> While the unit is operating at decreased power <2000 kW, generator bearing temperature DE has been elevated running as high as ~86C. Ambient is ~15-18C during this time. Other wind turbines during the same timeframe are operating with DE temperatures ~50-60C with similar active power.
# converted=> while the unit is operating at decrease power kw generator_bearing_temperature  de has been elevated running as high as c ambient is c during this time other wind_turbine  during the same timeframe are operating with de temperatures c with similar active power
# original=> We are currently seeing the active power tag for turbine 04 at 0 MW with wind speed from 5 to 13 m/s.
# converted=> we are currently seeing the active power tag for turbine at mw with wind_speed  from to m s
# original=> "Since 1/24/15, wind turbine 04 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s. Note, the WPS status tag is returning a ""2"" while the WT Operating State is returning ""0"". Update 2/9/15: Curtailment cleared. Closing case"
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s note the wps status tag is returning a while the wt operating state is returning update curtailed cleared close case
# original=> Within the past 2 weeks, WTG004 has been exhibiting increased NDE bearing temperatures that have spiked >33C above the model. On 3/25/14, NDE bearing temperature was ~86 C with a model estimate of ~53C. This has created an increased NDE bearing temperature spread of ~55C between the wind turbines. No other adverse bearing trends were noted.  Update 4/20/15: Within the past week,Generator bearing temperature DE has been increased as high as ~73C with an estimate of ~57C. Temperatures remained above the model for ~15 hrs before returning to the model.
# converted=> within the past weeks wtg has been exhibited increased nde_bearing_temperature s that have spike c above the model on nde_bearing_temperature  was c with a model_estimate  of c this has created an increased nde_bearing_temperature  spread of c between the wind_turbine  no other adverse bearing trends were noted update within the past week generator_bearing_temperature  de has been increased as high as c with an estimate of c temperatures remained above the model for hrs before returning to the model
# original=> Since, Oct. 2, NDE bearing temperatures have been tracking ~10-30C above the model, as high as ~89C. No other deviations are noted in the model.
# converted=> since oct nde_bearing  temperatures have been track c above the model as high as c no other deviate are noted in the model
# original=> Beginning May 1, wind turbine 4 appears curtailed at ~2700 kW with wind speed between ~8-13 m/s.
# converted=> beginning may wind_turbine  appears curtailed at kw with wind_speed  between m s
# original=> On May 8, turbine 4 appeared to return from curtailment to full power but appears to be curtailed again at ~1800 kW beginning May 9 with wind speed ~9-11 m/s
# converted=> on may turbine appeared to return from curtailed to full power but appears to be curtailed again at kw beginning may with wind_speed  m s
# original=> While the unit is operating at decreased power <1000 kW, generator bearing temperature NDE increased to as high as ~90C before returning to the model when the unit increased in power. Ambient was ~11C during this time.
# converted=> while the unit is operating at decrease power kw generator_bearing_temperature  nde increased to as high as c before returning to the model when the unit increased in power ambient was c during this time
# original=> NDE bearing temperatures are showing an increased frequency of high temperature spikes within the past week. Temperatures have increased to as high as ~87C. DE temperatures are tracking the model.  Update 2015-09-23: GEIP to continue monitoring. closing case.
# converted=> nde_bearing  temperatures are showing an increased frequency of high temperature spike within the past week temperatures have increased to as high as c de temperatures are track the model update geip to continue monitor close case
# original=> On Jan. 14, gear bearing temperatures increased to 60C on tag IMS-GEN, 54C on tag IMS-ROT, and 73C on tag HS-ROT. The turbine was running at full power, ambient was ~0C, and there was a brief increase in wind speed up to ~23 m/s. Since then, temperatures are not modulating as well as they have in the past.
#
# 2016-3-7 Weekly Report: Since Mar. 6, gear bearing temperatures have been increased. High temperatures observed are: HS-ROT ~73C, IMS-GEN ~59C, and IMS-ROT ~53C.
# converted=> on jan gear_bearing  temperatures increased to c on tag_ims  generator c on tag_ims  rot and c on tag hs_rot  the turbine was running at full power ambient was c and there was a brief increase in wind_speed  up to m s since then temperatures are not modulating as well as they have in the past weekly report since mar gear_bearing  temperatures have been increased high temperatures observed are hs_rot  c ims generator c and ims_rot  c
# original=> Within the past week, gear bearing temperatures increased to ~59C on tag IMS-GEN, ~53C on tag IMS-ROT, and 73C on tag HS-ROT. The turbine was running at full power during periods of increased temperatures, and ambient is ~14-18C during this time. Compared to other turbines during the same time period, temperatures are ~5-6C higher on turbine 6.
#
# Case 17917 was closed ~2 months ago for the same issue and some vibration issues were noted.
#
# Update 2016-8-29: Gear bearing temperatures have increased to ~63C on tag IMS-GEN, ~58C on tag IMS-ROT, and ~76C on tag HS-ROT with the turbine running at full power from Aug. 19-22. Ambient was ~14-17C during this time.
# converted=> within the past week gear_bearing  temperatures increased to c on tag_ims  generator c on tag_ims  rot and c on tag hs_rot  the turbine was running at full power during periodically of increased temperatures and ambient is c during this time compared to other turbine during the same time period temperatures are c higher on turbine case was close months ago for the same issue and some vibration issue were noted update gear_bearing  temperatures have increased to c on tag_ims  generator c on tag_ims  rot and c on tag hs_rot  with the turbine running at full power from aug ambient was c during this time
# original=> Wind Turbine 7 is indicating a code 9 on the WT Operating State tag. Is this turbine down for maintenance, or is this due to an error Update 1/26/15: Condition cleared. Closing case
# converted=> wind_turbine  is indicating a code on the wt operating state tag is this turbine down for maintenance or is this due to an error update condition_cleared  close case
# original=> It appears turbine 8 at inner dowsing is currently being curtailed to 1.8MW
# converted=> it appears turbine at inner dowsing is currently being curtailed to mw
# original=> Beginning Apr. 11, wind turbine 8 appears curtailed at ~1800 kW with wind speed between ~10-12 m/s.
# converted=> beginning apr wind_turbine  appears curtailed at kw with wind_speed  between m s
# original=> Since 1/23/15, wind turbine 09 appears to be curtailed at ~2700 kW with wind speed between ~5-10 m/s. Update 2/2/15: wind turbine no longer curtailed
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update wind_turbine  no longer curtailed
# original=> It appears on 10-25 turbine 10 came online but only to produce 1800 kW.It had stayed this way for roughly 5 hours and then returned to full power
# converted=> it appears on turbine came online but only to produce kw it had stayed this way for roughly hours and then returned to full power
# original=> On Feb. 16, gear bearing temperatures increased to ~54C on tag IMS-GEN, ~50C on tag IMS-ROT, and ~73C on tag HS-ROT. The turbine was running at full power and ambient was ~2-4C. Since Feb. 19, gear bearing temperatures appear to be modulating, but temperatures remained increased. Temperatures are not excessive. However, this was compared with other wind turbines, and turbine 10 HS gear bearing temperatures are ~5-7C above other wind turbines running <68C
# converted=> on feb gear_bearing  temperatures increased to c on tag_ims  generator c on tag_ims  rot and c on tag hs_rot  the turbine was running at full power and ambient was c since feb gear_bearing  temperatures appear to be modulating but temperatures remained increased temperatures are not excessive however this was compared with other wind_turbine  and turbine hs gear_bearing  temperatures are c above other wind_turbine  running c
# original=> It appears that turbine 11 is being limited to 3100 kW of power.
# converted=> it appears that turbine is being limited to kw of power
# original=> Wind turbine 11 appears to be curtailed at ~1800 kW with wind speed between ~6-13 m/s. 8/17/15: Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s curtailed cleared
# original=> Wwind turbine 13 appears to be curtailed at ~2700 kW with wind speed between ~7-15 m/s. Update 4/13/15: Turbine no longer curtailed. Closing case.
# converted=> wwind turbine appears to be curtailed at kw with wind_speed  between m s update turbine no longer curtailed close case
# original=> Wind turbine 13 appears to be curtailed at ~1800 kW with wind speed between ~5-22 m/s. 2016-1-25: Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s curtailed cleared
# original=> We are currently seeing the active power tag for turbine 15 at 0 MW with wind speed from 7 to 20 m/s.
# converted=> we are currently seeing the active power tag for turbine at mw with wind_speed  from to m s
# original=> Beginning Feb. 13, wind turbine 15 appears was curtailed at ~1800 kW with wind speed between ~5-15 m/s. Curtailment appears to have cleared since Feb. 18. Note: This was originally communicated via a Rapid Response notification.
# converted=> beginning feb wind_turbine  appears was curtailed at kw with wind_speed  between m s curtailed appears to have cleared since feb note this was originally communicated via a rapid response notification
# original=> Beginning May 21, wind turbine 15 appears curtailed at ~2700 kW with wind speed between ~4-15 m/s.
# converted=> beginning may wind_turbine  appears curtailed at kw with wind_speed  between m s
# original=> Wind Turbine 16 is indicating a code 9 on the WT Operating State tag. Is this turbine down for maintenance, or is this due to an error    Update 1/26/15: Condition cleared. Closing case
# converted=> wind_turbine  is indicating a code on the wt operating state tag is this turbine down for maintenance or is this due to an error update condition_cleared  close case
# original=> Since 1/24/15, wind turbine 16 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s. Update 2/2/15: On 1/28/15, wind turbine curtailment changed from ~1800 kW to ~2800 kW with wind speed between ~4-18 m/s.
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update on wind_turbine  curtailed changed from kw to kw with wind_speed  between m s
# original=> Wind turbine 16 appears to be curtailed at ~2700 kW with wind speed between ~6-17 m/s. Note: This was originally communicated via email notification on 3/28/15. Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s note this was originally communicated via email notification on curtailed cleared
# original=> Wind turbine 16 appears to be curtailed at ~1800 kW with wind speed between ~5-11 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> Since 2/26/15, wind turbine 17 appears to be curtailed at ~2700 kW with wind speed between ~5-22 m/s. Update 3/16/15: Wind turbine no longer curtailed. Closing case.
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update wind_turbine  no longer curtailed close case
# original=> Wind turbine 17 appears to be curtailed at ~1800 kW with wind speed between ~8-17 m/s. A short increase to ~2470 kW was observed on 8/23.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s a short increase to kw was observed on
# original=> While the unit is operating at decreased power <2000 kW, generator bearing temperature DE has been elevated running as high as ~82C. Ambient is ~11-17C during this time. Other wind turbines during the same timeframe are operating with DE temperatures ~42-48C with similar active power.
# converted=> while the unit is operating at decrease power kw generator_bearing_temperature  de has been elevated running as high as c ambient is c during this time other wind_turbine  during the same timeframe are operating with de temperatures c with similar active power
# original=> We are currently seeing the active power tag for turbine 18 at 0 MW with wind speed from 5 to 20 m/s.
# converted=> we are currently seeing the active power tag for turbine at mw with wind_speed  from to m s
# original=> Since 1/23/15, wind turbine 18 appears to be curtailed at ~2700 kW with wind speed between ~5-10 m/s. Update 2/16/15: Curtailment cleared
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed cleared
# original=> Wind turbine 18 appears to be curtailed at ~1800 kW with wind speed between ~5-19 m/s. A short increase to ~2550 kW was observed on 8/23.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s a short increase to kw was observed on
# original=> Wind turbine 18 appears to be curtailed at ~1800 kW with wind speed between ~5-15 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> It appears there is a possible amemometer issue on turbine 20, currently it is returning flatline values at 9.8 m/sbut the active power is reading 0kW. Wind at the farm is around 15m/s
# converted=> it appears there is a possible amemometer issue on turbine currently it is returning flatline values at m sbut the active power is read kw wind at the farm is around m s
# original=> Flatline data recieved on 1/6/14,from 6:07am to6:58am.
# converted=> flatline_data  recieved on from am to am
# original=> Turbine 24 for Inner Dowsing in not returning current data.
# converted=> turbine for inner dowsing in not returning current data
# original=> During the recent period of operation starting June 7, DE generator bearing temperatures have exceeded the estimates with a recent high of ~73C observed, 19C above the model. All other bearings in the model are tracking the estimates. The turbine was operating at <1000kW during this period of increased temperature.
# converted=> during the recent period of operation starting june de generator_bearing  temperatures have exceeded the estimate with a recent high of c observed c above the model all other bearing in the model are track the estimate the turbine was operating at kw during this period of increased temperature
# original=> Beginning May 21, wind turbine 24 appears curtailed at ~2700 kW with wind speed between ~4-15 m/s.
# converted=> beginning may wind_turbine  appears curtailed at kw with wind_speed  between m s
# original=> Since 12/14/14, wind turbine 25 appears to be curtailed at ~1800 kW with wind speed between ~5-15 m/s. Update 1/26/15: Wind turbine no longer curtailed. Closing case
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update wind_turbine  no longer curtailed close case
# original=> Inner Dowsing turbine 26 the power is currently limited to 1.8 MW.
# converted=> inner dowsing turbine the power is currently limited to mw
# original=> Since 12/15/14, wind turbine 26 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s. On 12/19/14, wind turbine active power increased to ~2700 kW with wind speed between ~8-20 m/s. An email notification was provided on 12/20/14. Update 2/16/15: Curtailment cleared
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s on wind_turbine  active power increased to kw with wind_speed  between m s an email notification was provided on update curtailed cleared
# original=> Wind turbine 26 appears to be curtailed at ~2700 kW with wind speed between ~5-17 m/s.  Note: This was originally communicated via email notification on 3/29/15 Update 4/13/15: Turbine no longer curtailed. Closing case.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s note this was originally communicated via email notification on update turbine no longer curtailed close case
# original=> Wind turbine 27 appears to be curtailed at ~1800 kW with wind speed between ~10-16 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> Since 12/7/14, wind turbine 28 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s. Update 1/5/15: Wind turbine 28 is now curtailed at ~2700 kW with wind speed between ~5-20 m/s.  Update 1/26/15: Wind turbine no longer curtailed. Closing case
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update wind_turbine  is now curtailed at kw with wind_speed  between m s update wind_turbine  no longer curtailed close case
# original=> It appears turbine 30 is currently limited to 1.8 MW during higher wind conditions.
# converted=> it appears turbine is currently limited to mw during higher wind condition
# original=> Beginning 12/25/14, WTG030 has been exhibiting increased DE bearing temperatures that have spiked >10 degC above the model. On 12/25/14, DE bearing temperature was ~59 degC with a model estimate of ~43 degC. On 12/28/14, DE bearing temperature was ~63 degC with a model estimate of ~47 degC. This has created an increased DE bearing temperature spread of ~49 degC between the wind turbines.
# converted=> beginning wtg has been exhibited increased de_bearing_temperature s that have spike degc above the model on de_bearing_temperature  was degc with a model_estimate  of degc on de_bearing_temperature  was degc with a model_estimate  of degc this has created an increased de_bearing_temperature  spread of degc between the wind_turbine
# original=> Starting at 9:30 on 9/28 we started to noitce the active power for turine 21 return flatline data compared to the rest. Also comparing turbine 5 to turbine 2 it appears for the same wind turbine 5 is struggling to maintian full power at wind above ~9m/s.
# converted=> starting at on we started to noitce the active power for turine return flatline_data  compared to the rest also comparing turbine to turbine it appears for the same wind_turbine  is struggling to maintian full power at wind above m s
# original=> It appears on turbine 13 the active power is remaining lower at 1800 KW.
# converted=> it appears on turbine the active power is remaining lower at kw
# original=> It appears turbine 6 is currently curtailed while we are seeing other tubines at full power and wind speed ~15 m/s.
# converted=> it appears turbine is currently curtailed while we are seeing other tubines at full power and wind_speed  m s
# original=> On 1/17/2014 it appears turbine 15 has been limited to 1 MW of power late on the 18th it appear to have rose to 1.8 MW. We are currently at a lower wind condition where we have not reached 1.8 MW again.
# converted=> on it appears turbine has been limited to mw of power late on the th it appear to have rose to mw we are currently at a lower wind condition where we have not reached mw again
# original=> All turbines for Lynn wind farm the active power tags are returning flatline data at 0 kW.
# converted=> all turbine for lynn wind farm the active power tag are returning flatline_data  at kw
# original=> We have been receiving flatline data for turbine 2 just wanted to confirm if this turbine is down for maintenance or there is a communication error.
# converted=> we have been receiving flatline_data  for turbine just wanted to confirm if this turbine is down for maintenance or there is a communication error
# original=> Since 12/7/14, wind turbine 02 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s. Update 12/15/14: generator no longer curtailed
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update generator no longer curtailed
# original=> During the period of operation beginning 5/28, HS-ROT temperature trended as high as ~11C above the model. Bearing temperatures reached ~78C. Previously, temperatures trended <4C above the model at ~73-74C. Update 6/29/15: Condition cleared, closing case.
# converted=> during the period of operation beginning hs_rot  temperature trend as high as c above the model_bearing  temperatures reached c previously temperatures trend c above the model at c update condition_cleared  close case
# original=> Note: This condition also occurred on all turbines but temperatures remained highest on turbine 3. On Jan. 14, gear bearing temperatures increased to 57C on tag IMS-GEN, 54C on tag IMS-ROT, and 72C on tag HS-ROT. The turbine was running at full power, ambient was ~0C, and there was a brief increase in wind speed up to ~23 m/s. Since then, temperatures are not modulating as well as they have in the past.
# converted=> note this condition also occurred on all turbine but temperatures remained highest on turbine on jan gear_bearing  temperatures increased to c on tag_ims  generator c on tag_ims  rot and c on tag hs_rot  the turbine was running at full power ambient was c and there was a brief increase in wind_speed  up to m s since then temperatures are not modulating as well as they have in the past
# original=> Wind turbine 3 appeared to be curtailed at ~1800 kW with wind speed between ~5-13 m/s on July 26. Curtailment appears to have since July 28 with at least one brief instance of power >1800 kW
# converted=> wind_turbine  appeared to be curtailed at kw with wind_speed  between m s on july curtailed appears to have since july with at least one brief instance of power kw
# original=> Wind turbine 4 appears to be curtailed at ~2700 kW with wind speed between ~4-16 m/s. Update 6/1/15: Turbine no longer curtailed. Closing case.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update turbine no longer curtailed close case
# original=> Wind turbine 4 appears to be curtailed at ~1800 kW with wind speed between ~5-13 m/s.  8/17/15: Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s curtailed cleared
# original=> Wind turbine 4 appears to be curtailed at ~2700 kW with wind speed between ~5-12 m/s. Update 9/14/15: Curtailment cleared
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed cleared
# original=> On Sep. 7th, gear bearing temperatures were elevated as high as 75C for HS-ROT, 64C for IMS-GEN, and 59C for IMS-ROT. At the same time as the gear bearing temperature deviations, the ambient temperature sensor for the turbine flatlined at -50C. No other issues are noted in the model.  2015-9-28 Weekly Report: All trends have returned to their models starting Sep. 27. Did the site perform any maintenance to resolve the issue
# converted=> on sep th gear_bearing  temperatures were elevated as high as c for hs_rot  c for ims generator and c for ims_rot  at the same time as the gear_bearing  temperature deviate the ambient_temperature  sensor for the turbine flatline at c no other issue are noted in the model weekly report all trends have returned to their model starting sep did the site perform any maintenance to resolve the issue
# original=> Wind turbine 4 appeared to be curtailed at ~1800 kW with wind speed between ~5-12 m/s on July 26. Curtailment appears to have since July 28 with a few brief instances of power >1800 kW
# converted=> wind_turbine  appeared to be curtailed at kw with wind_speed  between m s on july curtailed appears to have since july with a few brief instances of power kw
# original=> Wind Turbine 5 is indicating a code 9 on the WT Operating State tag. Is this turbine down for maintenance, or is this due to an error
# converted=> wind_turbine  is indicating a code on the wt operating state tag is this turbine down for maintenance or is this due to an error
# original=> On 4/8, generator DE bearing temperature began to exceed residual thresholds, and a high temperature of ~74C was observed on 4/9. Generator NDE bearing temperature was also increased with a high of ~86C observed on 4/9. Ambient temperature was ~13C at the time.
# converted=> on generator_de_bearing  temperature began to exceed residual_threshold  and a high temperature of c was observed on generator nde_bearing_temperature  was also increased with a high of c observed on ambient_temperature  was c at the time
# original=> Wind turbine 6 appears to be curtailed at ~1800 kW with wind speed between ~4-13 m/s. Curtailment cleared
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s curtailed cleared
# original=> Within the past week, generator DE bearing temperature increased to as high as ~73 on Oct. 15 while the turbine was operating at steady state. The condition cleared but returned on Oct. 18 with high temperature of ~68C observed.
# converted=> within the past week generator_de_bearing  temperature increased to as high as on oct while the turbine was operating at steady state the condition_cleared  but returned on oct with high temperature of c observed
# original=> Wind turbine 6 appears to be curtailed at ~1800 kW with wind speed between ~4-15 m/s. 11/23/15: Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s curtailed cleared
# original=> Within the past week, generator bearing temperature DE has exceeded the model estimate with a recent increase as high as ~77C with an estimate of ~56C. The turbine was running at lower power when most of the increases occurred at <2000kW and generator speed was <1500 RPM. Ambient temperature was ~4C during this time.
# converted=> within the past week generator_bearing_temperature  de has exceeded the model_estimate  with a recent increase as high as c with an estimate of c the turbine was running at lower power when most of the increase occurred at kw and generator_speed  was rpm ambient_temperature  was c during this time
# original=> Flatline data receivedfrom 1-5-14 (9:28am) to 1-6-14 (3:13am).
# converted=> flatline_data  receivedfrom ( am) to ( am)
# original=> Lynn turbine 7 is returning flatline data.
# converted=> lynn turbine is returning flatline_data
# original=> Wind turbine 7 appears to be curtailed at ~1800 kW with wind speed between ~4-16 m/s. Update 4/13/15: Turbine no longer curtailed. Closing case.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update turbine no longer curtailed close case
# original=> On May 31 with the turbine operating at full power, gear bearing temperatures were elevated and remained elevated ~48 hours. IMS-GEN increased to ~59C, IMS-ROT increased to ~55C, and HS-ROT increased to ~72C. Temperatures have been modulating well since June 2.
# converted=> on may with the turbine operating at full power gear_bearing  temperatures were elevated and remained_elevated  hours ims generator increased to c ims_rot  increased to c and hs_rot  increased to c temperatures have been modulating well since june
# original=> It appears turbine Lynn turbine 10 is currently limited to 1800 kW. Wind conditions appear to be upward of 13 m/s. Other turbines are able to maintain full active power during this time.
# converted=> it appears turbine lynn turbine is currently limited to kw wind condition appear to be upward of m s other turbine are able to maintain full active power during this time
# original=> Lynn turbine11 the power is currently limited to 1.8 MW
# converted=> lynn turbine the power is currently limited to mw
# original=> Since 1/9/15, wind turbine 11 appears to be curtailed at ~1800 kW with wind speed between ~7-21 m/s. Update 2/9/15: Curtailment closed. Closing case
# converted=> since wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed close close case
# original=> Within the past week, generator bearing temperature DE has exceeded the model estimate with a recent increase as high as ~72C with an estimate of ~54C. The turbine was running at lower power when most of the increases occurred at <2000kW and generator speed was <1500 RPM. Ambient temperature was ~4-6C during this time.
# converted=> within the past week generator_bearing_temperature  de has exceeded the model_estimate  with a recent increase as high as c with an estimate of c the turbine was running at lower power when most of the increase occurred at kw and generator_speed  was rpm ambient_temperature  was c during this time
# original=> Wind turbine 12 appears to be curtailed at ~2700 kW with wind speed between ~6-15 m/s. 10/26/15 Update: Curtailment cleared
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed cleared
# original=> Wind turbine 12 appears to be curtailed at ~1800 kW with wind speed between ~4-14 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> For a brief period on 10/5 the anemometer flatlined for 30-40 min at 3.8 m/s. It appears to have returned to normal.
#
# Update 1-3-14: Ran well until 12-13-13 where it flatlined for 3 hours, but since then it has ran well.
# converted=> for a brief period on the anemometer flatline for min at m s it appears to have returned to normal update ran well until where it flatline for hours but since then it has ran well
# original=> After a shut down and restart the suction and discharge pressure are significantly lower than the model estimate.  The discharge pressure is reading ~ 200 psig with a model estimate of ~ 1600 psig.  During the same time period the suction temperature decreased while the discharge temperature increased.
# converted=> after a shut down and restart the suction and discharge_pressure  are significantly lower than the model_estimate  the discharge_pressure  is read psig with a model_estimate  of psig during the same time period the suction_temperature  decrease while the discharge_temperature  increased
# original=> Wind turbine 13 appears to be curtailed at ~1800 kW with wind speed between ~4-14 m/s. Update 6/1/15: Turbine no longer curtailed. Closing case
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update turbine no longer curtailed close case
# original=> While offline the NDE X- Vib increased up to ~ 4 mil p/p.  When the train came online the vibrations spiked up to ~ 4 mil p/p and then stepped down to ~ 1.5 mil p/p.  The readings then trended back down to ~ 0.34 mil p/p with a model estimate of ~ 0.5 mil p/p.  Y-Axis vibrations spiked slightly (~0.1 mil p/p) on restart as well and then trended to ~ 0.4 mil p/p with a model estimate of ~ 0.6 mil p/p.
# converted=> while offline the nde x vibration increased up to mil p p when the train came online the vibration_spike  up to mil p p and then step down to mil p p the read then trend back down to mil p p with a model_estimate  of mil p p y axis vibration_spike  slightly ( mil p p) on restart as well and then trend to mil p p with a model_estimate  of mil p p
# original=> Wind turbine 13 appeared to be curtailed at ~1800 kW with wind speed between ~7-12 m/s during the brief period of operation on July 26.
# converted=> wind_turbine  appeared to be curtailed at kw with wind_speed  between m s during the brief period of operation on july
# original=> While offline the bearing temperatures are reading values that are similar to values expected during normal operations.  Speed and bearing vibration indicate the machine is offline.
# converted=> while offline the bearing temperatures are read_values  that are similar to values expected during normal operations speed and bearing_vibration  indicate the machine is offline
# original=>
# converted=>
# original=> On 4/8, generator DE bearing temperature began to exceed residual thresholds, and a high temperature of ~71C was observed on 4/9. Generator NDE bearing temperature was also increased with a high of ~80C observed on 4/9. A mbient temperature was ~13C at the time. Generator NDE bearing temperatures appear to be exhibiting an increased frequency of spikes within the past 2 weeks.
# converted=> on generator_de_bearing  temperature began to exceed residual_threshold  and a high temperature of c was observed on generator nde_bearing_temperature  was also increased with a high of c observed on a mbient temperature was c at the time generator nde_bearing_temperature s appear to be exhibited an increased frequency of spike within the past weeks
# original=> On 20 Sep the primary seal vent pressure increased on both ends. The DE increased up to ~0.8 psig with a model estimate of ~0.7 psig.  The NDE pressure increased up to ~ 0.7 psig with a model estimate of ~ 0.6 psig. No changes are noted in suction pressure or outlet vent flows.
# converted=> on sep the primary seal_vent  pressure increased on both ends the de increased up to psig with a model_estimate  of psig the nde pressure increased up to psig with a model_estimate  of psig no changes are noted in suction_pressure  or outlet vent_flow
# original=> Within the past week, generator bearing temperature NDE has exceeded the model estimate with a recent increase as high as ~79C with an estimate of ~55C. The turbine was running at lower power when most of the increases occurred at <2000kW and generator speed was <1500 RPM. Ambient temperature was ~4-6C during this time.
# converted=> within the past week generator_bearing_temperature  nde has exceeded the model_estimate  with a recent increase as high as c with an estimate of c the turbine was running at lower power when most of the increase occurred at kw and generator_speed  was rpm ambient_temperature  was c during this time
# original=>
# converted=>
# original=> Within the past week, wind turbines 15 and 22 appear to be curtailed at ~1800 kW with wind speed ~4-17 m/s
# converted=> within the past week wind_turbine  and appear to be curtailed at kw with wind_speed  m s
# original=> The seal gas coalescer filter DP trended from ~ 0.5 psid to ~ 4.9 psid. NO change in seal outlet flows are noted to indicate an increase on seal gas flow.
# converted=> the seal_gas  coalescer filter_dp  trend from psid to psid no change in seal_outlet_flow  are noted to indicate an increase on seal_gas_flow
# original=> Since the start of March the suction temperature has periodically increased up to ~ 153 degF with a corresponding increase in discharge temperature up to ~195 degF. At the time the suction temperature deceased a corresponding decrease in compressor speed is seen.
# converted=> since the start of march the suction_temperature  has periodically increased up to degf with a corresponding increase in discharge_temperature  up to degf at the time the suction_temperature  deceased a corresponding decrease in compressor_speed  is seen
# original=> Upon reviewing Sentinel we came across high gearbox bearing temperatures for Lynn turbine 16. While at full power late on 1/19 the IMS-ROT gearbox bearing increased from a historical 47 DEG C to 52 DEG C and the IMS-GEN gearbox bearing increased from 52 to 55 DEG C. Also just before the increase in power there were spikes in the NDE generator bearing from 47 to 82 DEG C.
# converted=> upon reviewing sentinel we came across high gearbox_bearing  temperatures for lynn turbine while at full power late on the ims_rot  gearbox_bearing  increased from a historical deg c to deg c and the ims generator gearbox_bearing  increased from to deg c also just before the increase in power there were spike in the nde_generator  bearing from to deg c
# original=> Several times recently, the DE Seal Vent has increased from 0.49 to 3.81 psig and the NDE Seal Vent increased from 0.39 to 3.70 psig. This is unusual behavior that is not being caused by the back pressure on the common  flare as you would expect.
# converted=> several times recently the de_seal  vent has increased from to psig and the nde_seal  vent increased from to psig this is unusual behavior that is not being caused by the back pressure on the common flare as you would expect
# original=> Wind turbine 16 appears to be curtailed at ~1800 kW with wind speed between ~5-10 m/s.    Update 9/14/15: Curtailment cleared
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed cleared
# original=>
# converted=>
# original=> During higher wind condition active power is limited to 1.8 MW on turbine 17.
# converted=> during higher wind condition active power is limited to mw on turbine
# original=> Over the course of the last 60 days the thrust position has decreased from ~ -2.66 mil with a model estimate of ~ -2.2 mil  to ~ -5.1 mil with a model estimate of -3.4 mil.  This change corresponds with a decreasing lube oil header temperature and steady speed, inlet steam pressure, and outlet steam pressure.
# converted=> over the course of the last days the thrust_position  has decrease from mil with a model_estimate  of mil to mil with a model_estimate  of mil this change corresponds with a decrease lube_oil  header temperature and steady speed inlet_steam  pressure and outlet_steam _pressure
# original=> Lynn turbine 17 is returning flatline data. Email sent to customer 11/6/14
# converted=> lynn turbine is returning flatline_data  email sent to customer
# original=>
# converted=>
# original=> While the active power is moving around the wind speed for turbine 18 is currently flatlined
# converted=> while the active power is moving around the wind_speed  for turbine is currently flatline
# original=> On 17 April, the lube oil temperature after the cooler spiked from 116 to 175 degF.  This caused a corresponding increase in all bearing temperatures.  The LO temperature has been ~5 degF higher than model prediction since 11 April.
# converted=> on april the lube_oil_temperature  after the cooler spike from to degf this caused a corresponding increase in all bearing temperatures the lo_temperature  has been degf higher than model_predicted  since april
# original=> It appears that lynn turbine 18 is currently returning flatline data.
# converted=> it appears that lynn turbine is currently returning flatline_data
# original=> After the machine came back online on 1 April the vibrations on the outboard bearing increased by ~ 0.3 mil in both directions.
#
# While the machine was operating at a low speed, ~ 850 rpm, the vibration on the inboard side did not decrease and remained steady at ~ 1 mil.  When the Machine came down to ~ 30 rpm the vibrations decreased to ~0 mils.
# converted=> after the machine came back online on april the vibration on the outboard_bearing  increased by mil in both directions while the machine was operating at a low_speed  rpm the vibration on the inboard side did not decrease and remained_steady  at mil when the machine came down to rpm the vibration decrease to mils
# original=> Wind turbine 18 appears to be curtailed at ~1800 kW with wind speed between ~5-16 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> The ZI201 and ZI200 tags have significantly different readings they vary by ~ 4.5 mil.  Previously the two tags were closer together with a difference of ~ 0.5 mil.
# 9/1/2015: Axial displacements tags are now ~ 1 mil different from each other.
# converted=> the zi and zi tag have significantly different read they vary by mil previously the two tag were closer together with a difference of mil axial displacements tag are now mil different from each other
# original=> "Wind turbine 19 appears to be curtailed at ~2700 kW with wind speed between ~7-19 m/s. Note: WPS Status is returning ""2"" Update 3/9/15: Turbine no longer curtailed. Closing case."
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s note wps status is returning update turbine no longer curtailed close case
# original=> On 23 August the discharge temperature increased up to ~ 357 degF with a model estimate of ~340 degF.  This corresponded to a drop in inlet flow from ~1200 MSCFH to ~600 MSCFH.
# converted=> on august the discharge_temperature  increased up to degf with a model_estimate  of degf this corresponded to a drop in inlet_flow  from mscfh to mscfh
# original=> Wind turbine 20 appears to be curtailed at ~2700 kW with wind speed between ~5-16 m/s. The WPS Status is indicating a fault condition
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s the wps status is indicating a fault condition
# original=> After restart and coming up to speed the stage 1 discharge pressure is reading ~ 166 psig with a model estimate of ~ 187.  This is causing the pressure ratio to decrease to ~ 6.5 with a model estimate of ~ 7.4.
# converted=> after restart and coming up to speed the stage discharge_pressure  is read psig with a model_estimate  of this is causing the pressure ratio to decrease to with a model_estimate  of
# original=> Turbine 21 during high wind conditions appears to be limited to 2.7 MW. Other turbines are able to run at full power.
#
# Updated screenshot 1/6/2013 it appears turbine is back to normal operating power at 3.6 MW
# converted=> turbine during high wind condition appears to be limited to mw other turbine are able to run at full power updated screenshot it appears turbine is back to normal operating power at mw
# original=> After shut down and restart on June 15 the vibrations on the outboard bearing increased up to ~ 1.6 mil pp with a model estimate of ~1.25 mil pp in the X direction and ~ 1.1 mil pp with a model estimate of ~ 0.9 mil pp in the Y direction.
# converted=> after shut down and restart on june the vibration on the outboard_bearing  increased up to mil pp with a model_estimate  of mil pp in the x direction and mil pp with a model_estimate  of mil pp in the y direction
# original=> Wind turbine 21 appears to be curtailed at ~1800 kW with wind speed between ~5-15 m/s. Update 6/8/15: Curtailment cleared.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s update curtailed cleared
# original=> The variation on both thrust bearing positions varies from ~ -2 mil to ~ 11 mils.  Outboard thrust bearing temperatures range from ~ 140 degF to ~150 degF.  Currently we do not have the axial probes modeled.
# converted=> the variation on both thrust_bearing_position  varies from mil to mils outboard thrust_bearing  temperatures range from degf to degf currently we do not have the axial_probe  modeled
# original=> Since the start of monitoring the stage 1 suction temperature is ranging between ~150 degF  to ~170 degF.  The data sheet indicates a suction temperature of ~ 110 degF.  The other process parameters are now closer to the data sheet values than the model estimate.
#
# Note the increased gearbox vibrations at these conditions.
#
# Is the 7SI107 tag the steam turbine speed and not the compressor speed
# 11/10/2015: Note the lube oil temp has increased a few times in the last few weeks. Was this intentionally artificially lifted
#
# 12/1/2015: Lube Oil Cooler issue opened in Case 14284.
# converted=> since the start of monitor the stage suction_temperature  is range between degf to degf the data sheet indicates a suction_temperature  of degf the other process parameters are now closer to the data sheet values than the model_estimate  note the increased gearbox vibration at these condition is the si tag the steam_turbine  speed and not the compressor_speed  note the lube_oil_temperature  has increased a few times in the last few weeks was this intentionally artificially lifted lube_oil_cooler  issue opened in case
# original=> Wind turbine 21 appears to be curtailed at ~2700 kW with wind speed between ~5-15 m/s.
# converted=> wind_turbine  appears to be curtailed at kw with wind_speed  between m s
# original=> test
# converted=> test
# original=> Within the past week, gear bearing temperatures have been elevated with temperatures as high as:
# HS-ROT: ~75C
# IMS-GEN: ~63C
# IMS-ROT: ~58C
# ...
# original=> On the last run, the bearing 1 vibrations increased from 3.2 to 3.6 mils, and have now come back down at 2.9 mils on the most recent run. The bearing 1 seismic vibrations show a small change at this same time, but the other bearing vibrations did not experience a change.
#
# 8/14/2015: bearing 1 vibrations have been steady and tracking in line with the model.
#
# 12/11/2015:  The bearing 1 vibration readings have been more consistent in the last two months.
# converted=> on the last run the bearing_vibration  increased from to mils and have now come back down at mils on the most recent run the bearing seismic vibration show a small change at this same time but the other bearing_vibration  did not experience a change bearing_vibration  have been steady and track in line with the model the bearing_vibration  read have been more consistent in the last two months
# original=> Y direvtion vibrations have increased above model predictions and there has been a change in axial position as well.
# converted=> y direvtion vibration have increased above model_predicted  and there has been a change in axial_position  as well
# original=> On 8/16 Exhaust Thermocouple 13 (G1.TTXD1_13) deviated from the model by approximately 400 deg F and came back in line with the model after unit was shutdown.
# converted=> on exhaust_thermocouple  (g ttxd ) deviate from the model by approximately deg f and came back in line with the model after unit was shutdown
# original=> Step change in lube oil filter DP from .20 to .07 Lube oil pressure and temperature remain steady
# converted=> step change in lube_oil_filter  dp from to lube_oil_pressure  and temperature remain steady
# original=> Lube Oil Filters increased from 0.1 barg before the shutdown to 0.45 barg after the 12/19 Restart
# converted=> lube_oil_filter  increased from barg before the shutdown to barg after the restart
# original=> On 1/7  Turbine Wheelspace Temperature Stage 1 Aft Outer 2 (G2.TTWS1AO2) has been trending at approx. values of 674 deg F while  Turbine Wheelspace Temperature Stage 1 Aft Outer 1 (G2.TTWS1AO1) is reporting values of aprox. 730 deg F. In reviewing a 140 day trend this is the lowest temperature the Turbine Wheelspace Temperature Stage 1 Aft Outer 2 has been, as it was reporting an approx. value of  700 deg F.
# converted=> on turbine_wheelspace  temperature stage aft outer (g ttws ao ) has been trend at approx values of deg f while turbine_wheelspace  temperature stage aft outer (g ttws ao ) is reporting_values  of aprox deg f in reviewing a day trend this is the lowest temperature the turbine_wheelspace  temperature stage aft outer has been as it was reporting an approx value of deg f
# original=> Lube oil filters have increased from 0.5 bar to 0.76 bar.
# converted=> lube_oil_filter  have increased from bar to bar
# original=> The bearing 1 and 2 vibrations have increased slightly during the most recent starts.  The bearing 1  vibrations have been up to 3.4-3.8 mils and up to 0.3 in/sec on the starts versus estimates of 0.23-0.25 in/sec.
#
# 7/25: Data trained in the model.
# converted=> the bearing and vibration have increased slightly during the most recent start the bearing_vibration  have been up to mils and up to in sec on the start versus estimate of in sec data train in the model
# original=> In the last month the turbine exhaust pressure has been up to over 13 in H20.
#
# Update 3/25: Turbine exhaust pressure has been trending at  approximately 10 in.H20.
# converted=> in the last month the turbine_exhaust_pressure  has been up to over in h update turbine_exhaust_pressure  has been trend at approximately in h
# original=> On 2/8, both X&Y Motor NDE Journal Bearing vibs increased and then returned to estimate. X vibs increased to 21um, and Y vibs increased to 29um.
# converted=> on both x&y motor nde_journal_bearing  vibration increased and then returned to estimate x vibration increased to um and y vibration increased to um
# original=> On 2/10, the thrust axial probe #1A position direct reading started to step to very low values.
#
# 5/27:  The thrust axial probe #1A position direct reading has been in line with the model for the last few months.
#
# 6/10:  The thrust axial probe #1A position direct reading has been in line with the model for the last few months.
# converted=> on the thrust_axial  probe a position direct read started to step to very low_values  the thrust_axial  probe a position direct read has been in line with the model for the last few months the thrust_axial  probe a position direct read has been in line with the model for the last few months
# original=> AWA-VI241229 is reading flatlined at zero. 8/11/2014 - Issue persists. 8/18/2014 - Correct asset name.Issue persists.
# converted=> awa vi is read flatline at zero issue persist correct asset name issue persist
# original=>
# converted=>
# original=>
# converted=>
# original=> 10/15:Dear BP Azerbaijan Colleagues                                        We have been monitoring a change in the operation of the minimum flow valve position after the last two start ups. Is there any issue with a possible stuck valve that has been noticed on the field
# converted=> dear bp azerbaijan colleagues we have been monitor a change in the operation of the minimum flow_valve_position  after the last two start ups is there any issue with a possible stuck valve that has been noticed on the field
# original=> Generator Collector - Hot Air (G2.DTGAH17) has been trending at approximate values of 106 deg F while previous values were approximately 93 deg F.
# converted=> generator collector hot_air  (g dtgah ) has been trend at approximate values of deg f while previous values were approximately deg f
# original=> The motor Drive End Journal Bearing Vibrations increased as high as 60um on 2nd July 2016. From previous cases we note the alarm limit at 65um.
# converted=> the motor drive end journal_bearing  vibration increased as high as um on nd july from previous cases we note the alarm limit at um
# original=> The motor Drive End Journal Bearing Vibrations increased as high as 60um on 2nd July 2016. From previous cases we note the alarm limit at 65um.
#
# 11 July 2016: Condition Persists
# 18 July 2016: Vibrations have dropped to acceptable levels.
# 25 July 2016 - Flow and Pressure do not seem to be correlating with the changes in Vibration - currently trending at ~56um.
#
# 01 August 2016: Vibrations are trending below 58um.
#
# 08 August 2016: Conditions are stable
# converted=> the motor drive end journal_bearing  vibration increased as high as um on nd july from previous cases we note the alarm limit at um july condition persist july vibration have dropped to acceptable levels july flow and pressure do not seem to be correlating with the changes in vibration currently trend at um august vibration are trend below um august condition are stable
# original=> During startup and shutdown, DV-PROFICY.HR298280_HPSHTSTMTE018B - HR2 HP SH DSH OUTLET TEMPERATURE will read erratically low, before coming up to the estimate at higher loads. Update 8-7: Erratic conditions appear to have ceased since beginning of July.
# converted=> during startup and shutdown dv proficy hr hpshtstmte b hr hp_sh_dsh  outlet_temperature  will read_erratic  low before coming up to the estimate at higher loads update erratic condition appear to have ceased since beginning of july
# original=> Update: Erratic condition corrected  Fluid coupling casing vibration has been erratic.
# converted=> update erratic condition corrected fluid_coupling_casing  vibration has been erratic
# original=> After resuming 2x1 operation, duct burner fuel pressure will remain low, spike high to ~55psig, then return to the model after about 6 hours. Duct temperature tracks throughout. Update 3-13: Duct Burner Fuel Pressure now appears to be reading correctly (0psig) when unit is offline. If readings while unit is running are also acceptable, the model can be updated.
# converted=> after resuming x operation duct_burner_fuel  pressure will remain low spike high to psig then return to the model after about hours duct temperature track throughout update duct_burner_fuel  pressure now appears to be read correct ( psig) when unit is offline if read while unit is running are also acceptable the model can be updated
# original=> Update: Lube oil filter changed.  Lube oil filter has been gradually increasing from ~0.07 barg to ~0.2 barg since 4/16/2011.
# converted=> update lube_oil_filter  changed lube_oil_filter  has been gradual increase from barg to barg since
# original=> On 4/27/2011, thrust bearing temp took a step change down from ~67 degC to ~12 degC with model prediction at ~67 degC.
# converted=> on thrust_bearing_temperature  took a step change down from degc to degc with model_predicted  at degc
# original=> Atreduced loads,IP attemperator spray valve and spray flow are higher than expected,with IP RH DSH OUTLET TEMPERATURE decreasing to ~768F with an estimate of ~812F. Update 3-13: IP RH DSH OUTLET TEMPERATUREis back totracking at ~820-840F of late. If current conditions are acceptable, they can be added to the model to improve tracking.
# converted=> atreduced loads ip_attemperator_spray  valve and spray_flow  are higher than expected with ip_rh_dsh  outlet_temperature  decrease to f with an estimate of f update ip_rh_dsh  outlet_temperature is back totracking at f of late if current condition are acceptable they can be added to the model to improve track
# original=> On 5/25/2011, suction pressure took a step change down from ~38.6 barg to ~34.9 barg with model prediction at ~39 barg.
# converted=> on suction_pressure  took a step change down from barg to barg with model_predicted  at barg
# original=> HR298280_GPSTKTE490, A, B, and C are showing increased spread. HR298280_GPSTKTE490A is currently the lowest, reading ~237F, with HR298280_GPSTKTE490B reading ~292F. In October, all four indications were reading within ~10F of each at ~225F. Update 3-13: Conditions persist.
# converted=> hr gpstkte a b and c are showing increased spread hr gpstkte a is currently the lowest read f with hr gpstkte b read f in october all four indications were read within f of each at f update condition persist
# original=> Condition continues Following data return on 5/9 the lube oil DP has been flatlined
# converted=> condition_continues  following data return on the lube_oil  dp has been flatline
# original=> On 3-18, HR298280.LPDRMSTMTE210 - HR2 LP DRUM OUTLET TEMPERATURE increased from ~288F to ~470F. The A and B sensors continued to track as expected at ~290F.
# converted=> on hr lpdrmstmte hr lp_drum  outlet_temperature  increased from f to f the a and b sensor continued to track as expected at f
# original=> Lube oil filter has been slowly increasing from ~0.08 barg to ~0.29 barg since 6/17/2011.
# converted=> lube_oil_filter  has been slowly increase from barg to barg since
# original=>
# converted=>
# original=> On 9/15/2011, pump discharge decreased down to ~40 with model prediction at ~58.  Multiple tags affected.
# converted=> on pump_discharge  decrease down to with model_predicted  at multiple tag affected
# original=> Before shutdown on 11/2/14, HP drum level 3 (tag T010B) began reading elevated from model estimates and drifting higher than the other two drum level indications, now reading about 4 inch differential. Update 11/17/2014: The issue has persisted on the most recent run as well.
# converted=> before shutdown on hp_drum  level (tag t b) began read elevated from model_estimate  and drifting higher than the other two drum level indications now read about inch differential update the issue has persist on the most recent run as well
# original=> After startup on 11/16/2011, lube oil filter increased up to 0.81 barg then dropped to 0.059
# converted=> after startup on lube_oil_filter  increased up to barg then dropped to
# original=> Discharge pressure has increased above model predictions since 12/26.
# converted=> discharge_pressure  has increased above model_predicted  since
# original=> On 11/5/2014, ST load is around 80 MW, GT load is at 168 MW, the unit is running 1X1. The IP RH DSH temp control valve was wide open for the most recent run. There are no duct burners running at this time.
# converted=> on st_load  is around mw gt_load  is at mw the unit is running x the ip_rh_dsh  temperature control_valve  was wide open for the most recent run there are no duct burners running at this time
# original=> Fluid coupling journal bearing temperature has increased above model predictionsl. Fluid coupling oil resevoir temperature has increased above model predictions as well. This is the only bearing increasing
# converted=> fluid_coupling  journal_bearing_temperature  has increased above model predictionsl fluid_coupling  oil resevoir temperature has increased above model_predicted  as well this is the only bearing increase
# original=> IP drum level 2 (HR2 IP drum level 2) was reading around 0 inches on the last run on 12/28 when the model was expecting -2.49 inches. IP drum level 1 is reading -5.9 inches and IP drum level 3 is reading -3.49 inches.
# converted=> ip_drum  level (hr ip_drum  level ) was read around inches on the last run on when the model was expecting inches ip_drum  level is read inches and ip_drum  level is read inches
# original=> Motor winding temperature has increased since 1/16.
# converted=> motor wind temperature has increased since
# original=> Pump drive end journal bearing temperature has increased since 1/17 and there also has been an axial position change in this time frame.
# converted=> pump drive end journal_bearing_temperature  has increased since and there also has been an axial_position  change in this time frame
# original=> HP drum level 2 (HR2 IP drum level 2) is reading up to 5.2 inches starting on 01/11/2015 while the model has been expecting expecting -5.8 inches. IP drum level 1 is reading -6 inches and IP drum level 3 is reading -8 inches.
# converted=> hp_drum  level (hr ip_drum  level ) is read up to inches starting on while the model has been expecting expecting inches ip_drum  level is read inches and ip_drum  level is read inches
# original=> Mischarge pressure has increased above model predictions since 1/19 and remains elevated.
# converted=> mischarge pressure has increased above model_predicted  since and remains elevated
# original=> On 1/25/2015, HP SH DSH spray flow is up to 45,000 lbm/hr and the HP SH DSH outlet temperature went down to as low as 615 deg F when the model was estimating 690 deg F.
# converted=> on hp_sh_dsh  spray_flow  is up to lbm hr and the hp_sh_dsh  outlet_temperature  went down to as low as deg f when the model was estimating deg f
# original=> The Lube Oil Filters have increased from 0.2 bar to 0.7 bar since 2/24 started and continue to rise.
# converted=> the lube_oil_filter  have increased from bar to bar since started and continue to rise
# original=> Lube oil temperature has increased above model predictions. NDE thrust bearing temperature has also increased over the same time period.
# converted=> lube_oil_temperature  has increased above model_predicted  nde thrust_bearing_temperature  has also increased over the same time period
# original=>
# converted=>
# original=> Coupling bearing temperature have increased over the past 36 hours and remain above model predictions.
# converted=> coupling bearing_temperature  have increased over the past hours and remain above model_predicted
# original=> In the last week the HR2 HP drum level B has been flat lined at 13.5 in.  Update 6/12/15: HP Drum Level 3 has dropped to predicted values, but HP Drum Level has flatlined at 13.5in
# converted=> in the last week the hr hp_drum  level b has been flat_lined  at in update hp_drum  level has dropped to predicted values but hp_drum  level has flatline at in
# original=> Condition cleared after restart Seal loop temperature has increased tracking with axial position
# converted=> condition_cleared  after restart seal loop temperature has increased track with axial_position
